# %% [markdown]
# # Multiple Chromosomes Simulation

# %% [markdown]
# **collapse simulation of chromosomes 10 and 11**
# setting up for multiple chromosomes production simulation

# %%
from OpenMiChroM.ChromDynamics import MiChroM
from OpenMiChroM.CndbTools import cndbTools

import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

from openmm.app import *

# %%
block = 5*10**2
n_blocks = 1*10**3

# %% [markdown]
# **{ chr 10 } collapse simulation**

# %%
# chromosome 10 collapse simulation
sim_chr10 = MiChroM(name="chr10", temperature=1.0, time_step=0.01)
sim_chr10.setup(platform="cuda")
sim_chr10.saveFolder('multi_op_chr10_11_allFrames')
Chrom10 = sim_chr10.createSpringSpiral(ChromSeq='../inputs/chr10_beads.txt')
sim_chr10.loadStructure(Chrom10, center=True)

sim_chr10.addFENEBonds(kfb=30.0)
sim_chr10.addAngles(ka=2.0)
sim_chr10.addRepulsiveSoftCore(Ecut=4.0)
sim_chr10.addFlatBottomHarmonic()
sim_chr10.addTypetoType(mu=3.22, rc = 1.78)
sim_chr10.addIdealChromosome(mu=3.22, rc = 1.78, dinit=3, dend=500)

print('GENERATING CHR10 SIM', '\n---\n')
for _ in range(n_blocks):
    sim_chr10.runSimBlock(block, increment=False)
    print('chr10 loop', '\n---\n')

print(sim_chr10.chromRG())
sim_chr10.saveStructure(filename="chr10", mode="ndb")
sim_chr10.saveStructure(filename="chr10", mode="pdb")
del sim_chr10    # why delete variable if still not used ??
# WE DON'T NEED THE VARIABLE ITSELF // WE ONLY NEED THE SAVED FILES
# Out:
#     ***************************************************************************************
#      **** **** *** *** *** *** *** *** OpenMiChroM-1.0.5 *** *** *** *** *** *** **** ****
#
#          OpenMiChroM is a Python library for performing chromatin dynamics simulations.
#                             OpenMiChroM uses the OpenMM Python API,
#                 employing the MiChroM (Minimal Chromatin Model) energy function.
#       The chromatin dynamics simulations generate an ensemble of 3D chromosomal structures
#       that are consistent with experimental Hi-C maps, also allows simulations of a single
#                  or multiple chromosome chain using High-Performance Computing
#                             in different platforms (GPUs and CPUs).
#          OpenMiChroM documentation is available at https://open-michrom.readthedocs.io
#
#          OpenMiChroM is described in: Oliveira Junior, A. B & Contessoto, V, G et. al.
#       A Scalable Computational Approach for Simulating Complexes of Multiple Chromosomes.
#                   Journal of Molecular Biology. doi:10.1016/j.jmb.2020.10.034.
#                                               and
#                                  Oliveira Junior, A. B. et al.
#      Chromosome Modeling on Downsampled Hi-C Maps Enhances the Compartmentalization Signal.
#                         J. Phys. Chem. B, doi:10.1021/acs.jpcb.1c04174.
#
#                     Copyright (c) 2022, The OpenMiChroM development team at
#                                         Rice University
#     ***************************************************************************************
# GENERATING CHR10 SIM
# ---
#
# Number of exceptions: 2711
# adding force  FENEBond 0
# adding force  AngleForce 1
# Add exclusions for RepulsiveSoftCore force
# adding force  RepulsiveSoftCore 2
# adding force  FlatBottomHarmonic 3
# Add exclusions for TypetoType force
# adding force  TypetoType 4
# Add exclusions for IdealChromosome force
# adding force  IdealChromosome 5
# Positions...
#  loaded!
# potential energy is 67.547601
# bl=1 pos[1]=[208.4 -11.0 0.3] dr=1.17 t=0.0ps kin=1.75 pot=67.60 Rg=146.269 SPS=3543
# chr10 loop
# ---
#
# bl=2 pos[1]=[205.9 -11.1 3.6] dr=2.43 t=0.0ps kin=2.53 pot=66.08 Rg=144.181 SPS=3701
# chr10 loop
# ---
#
# bl=3 pos[1]=[201.9 -10.2 5.4] dr=2.99 t=0.0ps kin=3.09 pot=64.29 Rg=141.480 SPS=3664
# chr10 loop
# ---
#
# bl=4 pos[1]=[197.8 -7.5 7.1] dr=3.28 t=0.0ps kin=3.31 pot=62.39 Rg=138.447 SPS=3685
# chr10 loop
# ---
#
# bl=5 pos[1]=[194.5 -6.4 9.5] dr=3.41 t=0.0ps kin=3.43 pot=60.45 Rg=135.271 SPS=3663
# chr10 loop
# ---
#
# bl=6 pos[1]=[189.9 -5.6 11.1] dr=3.42 t=0.0ps kin=3.46 pot=58.51 Rg=132.076 SPS=3642
# chr10 loop
# ---
#
# bl=7 pos[1]=[185.9 -5.4 10.9] dr=3.38 t=0.0ps kin=3.36 pot=56.64 Rg=128.933 SPS=3686
# chr10 loop
# ---
#
# bl=8 pos[1]=[181.0 -6.4 11.2] dr=3.32 t=0.0ps kin=3.32 pot=54.85 Rg=125.845 SPS=3559
# chr10 loop
# ---
#
# bl=9 pos[1]=[175.9 -5.8 10.5] dr=3.28 t=0.0ps kin=3.27 pot=53.15 Rg=122.805 SPS=3567
# chr10 loop
# ---
#
# bl=10 pos[1]=[170.8 -5.8 10.1] dr=3.20 t=0.0ps kin=3.11 pot=51.53 Rg=119.852 SPS=3633
# chr10 loop
# ---
#
# bl=11 pos[1]=[167.7 -6.1 11.3] dr=3.10 t=0.0ps kin=3.06 pot=49.95 Rg=117.010 SPS=3684
# chr10 loop
# ---
#
# bl=12 pos[1]=[163.1 -6.8 10.4] dr=3.07 t=0.0ps kin=3.01 pot=48.48 Rg=114.217 SPS=3608
# chr10 loop
# ---
#
# bl=13 pos[1]=[158.7 -7.1 12.8] dr=3.01 t=0.0ps kin=2.90 pot=47.07 Rg=111.485 SPS=3635
# chr10 loop
# ---
#
# bl=14 pos[1]=[153.5 -6.6 12.3] dr=2.95 t=0.0ps kin=2.87 pot=45.73 Rg=108.813 SPS=3682
# chr10 loop
# ---
#
# bl=15 pos[1]=[149.5 -6.7 11.6] dr=2.92 t=0.0ps kin=2.84 pot=44.41 Rg=106.179 SPS=3603
# chr10 loop
# ---
#
# bl=16 pos[1]=[145.6 -7.7 11.1] dr=2.85 t=0.0ps kin=2.76 pot=43.21 Rg=103.621 SPS=3377
# chr10 loop
# ---
#
# bl=17 pos[1]=[142.6 -7.1 11.7] dr=2.77 t=0.0ps kin=2.66 pot=42.04 Rg=101.161 SPS=3543
# chr10 loop
# ---
#
# bl=18 pos[1]=[140.2 -6.4 11.9] dr=2.71 t=0.0ps kin=2.61 pot=40.97 Rg=98.764 SPS=3639
# chr10 loop
# ---
#
# bl=19 pos[1]=[137.6 -5.8 12.0] dr=2.65 t=0.0ps kin=2.58 pot=39.93 Rg=96.423 SPS=3607
# chr10 loop
# ---
#
# bl=20 pos[1]=[133.7 -5.8 12.1] dr=2.62 t=0.0ps kin=2.56 pot=38.94 Rg=94.135 SPS=3536
# chr10 loop
# ---
#
# bl=21 pos[1]=[127.9 -6.3 12.2] dr=2.57 t=0.0ps kin=2.50 pot=38.05 Rg=91.907 SPS=3465
# chr10 loop
# ---
#
# bl=22 pos[1]=[125.3 -6.4 11.7] dr=2.54 t=0.0ps kin=2.44 pot=37.11 Rg=89.717 SPS=3514
# chr10 loop
# ---
#
# bl=23 pos[1]=[120.2 -5.3 9.6] dr=2.48 t=0.0ps kin=2.39 pot=36.25 Rg=87.585 SPS=3624
# chr10 loop
# ---
#
# bl=24 pos[1]=[118.1 -3.2 9.8] dr=2.45 t=0.0ps kin=2.38 pot=35.44 Rg=85.505 SPS=3554
# chr10 loop
# ---
#
# bl=25 pos[1]=[114.6 -3.3 10.3] dr=2.40 t=0.0ps kin=2.34 pot=34.68 Rg=83.479 SPS=3489
# chr10 loop
# ---
#
# bl=26 pos[1]=[111.9 -1.2 8.9] dr=2.35 t=0.0ps kin=2.27 pot=33.90 Rg=81.499 SPS=3482
# chr10 loop
# ---
#
# bl=27 pos[1]=[109.5 -2.2 8.4] dr=2.29 t=0.0ps kin=2.26 pot=33.19 Rg=79.581 SPS=3572
# chr10 loop
# ---
#
# bl=28 pos[1]=[106.4 -2.9 9.7] dr=2.25 t=0.0ps kin=2.19 pot=32.56 Rg=77.714 SPS=3611
# chr10 loop
# ---
#
# bl=29 pos[1]=[103.6 -2.3 7.4] dr=2.19 t=0.0ps kin=2.16 pot=31.89 Rg=75.922 SPS=3485
# chr10 loop
# ---
#
# bl=30 pos[1]=[100.4 -0.8 7.2] dr=2.14 t=0.0ps kin=2.09 pot=31.37 Rg=74.201 SPS=3610
# chr10 loop
# ---
#
# bl=31 pos[1]=[97.2 -1.0 7.5] dr=2.09 t=0.0ps kin=2.05 pot=30.82 Rg=72.527 SPS=3562
# chr10 loop
# ---
#
# bl=32 pos[1]=[95.1 -2.9 8.5] dr=2.05 t=0.0ps kin=2.05 pot=30.29 Rg=70.890 SPS=3616
# chr10 loop
# ---
#
# bl=33 pos[1]=[91.9 -1.6 8.9] dr=2.00 t=0.0ps kin=1.98 pot=29.77 Rg=69.317 SPS=3611
# chr10 loop
# ---
#
# bl=34 pos[1]=[88.9 -1.0 7.9] dr=1.95 t=0.0ps kin=1.98 pot=29.34 Rg=67.807 SPS=3612
# chr10 loop
# ---
#
# bl=35 pos[1]=[88.3 -1.1 8.0] dr=1.95 t=0.0ps kin=2.00 pot=28.90 Rg=66.322 SPS=3601
# chr10 loop
# ---
#
# bl=36 pos[1]=[86.5 -1.2 8.7] dr=1.93 t=0.0ps kin=1.95 pot=28.48 Rg=64.844 SPS=3559
# chr10 loop
# ---
#
# bl=37 pos[1]=[84.7 -2.0 8.5] dr=1.87 t=0.0ps kin=1.92 pot=28.04 Rg=63.423 SPS=3504
# chr10 loop
# ---
#
# bl=38 pos[1]=[81.5 -2.7 8.4] dr=1.84 t=0.0ps kin=1.87 pot=27.63 Rg=62.042 SPS=3473
# chr10 loop
# ---
#
# bl=39 pos[1]=[79.3 -3.7 9.3] dr=1.81 t=0.0ps kin=1.84 pot=27.27 Rg=60.695 SPS=3471
# chr10 loop
# ---
#
# bl=40 pos[1]=[77.4 -3.8 9.5] dr=1.80 t=0.0ps kin=1.86 pot=26.91 Rg=59.366 SPS=3464
# chr10 loop
# ---
#
# bl=41 pos[1]=[74.8 -2.5 9.7] dr=1.79 t=0.0ps kin=1.87 pot=26.58 Rg=58.044 SPS=3513
# chr10 loop
# ---
#
# bl=42 pos[1]=[73.2 -1.3 8.9] dr=1.78 t=0.0ps kin=1.82 pot=26.30 Rg=56.751 SPS=3427
# chr10 loop
# ---
#
# bl=43 pos[1]=[71.3 -2.7 8.6] dr=1.75 t=0.0ps kin=1.85 pot=25.97 Rg=55.511 SPS=3458
# chr10 loop
# ---
#
# bl=44 pos[1]=[69.2 -3.3 8.5] dr=1.69 t=0.0ps kin=1.75 pot=25.71 Rg=54.335 SPS=3483
# chr10 loop
# ---
#
# bl=45 pos[1]=[66.9 -4.1 8.9] dr=1.63 t=0.0ps kin=1.75 pot=25.39 Rg=53.214 SPS=3410
# chr10 loop
# ---
#
# bl=46 pos[1]=[63.9 -4.2 9.7] dr=1.62 t=0.0ps kin=1.79 pot=25.16 Rg=52.122 SPS=3478
# chr10 loop
# ---
#
# bl=47 pos[1]=[61.1 -3.1 10.0] dr=1.65 t=0.0ps kin=1.75 pot=24.91 Rg=51.003 SPS=3440
# chr10 loop
# ---
#
# bl=48 pos[1]=[60.0 -3.3 9.7] dr=1.63 t=0.0ps kin=1.80 pot=24.68 Rg=49.906 SPS=3056
# chr10 loop
# ---
#
# bl=49 pos[1]=[59.6 -3.9 7.6] dr=1.65 t=0.0ps kin=1.83 pot=24.42 Rg=48.772 SPS=3203
# chr10 loop
# ---
#
#
# Statistics for the simulation chr10, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.78568492  0.53361889  0.47990861]   Rg =  48.77243
#      median bond size is  0.965274025856995
#      three shortest/longest (<10)/ bonds are  [0.87835683 0.87855241 0.87994186]    [1.08901254 1.09066657 1.09789231]
#      95 percentile of distance to center is:    61.26357151970216
#      density of closest 95% monomers is:    0.0026749627986819035
#      density of the core monomers is:    0.0007394753454895622
#      min/median/mean/max coordinates are:
#      x: -53.11, -6.31, -0.79, 65.20
#      y: -59.01, 7.46, 0.53, 54.79
#      z: -15.15, 0.97, 0.48, 14.19
#
# Statistics for velocities:
#      mean kinetic energy is:  1.832605663383306 should be: 1.5
#      fastest particles are (in kT):  [10.38434288 10.55806326 10.67566887 10.77187367 13.41857687]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  24.418962596792035
# bl=50 pos[1]=[59.8 -1.8 7.0] dr=1.63 t=0.0ps kin=1.74 pot=24.22 Rg=47.646 SPS=2918
# chr10 loop
# ---
#
# bl=51 pos[1]=[58.7 -2.9 6.8] dr=1.59 t=0.0ps kin=1.68 pot=24.00 Rg=46.567 SPS=3038
# chr10 loop
# ---
#
# bl=52 pos[1]=[56.9 -3.2 5.8] dr=1.52 t=0.0ps kin=1.70 pot=23.77 Rg=45.564 SPS=3155
# chr10 loop
# ---
#
# bl=53 pos[1]=[56.7 -3.6 7.1] dr=1.51 t=0.0ps kin=1.69 pot=23.57 Rg=44.589 SPS=3038
# chr10 loop
# ---
#
# bl=54 pos[1]=[54.9 -4.1 7.1] dr=1.50 t=0.0ps kin=1.71 pot=23.44 Rg=43.608 SPS=3156
# chr10 loop
# ---
#
# bl=55 pos[1]=[52.2 -4.3 7.7] dr=1.51 t=0.0ps kin=1.71 pot=23.22 Rg=42.650 SPS=3115
# chr10 loop
# ---
#
# bl=56 pos[1]=[50.5 -4.9 8.5] dr=1.47 t=0.0ps kin=1.64 pot=23.09 Rg=41.738 SPS=3147
# chr10 loop
# ---
#
# bl=57 pos[1]=[48.7 -4.5 9.9] dr=1.43 t=0.0ps kin=1.67 pot=22.88 Rg=40.883 SPS=2988
# chr10 loop
# ---
#
# bl=58 pos[1]=[46.3 -3.6 8.1] dr=1.42 t=0.0ps kin=1.66 pot=22.78 Rg=40.033 SPS=3072
# chr10 loop
# ---
#
# bl=59 pos[1]=[45.7 -3.7 8.5] dr=1.43 t=0.0ps kin=1.66 pot=22.63 Rg=39.206 SPS=2933
# chr10 loop
# ---
#
# bl=60 pos[1]=[44.9 -4.9 9.2] dr=1.39 t=0.0ps kin=1.63 pot=22.52 Rg=38.382 SPS=2965
# chr10 loop
# ---
#
# bl=61 pos[1]=[45.0 -4.3 8.3] dr=1.36 t=0.0ps kin=1.63 pot=22.37 Rg=37.596 SPS=3022
# chr10 loop
# ---
#
# bl=62 pos[1]=[43.2 -3.4 6.8] dr=1.36 t=0.0ps kin=1.62 pot=22.26 Rg=36.825 SPS=2780
# chr10 loop
# ---
#
# bl=63 pos[1]=[41.9 -3.9 6.3] dr=1.35 t=0.0ps kin=1.62 pot=22.15 Rg=36.076 SPS=2986
# chr10 loop
# ---
#
# bl=64 pos[1]=[39.7 -1.4 7.0] dr=1.35 t=0.0ps kin=1.62 pot=22.01 Rg=35.321 SPS=2976
# chr10 loop
# ---
#
# bl=65 pos[1]=[39.3 -1.4 7.3] dr=1.30 t=0.0ps kin=1.59 pot=21.97 Rg=34.630 SPS=2977
# chr10 loop
# ---
#
# bl=66 pos[1]=[38.1 -1.2 5.6] dr=1.32 t=0.0ps kin=1.61 pot=21.84 Rg=33.923 SPS=2864
# chr10 loop
# ---
#
# bl=67 pos[1]=[37.5 -1.1 5.9] dr=1.33 t=0.0ps kin=1.62 pot=21.72 Rg=33.211 SPS=2959
# chr10 loop
# ---
#
# bl=68 pos[1]=[36.7 -2.0 5.2] dr=1.31 t=0.0ps kin=1.56 pot=21.68 Rg=32.534 SPS=2980
# chr10 loop
# ---
#
# bl=69 pos[1]=[34.8 -3.3 5.5] dr=1.28 t=0.0ps kin=1.56 pot=21.57 Rg=31.906 SPS=3006
# chr10 loop
# ---
#
# bl=70 pos[1]=[34.0 -4.0 6.7] dr=1.24 t=0.0ps kin=1.59 pot=21.48 Rg=31.325 SPS=2952
# chr10 loop
# ---
#
# bl=71 pos[1]=[33.9 -3.5 4.8] dr=1.24 t=0.0ps kin=1.62 pot=21.41 Rg=30.743 SPS=3014
# chr10 loop
# ---
#
# bl=72 pos[1]=[33.1 -0.9 3.2] dr=1.24 t=0.0ps kin=1.60 pot=21.35 Rg=30.170 SPS=2782
# chr10 loop
# ---
#
# bl=73 pos[1]=[33.6 -0.3 1.3] dr=1.23 t=0.0ps kin=1.59 pot=21.31 Rg=29.621 SPS=2919
# chr10 loop
# ---
#
# bl=74 pos[1]=[33.7 1.5 2.7] dr=1.22 t=0.0ps kin=1.57 pot=21.22 Rg=29.104 SPS=2796
# chr10 loop
# ---
#
# bl=75 pos[1]=[34.1 1.7 2.7] dr=1.20 t=0.0ps kin=1.54 pot=21.16 Rg=28.601 SPS=2830
# chr10 loop
# ---
#
# bl=76 pos[1]=[33.3 2.2 2.5] dr=1.18 t=0.0ps kin=1.58 pot=21.11 Rg=28.096 SPS=2774
# chr10 loop
# ---
#
# bl=77 pos[1]=[30.7 1.7 3.8] dr=1.19 t=0.0ps kin=1.57 pot=21.07 Rg=27.611 SPS=2747
# chr10 loop
# ---
#
# bl=78 pos[1]=[31.9 2.7 3.3] dr=1.18 t=0.0ps kin=1.59 pot=20.98 Rg=27.141 SPS=2856
# chr10 loop
# ---
#
# bl=79 pos[1]=[33.5 1.5 3.0] dr=1.17 t=0.0ps kin=1.55 pot=20.91 Rg=26.679 SPS=2771
# chr10 loop
# ---
#
# bl=80 pos[1]=[34.1 -0.2 4.4] dr=1.16 t=0.0ps kin=1.57 pot=20.86 Rg=26.214 SPS=2763
# chr10 loop
# ---
#
# bl=81 pos[1]=[32.2 -0.8 4.9] dr=1.18 t=0.0ps kin=1.55 pot=20.86 Rg=25.732 SPS=2898
# chr10 loop
# ---
#
# bl=82 pos[1]=[32.2 0.2 5.9] dr=1.15 t=0.0ps kin=1.55 pot=20.80 Rg=25.247 SPS=2833
# chr10 loop
# ---
#
# bl=83 pos[1]=[31.0 -0.9 4.8] dr=1.16 t=0.0ps kin=1.58 pot=20.74 Rg=24.795 SPS=2765
# chr10 loop
# ---
#
# bl=84 pos[1]=[31.4 -0.3 6.7] dr=1.11 t=0.0ps kin=1.53 pot=20.69 Rg=24.384 SPS=2823
# chr10 loop
# ---
#
# bl=85 pos[1]=[29.8 1.4 8.0] dr=1.11 t=0.0ps kin=1.56 pot=20.67 Rg=24.000 SPS=2634
# chr10 loop
# ---
#
# bl=86 pos[1]=[29.6 1.5 8.0] dr=1.10 t=0.0ps kin=1.57 pot=20.63 Rg=23.615 SPS=2637
# chr10 loop
# ---
#
# bl=87 pos[1]=[28.7 1.0 5.1] dr=1.10 t=0.0ps kin=1.56 pot=20.62 Rg=23.253 SPS=2793
# chr10 loop
# ---
#
# bl=88 pos[1]=[27.8 2.3 4.4] dr=1.10 t=0.0ps kin=1.54 pot=20.60 Rg=22.917 SPS=2639
# chr10 loop
# ---
#
# bl=89 pos[1]=[26.9 2.9 4.0] dr=1.08 t=0.0ps kin=1.53 pot=20.56 Rg=22.572 SPS=2802
# chr10 loop
# ---
#
# bl=90 pos[1]=[26.6 2.9 4.2] dr=1.10 t=0.0ps kin=1.57 pot=20.49 Rg=22.196 SPS=2765
# chr10 loop
# ---
#
# bl=91 pos[1]=[26.2 2.8 5.8] dr=1.08 t=0.0ps kin=1.53 pot=20.48 Rg=21.847 SPS=2797
# chr10 loop
# ---
#
# bl=92 pos[1]=[24.7 2.6 4.7] dr=1.08 t=0.0ps kin=1.48 pot=20.45 Rg=21.494 SPS=2835
# chr10 loop
# ---
#
# bl=93 pos[1]=[25.0 3.6 5.3] dr=1.08 t=0.0ps kin=1.54 pot=20.36 Rg=21.186 SPS=2825
# chr10 loop
# ---
#
# bl=94 pos[1]=[23.5 3.6 5.4] dr=1.09 t=0.0ps kin=1.49 pot=20.37 Rg=20.910 SPS=2903
# chr10 loop
# ---
#
# bl=95 pos[1]=[24.2 2.6 5.0] dr=1.05 t=0.0ps kin=1.49 pot=20.39 Rg=20.649 SPS=2865
# chr10 loop
# ---
#
# bl=96 pos[1]=[23.5 2.9 5.4] dr=1.04 t=0.0ps kin=1.50 pot=20.37 Rg=20.408 SPS=2854
# chr10 loop
# ---
#
# bl=97 pos[1]=[22.0 3.9 4.7] dr=1.03 t=0.0ps kin=1.50 pot=20.34 Rg=20.195 SPS=2815
# chr10 loop
# ---
#
# bl=98 pos[1]=[21.2 1.8 5.2] dr=1.04 t=0.0ps kin=1.50 pot=20.32 Rg=19.964 SPS=2815
# chr10 loop
# ---
#
# bl=99 pos[1]=[19.8 2.5 4.1] dr=1.05 t=0.0ps kin=1.50 pot=20.27 Rg=19.727 SPS=2926
# chr10 loop
# ---
#
#
# Statistics for the simulation chr10, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.66554966  0.34644035 -0.09966641]   Rg =  19.72663
#      median bond size is  0.9645595774344613
#      three shortest/longest (<10)/ bonds are  [0.87627731 0.88612747 0.88686643]    [1.07912217 1.10534565 1.14319861]
#      95 percentile of distance to center is:    23.97728738370858
#      density of closest 95% monomers is:    0.04461948315093238
#      density of the core monomers is:    0.009026116791653629
#      min/median/mean/max coordinates are:
#      x: -23.21, -2.15, -0.67, 24.27
#      y: -24.58, 2.42, 0.35, 24.05
#      z: -9.34, 0.03, -0.10, 7.91
#
# Statistics for velocities:
#      mean kinetic energy is:  1.501839261718756 should be: 1.5
#      fastest particles are (in kT):  [ 8.85379319  9.02402813  9.62409445 10.02978228 10.39496079]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  20.266555471054573
# bl=100 pos[1]=[18.6 2.6 4.8] dr=1.05 t=0.0ps kin=1.49 pot=20.29 Rg=19.530 SPS=2856
# chr10 loop
# ---
#
# bl=101 pos[1]=[18.7 2.5 4.5] dr=1.03 t=0.0ps kin=1.51 pot=20.26 Rg=19.298 SPS=2801
# chr10 loop
# ---
#
# bl=102 pos[1]=[18.2 3.8 3.6] dr=1.04 t=0.0ps kin=1.47 pot=20.28 Rg=19.062 SPS=2803
# chr10 loop
# ---
#
# bl=103 pos[1]=[17.8 3.4 4.5] dr=1.02 t=0.0ps kin=1.51 pot=20.23 Rg=18.796 SPS=2880
# chr10 loop
# ---
#
# bl=104 pos[1]=[17.8 2.1 6.4] dr=1.03 t=0.0ps kin=1.57 pot=20.23 Rg=18.525 SPS=2731
# chr10 loop
# ---
#
# bl=105 pos[1]=[17.7 2.8 4.5] dr=1.05 t=0.0ps kin=1.58 pot=20.22 Rg=18.283 SPS=2827
# chr10 loop
# ---
#
# bl=106 pos[1]=[17.4 2.6 3.8] dr=1.05 t=0.0ps kin=1.54 pot=20.26 Rg=18.063 SPS=2848
# chr10 loop
# ---
#
# bl=107 pos[1]=[16.9 3.6 4.5] dr=1.03 t=0.0ps kin=1.55 pot=20.19 Rg=17.845 SPS=2847
# chr10 loop
# ---
#
# bl=108 pos[1]=[15.7 2.9 5.5] dr=1.02 t=0.0ps kin=1.57 pot=20.16 Rg=17.630 SPS=2815
# chr10 loop
# ---
#
# bl=109 pos[1]=[15.8 3.3 6.0] dr=1.02 t=0.0ps kin=1.44 pot=20.19 Rg=17.425 SPS=2622
# chr10 loop
# ---
#
# bl=110 pos[1]=[16.1 2.5 5.9] dr=1.00 t=0.0ps kin=1.49 pot=20.18 Rg=17.242 SPS=2870
# chr10 loop
# ---
#
# bl=111 pos[1]=[16.2 3.2 5.1] dr=0.98 t=0.0ps kin=1.53 pot=20.10 Rg=17.078 SPS=2934
# chr10 loop
# ---
#
# bl=112 pos[1]=[16.7 3.9 5.4] dr=1.02 t=0.0ps kin=1.51 pot=20.12 Rg=16.978 SPS=2928
# chr10 loop
# ---
#
# bl=113 pos[1]=[17.5 5.0 5.6] dr=1.01 t=0.0ps kin=1.47 pot=20.13 Rg=16.867 SPS=2882
# chr10 loop
# ---
#
# bl=114 pos[1]=[17.8 4.6 4.3] dr=1.01 t=0.0ps kin=1.47 pot=20.11 Rg=16.710 SPS=2900
# chr10 loop
# ---
#
# bl=115 pos[1]=[17.3 4.6 5.5] dr=0.98 t=0.0ps kin=1.50 pot=20.11 Rg=16.603 SPS=2748
# chr10 loop
# ---
#
# bl=116 pos[1]=[16.6 4.2 6.5] dr=1.00 t=0.0ps kin=1.50 pot=20.09 Rg=16.468 SPS=2799
# chr10 loop
# ---
#
# bl=117 pos[1]=[17.0 4.7 6.9] dr=0.99 t=0.0ps kin=1.53 pot=20.06 Rg=16.342 SPS=2945
# chr10 loop
# ---
#
# bl=118 pos[1]=[16.4 4.9 7.6] dr=1.00 t=0.0ps kin=1.44 pot=20.13 Rg=16.223 SPS=2954
# chr10 loop
# ---
#
# bl=119 pos[1]=[16.1 4.2 7.2] dr=1.00 t=0.0ps kin=1.50 pot=20.09 Rg=16.110 SPS=2845
# chr10 loop
# ---
#
# bl=120 pos[1]=[16.5 3.5 7.3] dr=1.03 t=0.0ps kin=1.53 pot=20.11 Rg=16.011 SPS=2823
# chr10 loop
# ---
#
# bl=121 pos[1]=[15.5 3.5 5.7] dr=1.01 t=0.0ps kin=1.53 pot=20.10 Rg=15.895 SPS=2959
# chr10 loop
# ---
#
# bl=122 pos[1]=[15.3 3.7 5.5] dr=1.01 t=0.0ps kin=1.51 pot=20.09 Rg=15.779 SPS=2914
# chr10 loop
# ---
#
# bl=123 pos[1]=[14.5 4.1 5.9] dr=1.00 t=0.0ps kin=1.47 pot=20.08 Rg=15.642 SPS=2730
# chr10 loop
# ---
#
# bl=124 pos[1]=[13.5 3.3 4.7] dr=1.02 t=0.0ps kin=1.51 pot=20.05 Rg=15.493 SPS=2858
# chr10 loop
# ---
#
# bl=125 pos[1]=[14.0 4.0 5.7] dr=1.01 t=0.0ps kin=1.51 pot=20.06 Rg=15.368 SPS=2930
# chr10 loop
# ---
#
# bl=126 pos[1]=[14.8 4.2 5.2] dr=0.97 t=0.0ps kin=1.51 pot=20.04 Rg=15.235 SPS=2862
# chr10 loop
# ---
#
# bl=127 pos[1]=[14.8 4.1 4.9] dr=1.00 t=0.0ps kin=1.54 pot=20.07 Rg=15.113 SPS=2939
# chr10 loop
# ---
#
# bl=128 pos[1]=[16.2 4.0 4.0] dr=1.00 t=0.0ps kin=1.47 pot=20.11 Rg=15.033 SPS=2804
# chr10 loop
# ---
#
# bl=129 pos[1]=[15.8 4.3 4.1] dr=1.01 t=0.0ps kin=1.55 pot=20.03 Rg=14.927 SPS=2856
# chr10 loop
# ---
#
# bl=130 pos[1]=[15.7 4.1 5.3] dr=0.99 t=0.0ps kin=1.49 pot=20.03 Rg=14.851 SPS=2926
# chr10 loop
# ---
#
# bl=131 pos[1]=[16.2 4.2 4.6] dr=1.01 t=0.0ps kin=1.50 pot=20.02 Rg=14.749 SPS=2903
# chr10 loop
# ---
#
# bl=132 pos[1]=[15.9 3.9 7.4] dr=0.95 t=0.0ps kin=1.48 pot=20.01 Rg=14.658 SPS=2782
# chr10 loop
# ---
#
# bl=133 pos[1]=[15.1 2.9 6.8] dr=0.99 t=0.0ps kin=1.44 pot=20.02 Rg=14.547 SPS=2869
# chr10 loop
# ---
#
# bl=134 pos[1]=[14.1 4.1 6.3] dr=0.98 t=0.0ps kin=1.49 pot=19.97 Rg=14.400 SPS=2826
# chr10 loop
# ---
#
# bl=135 pos[1]=[13.8 3.8 6.9] dr=1.01 t=0.0ps kin=1.51 pot=19.99 Rg=14.234 SPS=2943
# chr10 loop
# ---
#
# bl=136 pos[1]=[13.6 3.9 7.1] dr=1.00 t=0.0ps kin=1.54 pot=19.96 Rg=14.062 SPS=2819
# chr10 loop
# ---
#
# bl=137 pos[1]=[12.9 4.3 6.6] dr=1.00 t=0.0ps kin=1.52 pot=20.02 Rg=13.904 SPS=2827
# chr10 loop
# ---
#
# bl=138 pos[1]=[12.0 4.1 5.8] dr=0.99 t=0.0ps kin=1.51 pot=20.04 Rg=13.796 SPS=2844
# chr10 loop
# ---
#
# bl=139 pos[1]=[12.5 3.5 6.5] dr=0.98 t=0.0ps kin=1.57 pot=19.97 Rg=13.705 SPS=2714
# chr10 loop
# ---
#
# bl=140 pos[1]=[11.6 3.4 5.7] dr=0.98 t=0.0ps kin=1.52 pot=20.01 Rg=13.606 SPS=2772
# chr10 loop
# ---
#
# bl=141 pos[1]=[11.9 2.9 5.7] dr=1.00 t=0.0ps kin=1.53 pot=20.01 Rg=13.506 SPS=2621
# chr10 loop
# ---
#
# bl=142 pos[1]=[14.8 3.4 7.6] dr=0.99 t=0.0ps kin=1.51 pot=20.01 Rg=13.416 SPS=2847
# chr10 loop
# ---
#
# bl=143 pos[1]=[15.3 3.7 7.2] dr=0.99 t=0.0ps kin=1.50 pot=20.01 Rg=13.362 SPS=2808
# chr10 loop
# ---
#
# bl=144 pos[1]=[14.9 3.5 5.3] dr=0.99 t=0.0ps kin=1.49 pot=20.04 Rg=13.292 SPS=2762
# chr10 loop
# ---
#
# bl=145 pos[1]=[15.9 3.8 3.7] dr=0.95 t=0.0ps kin=1.51 pot=19.99 Rg=13.212 SPS=2811
# chr10 loop
# ---
#
# bl=146 pos[1]=[15.5 4.7 4.3] dr=0.95 t=0.0ps kin=1.51 pot=19.95 Rg=13.079 SPS=2893
# chr10 loop
# ---
#
# bl=147 pos[1]=[14.0 3.8 5.5] dr=0.98 t=0.0ps kin=1.49 pot=20.00 Rg=12.929 SPS=2829
# chr10 loop
# ---
#
# bl=148 pos[1]=[13.2 2.9 5.1] dr=0.98 t=0.0ps kin=1.52 pot=19.97 Rg=12.798 SPS=2795
# chr10 loop
# ---
#
# bl=149 pos[1]=[13.8 3.6 5.0] dr=0.97 t=0.0ps kin=1.52 pot=19.90 Rg=12.656 SPS=2850
# chr10 loop
# ---
#
#
# Statistics for the simulation chr10, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-1.21653131  0.03215653 -0.02374653]   Rg =  12.656203
#      median bond size is  0.9644632408045866
#      three shortest/longest (<10)/ bonds are  [0.8759205  0.87752883 0.87793253]    [1.08005679 1.08485947 1.08898474]
#      95 percentile of distance to center is:    16.479026198087155
#      density of closest 95% monomers is:    0.13744534908706854
#      density of the core monomers is:    0.05484416943688438
#      min/median/mean/max coordinates are:
#      x: -15.75, -1.92, -1.22, 15.93
#      y: -18.33, 1.83, 0.03, 15.47
#      z: -8.17, 0.04, -0.02, 7.16
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5261901129299362 should be: 1.5
#      fastest particles are (in kT):  [8.32894354 8.4599037  8.67860946 9.62711255 9.89613018]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.900416551438052
# bl=150 pos[1]=[14.5 1.7 4.7] dr=0.96 t=0.0ps kin=1.49 pot=19.93 Rg=12.571 SPS=2657
# chr10 loop
# ---
#
# bl=151 pos[1]=[15.4 1.5 4.8] dr=0.95 t=0.0ps kin=1.50 pot=19.93 Rg=12.483 SPS=2864
# chr10 loop
# ---
#
# bl=152 pos[1]=[14.6 2.1 3.6] dr=0.96 t=0.0ps kin=1.49 pot=19.95 Rg=12.403 SPS=2858
# chr10 loop
# ---
#
# bl=153 pos[1]=[14.2 1.2 2.7] dr=0.98 t=0.0ps kin=1.49 pot=19.97 Rg=12.363 SPS=2889
# chr10 loop
# ---
#
# bl=154 pos[1]=[13.0 1.7 3.3] dr=1.01 t=0.0ps kin=1.53 pot=19.99 Rg=12.320 SPS=2841
# chr10 loop
# ---
#
# bl=155 pos[1]=[13.8 1.4 3.3] dr=0.98 t=0.0ps kin=1.53 pot=19.92 Rg=12.277 SPS=2803
# chr10 loop
# ---
#
# bl=156 pos[1]=[14.0 0.2 2.7] dr=0.99 t=0.0ps kin=1.52 pot=19.96 Rg=12.245 SPS=2865
# chr10 loop
# ---
#
# bl=157 pos[1]=[13.7 0.4 3.2] dr=0.99 t=0.0ps kin=1.51 pot=19.96 Rg=12.200 SPS=2905
# chr10 loop
# ---
#
# bl=158 pos[1]=[14.3 0.6 3.4] dr=0.99 t=0.0ps kin=1.48 pot=19.97 Rg=12.161 SPS=2828
# chr10 loop
# ---
#
# bl=159 pos[1]=[13.1 0.4 2.2] dr=0.99 t=0.0ps kin=1.51 pot=19.96 Rg=12.125 SPS=2889
# chr10 loop
# ---
#
# bl=160 pos[1]=[14.1 -0.6 2.6] dr=0.97 t=0.0ps kin=1.51 pot=19.91 Rg=12.101 SPS=2808
# chr10 loop
# ---
#
# bl=161 pos[1]=[13.3 -0.3 2.8] dr=0.97 t=0.0ps kin=1.49 pot=19.90 Rg=12.047 SPS=2668
# chr10 loop
# ---
#
# bl=162 pos[1]=[13.7 0.1 3.3] dr=0.97 t=0.0ps kin=1.51 pot=19.91 Rg=12.016 SPS=2801
# chr10 loop
# ---
#
# bl=163 pos[1]=[13.3 0.7 1.6] dr=0.98 t=0.0ps kin=1.49 pot=19.91 Rg=11.989 SPS=2872
# chr10 loop
# ---
#
# bl=164 pos[1]=[12.3 1.1 2.4] dr=0.99 t=0.0ps kin=1.48 pot=19.97 Rg=11.917 SPS=2842
# chr10 loop
# ---
#
# bl=165 pos[1]=[12.1 0.7 2.1] dr=0.98 t=0.0ps kin=1.53 pot=19.90 Rg=11.837 SPS=2855
# chr10 loop
# ---
#
# bl=166 pos[1]=[12.2 -0.3 2.4] dr=0.97 t=0.0ps kin=1.50 pot=19.96 Rg=11.795 SPS=2924
# chr10 loop
# ---
#
# bl=167 pos[1]=[12.8 -0.5 2.1] dr=0.98 t=0.0ps kin=1.50 pot=19.96 Rg=11.734 SPS=2790
# chr10 loop
# ---
#
# bl=168 pos[1]=[14.5 -0.5 2.8] dr=0.98 t=0.0ps kin=1.53 pot=19.91 Rg=11.679 SPS=2896
# chr10 loop
# ---
#
# bl=169 pos[1]=[13.5 -1.2 3.4] dr=0.99 t=0.0ps kin=1.53 pot=19.99 Rg=11.635 SPS=3034
# chr10 loop
# ---
#
# bl=170 pos[1]=[14.0 -2.3 3.9] dr=0.99 t=0.0ps kin=1.56 pot=19.98 Rg=11.589 SPS=2898
# chr10 loop
# ---
#
# bl=171 pos[1]=[14.6 -1.3 4.2] dr=1.01 t=0.0ps kin=1.54 pot=19.95 Rg=11.536 SPS=2986
# chr10 loop
# ---
#
# bl=172 pos[1]=[14.1 -0.3 4.6] dr=0.98 t=0.0ps kin=1.53 pot=19.94 Rg=11.470 SPS=2970
# chr10 loop
# ---
#
# bl=173 pos[1]=[13.3 1.3 5.2] dr=0.97 t=0.0ps kin=1.51 pot=19.93 Rg=11.386 SPS=2806
# chr10 loop
# ---
#
# bl=174 pos[1]=[14.4 4.2 3.9] dr=0.98 t=0.0ps kin=1.50 pot=19.91 Rg=11.279 SPS=2762
# chr10 loop
# ---
#
# bl=175 pos[1]=[13.5 3.5 2.2] dr=0.98 t=0.0ps kin=1.50 pot=19.91 Rg=11.186 SPS=2674
# chr10 loop
# ---
#
# bl=176 pos[1]=[12.0 3.2 1.7] dr=0.97 t=0.0ps kin=1.49 pot=19.87 Rg=11.122 SPS=2581
# chr10 loop
# ---
#
# bl=177 pos[1]=[12.1 2.8 1.1] dr=0.97 t=0.0ps kin=1.47 pot=19.90 Rg=11.067 SPS=2582
# chr10 loop
# ---
#
# bl=178 pos[1]=[12.1 3.3 2.1] dr=0.96 t=0.0ps kin=1.52 pot=19.91 Rg=11.016 SPS=2693
# chr10 loop
# ---
#
# bl=179 pos[1]=[13.3 2.6 4.1] dr=0.95 t=0.0ps kin=1.49 pot=19.92 Rg=10.994 SPS=2485
# chr10 loop
# ---
#
# bl=180 pos[1]=[13.2 1.4 3.3] dr=0.97 t=0.0ps kin=1.51 pot=19.89 Rg=10.987 SPS=2586
# chr10 loop
# ---
#
# bl=181 pos[1]=[13.6 2.2 2.9] dr=1.00 t=0.0ps kin=1.49 pot=19.89 Rg=10.952 SPS=2547
# chr10 loop
# ---
#
# bl=182 pos[1]=[11.3 1.8 2.8] dr=0.94 t=0.0ps kin=1.48 pot=19.89 Rg=10.922 SPS=2559
# chr10 loop
# ---
#
# bl=183 pos[1]=[11.0 1.8 3.4] dr=0.94 t=0.0ps kin=1.54 pot=19.89 Rg=10.883 SPS=2616
# chr10 loop
# ---
#
# bl=184 pos[1]=[9.3 2.1 4.1] dr=0.98 t=0.0ps kin=1.49 pot=19.92 Rg=10.854 SPS=2652
# chr10 loop
# ---
#
# bl=185 pos[1]=[9.4 1.5 3.5] dr=0.97 t=0.0ps kin=1.52 pot=19.91 Rg=10.835 SPS=2621
# chr10 loop
# ---
#
# bl=186 pos[1]=[10.1 1.5 3.1] dr=1.00 t=0.0ps kin=1.52 pot=19.89 Rg=10.787 SPS=2795
# chr10 loop
# ---
#
# bl=187 pos[1]=[10.4 2.4 2.5] dr=0.99 t=0.0ps kin=1.50 pot=19.87 Rg=10.768 SPS=2832
# chr10 loop
# ---
#
# bl=188 pos[1]=[10.9 3.6 1.5] dr=0.94 t=0.0ps kin=1.50 pot=19.87 Rg=10.760 SPS=2860
# chr10 loop
# ---
#
# bl=189 pos[1]=[11.1 3.7 2.3] dr=0.94 t=0.0ps kin=1.47 pot=19.87 Rg=10.767 SPS=2930
# chr10 loop
# ---
#
# bl=190 pos[1]=[11.6 5.7 5.0] dr=0.95 t=0.0ps kin=1.45 pot=19.90 Rg=10.756 SPS=2797
# chr10 loop
# ---
#
# bl=191 pos[1]=[10.5 3.3 5.9] dr=0.96 t=0.0ps kin=1.49 pot=19.87 Rg=10.736 SPS=2893
# chr10 loop
# ---
#
# bl=192 pos[1]=[10.7 2.6 4.8] dr=0.95 t=0.0ps kin=1.52 pot=19.86 Rg=10.712 SPS=2687
# chr10 loop
# ---
#
# bl=193 pos[1]=[12.2 2.1 4.5] dr=0.97 t=0.0ps kin=1.51 pot=19.90 Rg=10.685 SPS=2798
# chr10 loop
# ---
#
# bl=194 pos[1]=[11.7 1.2 4.6] dr=0.97 t=0.0ps kin=1.50 pot=19.91 Rg=10.665 SPS=2810
# chr10 loop
# ---
#
# bl=195 pos[1]=[11.4 0.7 4.8] dr=0.97 t=0.0ps kin=1.53 pot=19.87 Rg=10.646 SPS=2600
# chr10 loop
# ---
#
# bl=196 pos[1]=[10.5 1.4 6.6] dr=0.96 t=0.0ps kin=1.52 pot=19.88 Rg=10.664 SPS=2570
# chr10 loop
# ---
#
# bl=197 pos[1]=[10.1 0.9 6.1] dr=0.96 t=0.0ps kin=1.51 pot=19.89 Rg=10.610 SPS=2950
# chr10 loop
# ---
#
# bl=198 pos[1]=[10.2 1.1 6.0] dr=0.98 t=0.0ps kin=1.53 pot=19.90 Rg=10.522 SPS=2934
# chr10 loop
# ---
#
# bl=199 pos[1]=[9.4 1.3 6.5] dr=0.97 t=0.0ps kin=1.48 pot=19.90 Rg=10.458 SPS=2619
# chr10 loop
# ---
#
#
# Statistics for the simulation chr10, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-1.34743955  0.50118171 -0.22170684]   Rg =  10.458171
#      median bond size is  0.9632817626860511
#      three shortest/longest (<10)/ bonds are  [0.88029494 0.88200787 0.88333011]    [1.09646473 1.09715321 1.11722926]
#      95 percentile of distance to center is:    14.195480650791835
#      density of closest 95% monomers is:    0.21501778068928137
#      density of the core monomers is:    0.19320650305042525
#      min/median/mean/max coordinates are:
#      x: -14.53, -2.05, -1.35, 13.29
#      y: -15.86, 1.76, 0.50, 14.69
#      z: -7.89, -0.23, -0.22, 6.51
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4846099366751255 should be: 1.5
#      fastest particles are (in kT):  [7.01693364 7.0613953  7.44625031 7.80445086 8.60819101]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.896588080752213
# bl=200 pos[1]=[9.9 0.5 6.9] dr=0.96 t=0.0ps kin=1.55 pot=19.85 Rg=10.394 SPS=2775
# chr10 loop
# ---
#
# bl=201 pos[1]=[10.4 1.1 5.7] dr=0.95 t=0.0ps kin=1.50 pot=19.90 Rg=10.374 SPS=2628
# chr10 loop
# ---
#
# bl=202 pos[1]=[10.2 1.0 5.1] dr=0.97 t=0.0ps kin=1.53 pot=19.88 Rg=10.377 SPS=2575
# chr10 loop
# ---
#
# bl=203 pos[1]=[9.9 2.0 6.8] dr=0.96 t=0.0ps kin=1.49 pot=19.92 Rg=10.334 SPS=2618
# chr10 loop
# ---
#
# bl=204 pos[1]=[10.3 0.5 6.1] dr=0.98 t=0.0ps kin=1.49 pot=19.91 Rg=10.282 SPS=2735
# chr10 loop
# ---
#
# bl=205 pos[1]=[10.6 0.7 6.2] dr=0.97 t=0.0ps kin=1.49 pot=19.89 Rg=10.204 SPS=2751
# chr10 loop
# ---
#
# bl=206 pos[1]=[10.6 2.0 4.7] dr=0.96 t=0.0ps kin=1.50 pot=19.87 Rg=10.135 SPS=2766
# chr10 loop
# ---
#
# bl=207 pos[1]=[9.8 3.6 5.1] dr=0.95 t=0.0ps kin=1.49 pot=19.89 Rg=10.117 SPS=2894
# chr10 loop
# ---
#
# bl=208 pos[1]=[10.6 3.4 4.8] dr=0.96 t=0.0ps kin=1.45 pot=19.91 Rg=10.092 SPS=2807
# chr10 loop
# ---
#
# bl=209 pos[1]=[10.2 3.0 5.0] dr=0.95 t=0.0ps kin=1.48 pot=19.86 Rg=10.024 SPS=2819
# chr10 loop
# ---
#
# bl=210 pos[1]=[9.6 2.3 6.5] dr=0.94 t=0.0ps kin=1.50 pot=19.86 Rg=9.961 SPS=2717
# chr10 loop
# ---
#
# bl=211 pos[1]=[9.9 1.8 6.0] dr=0.95 t=0.0ps kin=1.49 pot=19.87 Rg=9.885 SPS=2774
# chr10 loop
# ---
#
# bl=212 pos[1]=[9.0 2.8 5.0] dr=0.95 t=0.0ps kin=1.52 pot=19.84 Rg=9.821 SPS=2878
# chr10 loop
# ---
#
# bl=213 pos[1]=[7.8 2.7 4.9] dr=0.95 t=0.0ps kin=1.48 pot=19.87 Rg=9.767 SPS=2756
# chr10 loop
# ---
#
# bl=214 pos[1]=[8.3 2.7 4.9] dr=0.97 t=0.0ps kin=1.50 pot=19.89 Rg=9.709 SPS=2795
# chr10 loop
# ---
#
# bl=215 pos[1]=[10.1 2.6 4.4] dr=0.95 t=0.0ps kin=1.54 pot=19.86 Rg=9.682 SPS=2788
# chr10 loop
# ---
#
# bl=216 pos[1]=[10.7 1.5 2.9] dr=0.96 t=0.0ps kin=1.48 pot=19.88 Rg=9.655 SPS=2784
# chr10 loop
# ---
#
# bl=217 pos[1]=[10.1 1.2 4.4] dr=0.98 t=0.0ps kin=1.52 pot=19.81 Rg=9.597 SPS=2841
# chr10 loop
# ---
#
# bl=218 pos[1]=[9.1 1.6 5.0] dr=0.98 t=0.0ps kin=1.51 pot=19.85 Rg=9.553 SPS=2889
# chr10 loop
# ---
#
# bl=219 pos[1]=[7.5 2.1 3.9] dr=0.97 t=0.0ps kin=1.49 pot=19.89 Rg=9.539 SPS=2725
# chr10 loop
# ---
#
# bl=220 pos[1]=[7.6 2.9 4.0] dr=0.95 t=0.0ps kin=1.53 pot=19.91 Rg=9.489 SPS=2884
# chr10 loop
# ---
#
# bl=221 pos[1]=[7.4 0.7 4.7] dr=0.98 t=0.0ps kin=1.51 pot=19.92 Rg=9.433 SPS=2758
# chr10 loop
# ---
#
# bl=222 pos[1]=[6.4 0.3 5.4] dr=0.99 t=0.0ps kin=1.51 pot=19.94 Rg=9.410 SPS=2866
# chr10 loop
# ---
#
# bl=223 pos[1]=[6.9 -0.6 5.8] dr=0.98 t=0.0ps kin=1.55 pot=19.94 Rg=9.395 SPS=2712
# chr10 loop
# ---
#
# bl=224 pos[1]=[6.3 1.1 5.6] dr=0.98 t=0.0ps kin=1.57 pot=19.95 Rg=9.381 SPS=2885
# chr10 loop
# ---
#
# bl=225 pos[1]=[5.4 1.9 6.0] dr=0.99 t=0.0ps kin=1.55 pot=19.96 Rg=9.395 SPS=2892
# chr10 loop
# ---
#
# bl=226 pos[1]=[5.7 2.2 5.3] dr=0.97 t=0.0ps kin=1.56 pot=19.90 Rg=9.372 SPS=2740
# chr10 loop
# ---
#
# bl=227 pos[1]=[5.1 3.3 4.9] dr=0.98 t=0.0ps kin=1.52 pot=19.89 Rg=9.343 SPS=2779
# chr10 loop
# ---
#
# bl=228 pos[1]=[6.6 2.8 4.8] dr=0.97 t=0.0ps kin=1.48 pot=19.90 Rg=9.333 SPS=2883
# chr10 loop
# ---
#
# bl=229 pos[1]=[5.5 2.3 5.2] dr=0.95 t=0.0ps kin=1.52 pot=19.82 Rg=9.346 SPS=2784
# chr10 loop
# ---
#
# bl=230 pos[1]=[5.2 2.7 4.8] dr=0.95 t=0.0ps kin=1.49 pot=19.85 Rg=9.358 SPS=2585
# chr10 loop
# ---
#
# bl=231 pos[1]=[6.4 1.9 5.2] dr=0.97 t=0.0ps kin=1.52 pot=19.83 Rg=9.359 SPS=2937
# chr10 loop
# ---
#
# bl=232 pos[1]=[8.4 3.1 4.5] dr=0.96 t=0.0ps kin=1.49 pot=19.85 Rg=9.333 SPS=2790
# chr10 loop
# ---
#
# bl=233 pos[1]=[7.9 3.7 3.8] dr=0.94 t=0.0ps kin=1.49 pot=19.81 Rg=9.266 SPS=2694
# chr10 loop
# ---
#
# bl=234 pos[1]=[8.5 3.4 2.2] dr=0.95 t=0.0ps kin=1.44 pot=19.84 Rg=9.177 SPS=2855
# chr10 loop
# ---
#
# bl=235 pos[1]=[8.7 3.7 1.8] dr=0.93 t=0.0ps kin=1.46 pot=19.82 Rg=9.114 SPS=2860
# chr10 loop
# ---
#
# bl=236 pos[1]=[8.0 3.5 2.1] dr=0.97 t=0.0ps kin=1.47 pot=19.82 Rg=9.037 SPS=2899
# chr10 loop
# ---
#
# bl=237 pos[1]=[8.0 3.2 3.3] dr=0.96 t=0.0ps kin=1.47 pot=19.79 Rg=8.978 SPS=2847
# chr10 loop
# ---
#
# bl=238 pos[1]=[7.4 1.5 5.0] dr=0.97 t=0.0ps kin=1.45 pot=19.81 Rg=8.934 SPS=2768
# chr10 loop
# ---
#
# bl=239 pos[1]=[8.1 1.1 3.2] dr=0.95 t=0.0ps kin=1.47 pot=19.82 Rg=8.872 SPS=2886
# chr10 loop
# ---
#
# bl=240 pos[1]=[6.5 0.7 3.9] dr=0.94 t=0.0ps kin=1.47 pot=19.88 Rg=8.812 SPS=2886
# chr10 loop
# ---
#
# bl=241 pos[1]=[7.2 -0.0 4.5] dr=0.95 t=0.0ps kin=1.53 pot=19.81 Rg=8.788 SPS=2776
# chr10 loop
# ---
#
# bl=242 pos[1]=[8.0 0.3 5.5] dr=0.96 t=0.0ps kin=1.51 pot=19.83 Rg=8.803 SPS=2738
# chr10 loop
# ---
#
# bl=243 pos[1]=[8.1 -0.4 4.7] dr=0.94 t=0.0ps kin=1.52 pot=19.84 Rg=8.793 SPS=2749
# chr10 loop
# ---
#
# bl=244 pos[1]=[7.2 -0.4 3.1] dr=0.96 t=0.0ps kin=1.51 pot=19.85 Rg=8.722 SPS=2813
# chr10 loop
# ---
#
# bl=245 pos[1]=[7.3 0.4 3.5] dr=0.94 t=0.0ps kin=1.46 pot=19.83 Rg=8.670 SPS=2907
# chr10 loop
# ---
#
# bl=246 pos[1]=[7.5 -0.4 5.2] dr=0.94 t=0.0ps kin=1.49 pot=19.81 Rg=8.647 SPS=2901
# chr10 loop
# ---
#
# bl=247 pos[1]=[7.8 0.5 4.0] dr=0.95 t=0.0ps kin=1.50 pot=19.78 Rg=8.600 SPS=2924
# chr10 loop
# ---
#
# bl=248 pos[1]=[7.0 -0.8 3.6] dr=0.93 t=0.0ps kin=1.47 pot=19.81 Rg=8.547 SPS=2898
# chr10 loop
# ---
#
# bl=249 pos[1]=[5.7 -0.8 3.3] dr=0.95 t=0.0ps kin=1.55 pot=19.76 Rg=8.553 SPS=2831
# chr10 loop
# ---
#
#
# Statistics for the simulation chr10, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-1.03259638 -0.30829191 -0.03734931]   Rg =  8.553095
#      median bond size is  0.963857519389631
#      three shortest/longest (<10)/ bonds are  [0.87348563 0.8739704  0.8802314 ]    [1.08000727 1.083505   1.08889493]
#      95 percentile of distance to center is:    11.950228605698852
#      density of closest 95% monomers is:    0.3604093433050984
#      density of the core monomers is:    0.7125165618836495
#      min/median/mean/max coordinates are:
#      x: -11.82, -1.09, -1.03, 11.05
#      y: -15.15, -0.14, -0.31, 12.66
#      z: -8.11, -0.11, -0.04, 7.90
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5524052396781385 should be: 1.5
#      fastest particles are (in kT):  [ 8.48056526  8.89547727  9.38789022  9.70610888 10.87645889]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.75641103198746
# bl=250 pos[1]=[4.5 -0.1 3.9] dr=0.96 t=0.0ps kin=1.50 pot=19.84 Rg=8.573 SPS=2878
# chr10 loop
# ---
#
# bl=251 pos[1]=[5.7 -0.2 3.7] dr=0.97 t=0.0ps kin=1.47 pot=19.84 Rg=8.574 SPS=2877
# chr10 loop
# ---
#
# bl=252 pos[1]=[5.3 -0.9 3.0] dr=0.96 t=0.0ps kin=1.52 pot=19.80 Rg=8.518 SPS=2883
# chr10 loop
# ---
#
# bl=253 pos[1]=[5.4 -0.8 2.9] dr=0.94 t=0.0ps kin=1.50 pot=19.84 Rg=8.488 SPS=2806
# chr10 loop
# ---
#
# bl=254 pos[1]=[3.7 -1.1 2.8] dr=0.94 t=0.0ps kin=1.52 pot=19.82 Rg=8.463 SPS=2828
# chr10 loop
# ---
#
# bl=255 pos[1]=[4.6 -0.9 2.7] dr=0.95 t=0.0ps kin=1.50 pot=19.83 Rg=8.485 SPS=2898
# chr10 loop
# ---
#
# bl=256 pos[1]=[4.7 -0.7 3.3] dr=0.97 t=0.0ps kin=1.48 pot=19.81 Rg=8.490 SPS=2970
# chr10 loop
# ---
#
# bl=257 pos[1]=[5.5 -1.5 2.7] dr=0.96 t=0.0ps kin=1.49 pot=19.78 Rg=8.458 SPS=2892
# chr10 loop
# ---
#
# bl=258 pos[1]=[5.9 -1.4 3.4] dr=0.96 t=0.0ps kin=1.52 pot=19.80 Rg=8.447 SPS=2822
# chr10 loop
# ---
#
# bl=259 pos[1]=[3.9 -1.3 3.5] dr=0.97 t=0.0ps kin=1.52 pot=19.81 Rg=8.429 SPS=2854
# chr10 loop
# ---
#
# bl=260 pos[1]=[4.8 -0.9 4.1] dr=0.95 t=0.0ps kin=1.51 pot=19.83 Rg=8.418 SPS=2610
# chr10 loop
# ---
#
# bl=261 pos[1]=[4.3 0.0 4.5] dr=0.96 t=0.0ps kin=1.52 pot=19.81 Rg=8.429 SPS=2801
# chr10 loop
# ---
#
# bl=262 pos[1]=[5.5 -0.5 4.3] dr=0.93 t=0.0ps kin=1.51 pot=19.79 Rg=8.430 SPS=2601
# chr10 loop
# ---
#
# bl=263 pos[1]=[5.0 -1.1 4.4] dr=0.92 t=0.0ps kin=1.53 pot=19.78 Rg=8.417 SPS=2493
# chr10 loop
# ---
#
# bl=264 pos[1]=[5.4 0.0 4.9] dr=0.95 t=0.0ps kin=1.50 pot=19.81 Rg=8.421 SPS=2871
# chr10 loop
# ---
#
# bl=265 pos[1]=[6.9 0.9 4.3] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=8.411 SPS=2791
# chr10 loop
# ---
#
# bl=266 pos[1]=[6.6 -0.2 5.4] dr=0.92 t=0.0ps kin=1.49 pot=19.79 Rg=8.376 SPS=2832
# chr10 loop
# ---
#
# bl=267 pos[1]=[5.0 -0.1 6.1] dr=0.95 t=0.0ps kin=1.51 pot=19.79 Rg=8.376 SPS=2726
# chr10 loop
# ---
#
# bl=268 pos[1]=[5.3 -0.3 5.5] dr=0.94 t=0.0ps kin=1.51 pot=19.79 Rg=8.384 SPS=2881
# chr10 loop
# ---
#
# bl=269 pos[1]=[5.5 -0.3 6.0] dr=0.94 t=0.0ps kin=1.47 pot=19.83 Rg=8.401 SPS=2660
# chr10 loop
# ---
#
# bl=270 pos[1]=[4.9 -0.3 5.5] dr=0.96 t=0.0ps kin=1.48 pot=19.77 Rg=8.395 SPS=2721
# chr10 loop
# ---
#
# bl=271 pos[1]=[5.2 -0.2 4.3] dr=0.92 t=0.0ps kin=1.47 pot=19.79 Rg=8.390 SPS=2865
# chr10 loop
# ---
#
# bl=272 pos[1]=[5.9 -0.3 3.8] dr=0.94 t=0.0ps kin=1.48 pot=19.78 Rg=8.388 SPS=2851
# chr10 loop
# ---
#
# bl=273 pos[1]=[5.1 0.8 4.4] dr=0.93 t=0.0ps kin=1.49 pot=19.77 Rg=8.359 SPS=2854
# chr10 loop
# ---
#
# bl=274 pos[1]=[5.3 0.3 6.1] dr=0.95 t=0.0ps kin=1.50 pot=19.80 Rg=8.361 SPS=2865
# chr10 loop
# ---
#
# bl=275 pos[1]=[4.3 -1.0 6.5] dr=0.95 t=0.0ps kin=1.50 pot=19.80 Rg=8.364 SPS=2878
# chr10 loop
# ---
#
# bl=276 pos[1]=[4.9 -2.1 5.2] dr=0.94 t=0.0ps kin=1.50 pot=19.80 Rg=8.413 SPS=2803
# chr10 loop
# ---
#
# bl=277 pos[1]=[4.3 -1.4 7.0] dr=0.95 t=0.0ps kin=1.50 pot=19.81 Rg=8.419 SPS=2793
# chr10 loop
# ---
#
# bl=278 pos[1]=[3.8 -1.0 7.1] dr=0.94 t=0.0ps kin=1.51 pot=19.81 Rg=8.441 SPS=2795
# chr10 loop
# ---
#
# bl=279 pos[1]=[3.2 -0.3 6.7] dr=0.95 t=0.0ps kin=1.55 pot=19.81 Rg=8.460 SPS=2947
# chr10 loop
# ---
#
# bl=280 pos[1]=[2.9 -1.5 7.4] dr=0.95 t=0.0ps kin=1.51 pot=19.86 Rg=8.474 SPS=2827
# chr10 loop
# ---
#
# bl=281 pos[1]=[3.6 -2.0 6.6] dr=0.94 t=0.0ps kin=1.50 pot=19.82 Rg=8.480 SPS=2816
# chr10 loop
# ---
#
# bl=282 pos[1]=[5.1 -1.2 5.3] dr=0.92 t=0.0ps kin=1.50 pot=19.75 Rg=8.507 SPS=2855
# chr10 loop
# ---
#
# bl=283 pos[1]=[5.7 -1.9 6.1] dr=0.96 t=0.0ps kin=1.46 pot=19.79 Rg=8.490 SPS=2898
# chr10 loop
# ---
#
# bl=284 pos[1]=[4.4 -1.5 7.0] dr=0.93 t=0.0ps kin=1.50 pot=19.77 Rg=8.433 SPS=2865
# chr10 loop
# ---
#
# bl=285 pos[1]=[2.9 -1.6 6.5] dr=0.94 t=0.0ps kin=1.48 pot=19.76 Rg=8.397 SPS=2695
# chr10 loop
# ---
#
# bl=286 pos[1]=[3.0 -2.8 6.6] dr=0.94 t=0.0ps kin=1.47 pot=19.76 Rg=8.340 SPS=2729
# chr10 loop
# ---
#
# bl=287 pos[1]=[3.0 -3.6 6.1] dr=0.94 t=0.0ps kin=1.49 pot=19.76 Rg=8.277 SPS=2865
# chr10 loop
# ---
#
# bl=288 pos[1]=[4.8 -2.2 6.1] dr=0.94 t=0.0ps kin=1.52 pot=19.78 Rg=8.236 SPS=2771
# chr10 loop
# ---
#
# bl=289 pos[1]=[4.0 -1.1 4.5] dr=0.93 t=0.0ps kin=1.49 pot=19.79 Rg=8.227 SPS=2784
# chr10 loop
# ---
#
# bl=290 pos[1]=[3.5 -1.5 6.0] dr=0.93 t=0.0ps kin=1.48 pot=19.82 Rg=8.237 SPS=2915
# chr10 loop
# ---
#
# bl=291 pos[1]=[3.1 -2.3 5.5] dr=0.95 t=0.0ps kin=1.51 pot=19.77 Rg=8.194 SPS=2808
# chr10 loop
# ---
#
# bl=292 pos[1]=[4.8 -1.8 4.6] dr=0.93 t=0.0ps kin=1.46 pot=19.80 Rg=8.147 SPS=2845
# chr10 loop
# ---
#
# bl=293 pos[1]=[3.4 -3.2 4.8] dr=0.91 t=0.0ps kin=1.51 pot=19.77 Rg=8.147 SPS=2881
# chr10 loop
# ---
#
# bl=294 pos[1]=[3.6 -2.9 5.0] dr=0.91 t=0.0ps kin=1.46 pot=19.79 Rg=8.135 SPS=2810
# chr10 loop
# ---
#
# bl=295 pos[1]=[3.5 -2.4 5.5] dr=0.93 t=0.0ps kin=1.47 pot=19.74 Rg=8.167 SPS=2899
# chr10 loop
# ---
#
# bl=296 pos[1]=[2.5 -1.8 5.7] dr=0.90 t=0.0ps kin=1.51 pot=19.77 Rg=8.155 SPS=2862
# chr10 loop
# ---
#
# bl=297 pos[1]=[2.6 -2.9 5.2] dr=0.92 t=0.0ps kin=1.47 pot=19.76 Rg=8.158 SPS=2817
# chr10 loop
# ---
#
# bl=298 pos[1]=[2.4 -2.5 5.5] dr=0.94 t=0.0ps kin=1.50 pot=19.74 Rg=8.102 SPS=2646
# chr10 loop
# ---
#
# bl=299 pos[1]=[3.5 -3.5 5.8] dr=0.93 t=0.0ps kin=1.48 pot=19.73 Rg=8.044 SPS=2813
# chr10 loop
# ---
#
#
# Statistics for the simulation chr10, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-1.84044804 -0.61491789  0.3634407 ]   Rg =  8.044329
#      median bond size is  0.9633648440261227
#      three shortest/longest (<10)/ bonds are  [0.88100051 0.88146951 0.88335643]    [1.08379061 1.08778033 1.11516848]
#      95 percentile of distance to center is:    11.1880221153314
#      density of closest 95% monomers is:    0.439202428361928
#      density of the core monomers is:    0.7180031896959426
#      min/median/mean/max coordinates are:
#      x: -13.77, -1.79, -1.84, 9.13
#      y: -12.79, -0.38, -0.61, 9.99
#      z: -8.20, 0.35, 0.36, 9.78
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4833713903031416 should be: 1.5
#      fastest particles are (in kT):  [ 7.17354425  7.34817875  8.28258104  8.43014996 11.39158567]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.726458794247787
# bl=300 pos[1]=[3.6 -3.6 5.9] dr=0.92 t=0.0ps kin=1.44 pot=19.77 Rg=8.036 SPS=2742
# chr10 loop
# ---
#
# bl=301 pos[1]=[3.2 -3.5 5.1] dr=0.93 t=0.0ps kin=1.49 pot=19.78 Rg=8.019 SPS=2839
# chr10 loop
# ---
#
# bl=302 pos[1]=[2.7 -2.5 5.3] dr=0.94 t=0.0ps kin=1.47 pot=19.77 Rg=8.014 SPS=2933
# chr10 loop
# ---
#
# bl=303 pos[1]=[2.5 -2.5 5.2] dr=0.92 t=0.0ps kin=1.48 pot=19.76 Rg=8.043 SPS=2948
# chr10 loop
# ---
#
# bl=304 pos[1]=[3.6 -2.3 5.6] dr=0.93 t=0.0ps kin=1.48 pot=19.80 Rg=8.055 SPS=2900
# chr10 loop
# ---
#
# bl=305 pos[1]=[2.6 -3.2 5.5] dr=0.92 t=0.0ps kin=1.47 pot=19.77 Rg=8.060 SPS=2939
# chr10 loop
# ---
#
# bl=306 pos[1]=[2.8 -3.4 6.1] dr=0.92 t=0.0ps kin=1.48 pot=19.77 Rg=8.059 SPS=2866
# chr10 loop
# ---
#
# bl=307 pos[1]=[2.8 -3.0 6.0] dr=0.93 t=0.0ps kin=1.47 pot=19.81 Rg=8.062 SPS=2966
# chr10 loop
# ---
#
# bl=308 pos[1]=[3.4 -4.1 5.0] dr=0.95 t=0.0ps kin=1.52 pot=19.82 Rg=8.051 SPS=2747
# chr10 loop
# ---
#
# bl=309 pos[1]=[3.7 -3.6 5.1] dr=0.97 t=0.0ps kin=1.49 pot=19.82 Rg=8.064 SPS=2759
# chr10 loop
# ---
#
# bl=310 pos[1]=[2.5 -2.4 4.8] dr=0.95 t=0.0ps kin=1.48 pot=19.84 Rg=8.089 SPS=2776
# chr10 loop
# ---
#
# bl=311 pos[1]=[2.0 -2.8 5.2] dr=0.94 t=0.0ps kin=1.47 pot=19.82 Rg=8.122 SPS=2800
# chr10 loop
# ---
#
# bl=312 pos[1]=[2.4 -3.2 4.9] dr=0.93 t=0.0ps kin=1.49 pot=19.80 Rg=8.163 SPS=2789
# chr10 loop
# ---
#
# bl=313 pos[1]=[4.7 -2.5 4.0] dr=0.95 t=0.0ps kin=1.48 pot=19.78 Rg=8.157 SPS=2858
# chr10 loop
# ---
#
# bl=314 pos[1]=[5.5 -3.3 3.6] dr=0.95 t=0.0ps kin=1.49 pot=19.77 Rg=8.136 SPS=2761
# chr10 loop
# ---
#
# bl=315 pos[1]=[4.8 -4.3 3.2] dr=0.93 t=0.0ps kin=1.47 pot=19.82 Rg=8.141 SPS=2869
# chr10 loop
# ---
#
# bl=316 pos[1]=[5.0 -4.0 3.4] dr=0.94 t=0.0ps kin=1.53 pot=19.78 Rg=8.142 SPS=2865
# chr10 loop
# ---
#
# bl=317 pos[1]=[3.7 -2.9 3.1] dr=0.95 t=0.0ps kin=1.47 pot=19.78 Rg=8.115 SPS=2750
# chr10 loop
# ---
#
# bl=318 pos[1]=[3.5 -3.8 3.1] dr=0.94 t=0.0ps kin=1.49 pot=19.73 Rg=8.110 SPS=2678
# chr10 loop
# ---
#
# bl=319 pos[1]=[3.8 -3.9 2.9] dr=0.93 t=0.0ps kin=1.48 pot=19.77 Rg=8.103 SPS=2665
# chr10 loop
# ---
#
# bl=320 pos[1]=[4.2 -2.3 3.6] dr=0.94 t=0.0ps kin=1.50 pot=19.79 Rg=8.099 SPS=2766
# chr10 loop
# ---
#
# bl=321 pos[1]=[5.0 -3.2 3.7] dr=0.96 t=0.0ps kin=1.51 pot=19.82 Rg=8.146 SPS=2726
# chr10 loop
# ---
#
# bl=322 pos[1]=[4.1 -4.2 3.3] dr=0.96 t=0.0ps kin=1.50 pot=19.83 Rg=8.162 SPS=2715
# chr10 loop
# ---
#
# bl=323 pos[1]=[3.6 -4.2 4.1] dr=0.96 t=0.0ps kin=1.48 pot=19.83 Rg=8.162 SPS=2900
# chr10 loop
# ---
#
# bl=324 pos[1]=[4.1 -4.8 4.1] dr=0.95 t=0.0ps kin=1.49 pot=19.79 Rg=8.145 SPS=2774
# chr10 loop
# ---
#
# bl=325 pos[1]=[3.4 -4.7 5.6] dr=0.94 t=0.0ps kin=1.55 pot=19.77 Rg=8.126 SPS=2889
# chr10 loop
# ---
#
# bl=326 pos[1]=[3.6 -6.6 6.4] dr=0.95 t=0.0ps kin=1.47 pot=19.78 Rg=8.147 SPS=2830
# chr10 loop
# ---
#
# bl=327 pos[1]=[3.6 -7.9 5.5] dr=0.95 t=0.0ps kin=1.45 pot=19.79 Rg=8.165 SPS=2841
# chr10 loop
# ---
#
# bl=328 pos[1]=[1.7 -7.8 5.7] dr=0.93 t=0.0ps kin=1.53 pot=19.74 Rg=8.101 SPS=2800
# chr10 loop
# ---
#
# bl=329 pos[1]=[1.6 -4.6 6.6] dr=0.94 t=0.0ps kin=1.52 pot=19.79 Rg=8.061 SPS=2855
# chr10 loop
# ---
#
# bl=330 pos[1]=[0.5 -4.0 6.9] dr=0.94 t=0.0ps kin=1.51 pot=19.81 Rg=8.051 SPS=2957
# chr10 loop
# ---
#
# bl=331 pos[1]=[-2.4 -4.3 6.3] dr=0.96 t=0.0ps kin=1.49 pot=19.83 Rg=8.075 SPS=2850
# chr10 loop
# ---
#
# bl=332 pos[1]=[-2.4 -3.4 6.8] dr=0.94 t=0.0ps kin=1.48 pot=19.84 Rg=8.095 SPS=2886
# chr10 loop
# ---
#
# bl=333 pos[1]=[-2.5 -2.3 7.0] dr=0.94 t=0.0ps kin=1.50 pot=19.84 Rg=8.134 SPS=2908
# chr10 loop
# ---
#
# bl=334 pos[1]=[-1.7 -3.7 8.1] dr=0.97 t=0.0ps kin=1.53 pot=19.82 Rg=8.147 SPS=2691
# chr10 loop
# ---
#
# bl=335 pos[1]=[-1.1 -3.1 7.3] dr=0.95 t=0.0ps kin=1.50 pot=19.82 Rg=8.171 SPS=2958
# chr10 loop
# ---
#
# bl=336 pos[1]=[-0.9 -0.7 8.7] dr=0.94 t=0.0ps kin=1.48 pot=19.84 Rg=8.171 SPS=2895
# chr10 loop
# ---
#
# bl=337 pos[1]=[0.1 0.1 8.2] dr=0.94 t=0.0ps kin=1.50 pot=19.79 Rg=8.131 SPS=2727
# chr10 loop
# ---
#
# bl=338 pos[1]=[0.1 -0.7 8.3] dr=0.97 t=0.0ps kin=1.51 pot=19.76 Rg=8.108 SPS=2777
# chr10 loop
# ---
#
# bl=339 pos[1]=[2.3 -0.4 7.0] dr=0.97 t=0.0ps kin=1.47 pot=19.80 Rg=8.081 SPS=2793
# chr10 loop
# ---
#
# bl=340 pos[1]=[2.7 -1.1 6.1] dr=0.96 t=0.0ps kin=1.51 pot=19.76 Rg=8.090 SPS=2858
# chr10 loop
# ---
#
# bl=341 pos[1]=[3.8 -0.4 8.0] dr=0.95 t=0.0ps kin=1.48 pot=19.81 Rg=8.098 SPS=2911
# chr10 loop
# ---
#
# bl=342 pos[1]=[3.4 0.3 6.9] dr=0.95 t=0.0ps kin=1.48 pot=19.79 Rg=8.096 SPS=2867
# chr10 loop
# ---
#
# bl=343 pos[1]=[2.7 -0.5 6.7] dr=0.97 t=0.0ps kin=1.53 pot=19.75 Rg=8.071 SPS=2726
# chr10 loop
# ---
#
# bl=344 pos[1]=[1.1 -0.5 6.5] dr=0.95 t=0.0ps kin=1.48 pot=19.82 Rg=8.065 SPS=2910
# chr10 loop
# ---
#
# bl=345 pos[1]=[1.1 -0.0 6.2] dr=0.96 t=0.0ps kin=1.49 pot=19.77 Rg=8.062 SPS=2875
# chr10 loop
# ---
#
# bl=346 pos[1]=[3.0 0.4 6.1] dr=0.93 t=0.0ps kin=1.49 pot=19.78 Rg=8.070 SPS=2943
# chr10 loop
# ---
#
# bl=347 pos[1]=[1.6 0.9 5.8] dr=0.95 t=0.0ps kin=1.49 pot=19.74 Rg=8.051 SPS=2946
# chr10 loop
# ---
#
# bl=348 pos[1]=[1.4 1.2 4.5] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=8.040 SPS=2983
# chr10 loop
# ---
#
# bl=349 pos[1]=[2.5 0.5 4.2] dr=0.98 t=0.0ps kin=1.53 pot=19.79 Rg=8.047 SPS=2794
# chr10 loop
# ---
#
#
# Statistics for the simulation chr10, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-1.59676844 -0.64030455  0.20772063]   Rg =  8.0468025
#      median bond size is  0.9637668772642192
#      three shortest/longest (<10)/ bonds are  [0.87459273 0.88447686 0.88747453]    [1.10264788 1.10360349 1.11998471]
#      95 percentile of distance to center is:    11.275683724543393
#      density of closest 95% monomers is:    0.4290382614284729
#      density of the core monomers is:    0.6984070556140619
#      min/median/mean/max coordinates are:
#      x: -13.77, -1.40, -1.60, 9.63
#      y: -13.32, -0.69, -0.64, 11.04
#      z: -8.07, 0.17, 0.21, 9.02
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5290456196590656 should be: 1.5
#      fastest particles are (in kT):  [ 8.21160426  8.73629436  9.15779562  9.53139421 11.45272289]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.792908254977874
# bl=350 pos[1]=[2.6 0.6 3.7] dr=0.94 t=0.0ps kin=1.50 pot=19.82 Rg=8.079 SPS=2690
# chr10 loop
# ---
#
# bl=351 pos[1]=[1.5 0.7 3.7] dr=0.93 t=0.0ps kin=1.54 pot=19.78 Rg=8.099 SPS=2659
# chr10 loop
# ---
#
# bl=352 pos[1]=[1.4 0.5 4.4] dr=0.95 t=0.0ps kin=1.51 pot=19.84 Rg=8.077 SPS=2870
# chr10 loop
# ---
#
# bl=353 pos[1]=[1.4 0.3 4.7] dr=0.94 t=0.0ps kin=1.52 pot=19.83 Rg=8.082 SPS=2838
# chr10 loop
# ---
#
# bl=354 pos[1]=[0.4 0.7 4.8] dr=0.94 t=0.0ps kin=1.53 pot=19.82 Rg=8.097 SPS=2840
# chr10 loop
# ---
#
# bl=355 pos[1]=[1.4 1.2 3.2] dr=0.95 t=0.0ps kin=1.52 pot=19.80 Rg=8.103 SPS=2806
# chr10 loop
# ---
#
# bl=356 pos[1]=[1.8 1.7 3.7] dr=0.94 t=0.0ps kin=1.51 pot=19.82 Rg=8.108 SPS=2853
# chr10 loop
# ---
#
# bl=357 pos[1]=[0.6 1.3 3.6] dr=0.97 t=0.0ps kin=1.47 pot=19.82 Rg=8.073 SPS=2878
# chr10 loop
# ---
#
# bl=358 pos[1]=[0.2 1.2 3.0] dr=0.95 t=0.0ps kin=1.50 pot=19.78 Rg=8.048 SPS=2704
# chr10 loop
# ---
#
# bl=359 pos[1]=[0.9 0.1 2.8] dr=0.94 t=0.0ps kin=1.47 pot=19.81 Rg=8.025 SPS=2764
# chr10 loop
# ---
#
# bl=360 pos[1]=[0.6 -0.6 2.1] dr=0.92 t=0.0ps kin=1.53 pot=19.77 Rg=8.002 SPS=2763
# chr10 loop
# ---
#
# bl=361 pos[1]=[-0.3 -0.5 1.9] dr=0.94 t=0.0ps kin=1.48 pot=19.78 Rg=7.989 SPS=2801
# chr10 loop
# ---
#
# bl=362 pos[1]=[0.5 -0.3 2.4] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=7.958 SPS=2798
# chr10 loop
# ---
#
# bl=363 pos[1]=[0.8 0.0 2.6] dr=0.94 t=0.0ps kin=1.47 pot=19.77 Rg=7.961 SPS=2813
# chr10 loop
# ---
#
# bl=364 pos[1]=[0.2 -0.1 2.8] dr=0.92 t=0.0ps kin=1.48 pot=19.74 Rg=7.974 SPS=2668
# chr10 loop
# ---
#
# bl=365 pos[1]=[0.4 -1.0 2.2] dr=0.93 t=0.0ps kin=1.45 pot=19.74 Rg=7.985 SPS=2663
# chr10 loop
# ---
#
# bl=366 pos[1]=[0.2 -1.3 2.4] dr=0.92 t=0.0ps kin=1.49 pot=19.73 Rg=7.991 SPS=2800
# chr10 loop
# ---
#
# bl=367 pos[1]=[0.6 -1.3 3.2] dr=0.94 t=0.0ps kin=1.46 pot=19.77 Rg=7.986 SPS=2823
# chr10 loop
# ---
#
# bl=368 pos[1]=[0.8 -0.4 2.8] dr=0.96 t=0.0ps kin=1.50 pot=19.75 Rg=7.958 SPS=2714
# chr10 loop
# ---
#
# bl=369 pos[1]=[0.1 -0.6 2.9] dr=0.93 t=0.0ps kin=1.46 pot=19.78 Rg=7.964 SPS=2808
# chr10 loop
# ---
#
# bl=370 pos[1]=[0.3 -0.1 3.0] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=7.949 SPS=2871
# chr10 loop
# ---
#
# bl=371 pos[1]=[0.8 -0.1 3.0] dr=0.95 t=0.0ps kin=1.52 pot=19.75 Rg=7.951 SPS=2764
# chr10 loop
# ---
#
# bl=372 pos[1]=[1.5 -0.6 3.1] dr=0.94 t=0.0ps kin=1.51 pot=19.79 Rg=7.979 SPS=2778
# chr10 loop
# ---
#
# bl=373 pos[1]=[1.2 -0.2 3.4] dr=0.94 t=0.0ps kin=1.51 pot=19.81 Rg=7.984 SPS=2799
# chr10 loop
# ---
#
# bl=374 pos[1]=[1.8 -0.1 3.5] dr=0.95 t=0.0ps kin=1.54 pot=19.81 Rg=7.974 SPS=2833
# chr10 loop
# ---
#
# bl=375 pos[1]=[2.1 -0.4 3.0] dr=0.96 t=0.0ps kin=1.54 pot=19.81 Rg=7.965 SPS=2773
# chr10 loop
# ---
#
# bl=376 pos[1]=[2.4 0.4 3.4] dr=0.96 t=0.0ps kin=1.50 pot=19.82 Rg=7.949 SPS=2872
# chr10 loop
# ---
#
# ...
# chr10 loop
# ---
#
# bl=876 pos[1]=[6.7 1.4 8.6] dr=0.95 t=0.0ps kin=1.52 pot=19.79 Rg=7.737 SPS=2810
# chr10 loop
# ---
#
# bl=877 pos[1]=[6.9 0.2 9.6] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=7.750 SPS=2834
# chr10 loop
# ---
#
# bl=878 pos[1]=[6.4 1.2 8.8] dr=0.97 t=0.0ps kin=1.49 pot=19.81 Rg=7.763 SPS=2748
# chr10 loop
# ---
#
# bl=879 pos[1]=[6.5 1.4 9.9] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=7.719 SPS=2866
# chr10 loop
# ---
#
# bl=880 pos[1]=[6.6 -0.2 9.9] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=7.696 SPS=2770
# chr10 loop
# ---
#
# bl=881 pos[1]=[5.3 1.6 10.1] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=7.700 SPS=2806
# chr10 loop
# ---
#
# bl=882 pos[1]=[5.0 2.4 8.7] dr=0.96 t=0.0ps kin=1.50 pot=19.78 Rg=7.693 SPS=2812
# chr10 loop
# ---
#
# bl=883 pos[1]=[4.6 2.2 9.5] dr=0.93 t=0.0ps kin=1.45 pot=19.78 Rg=7.687 SPS=2860
# chr10 loop
# ---
#
# bl=884 pos[1]=[5.4 2.0 7.8] dr=0.92 t=0.0ps kin=1.47 pot=19.78 Rg=7.694 SPS=2805
# chr10 loop
# ---
#
# bl=885 pos[1]=[4.6 1.8 9.0] dr=0.94 t=0.0ps kin=1.50 pot=19.75 Rg=7.709 SPS=2747
# chr10 loop
# ---
#
# bl=886 pos[1]=[4.8 2.2 8.9] dr=0.94 t=0.0ps kin=1.54 pot=19.75 Rg=7.713 SPS=2847
# chr10 loop
# ---
#
# bl=887 pos[1]=[4.5 2.8 8.8] dr=0.93 t=0.0ps kin=1.50 pot=19.77 Rg=7.714 SPS=2886
# chr10 loop
# ---
#
# bl=888 pos[1]=[4.4 2.1 8.2] dr=0.95 t=0.0ps kin=1.50 pot=19.76 Rg=7.723 SPS=2795
# chr10 loop
# ---
#
# bl=889 pos[1]=[3.1 2.5 8.4] dr=0.96 t=0.0ps kin=1.52 pot=19.76 Rg=7.741 SPS=2875
# chr10 loop
# ---
#
# bl=890 pos[1]=[2.0 2.5 7.2] dr=0.94 t=0.0ps kin=1.52 pot=19.77 Rg=7.741 SPS=2754
# chr10 loop
# ---
#
# bl=891 pos[1]=[2.1 2.3 8.1] dr=0.94 t=0.0ps kin=1.52 pot=19.71 Rg=7.737 SPS=2754
# chr10 loop
# ---
#
# bl=892 pos[1]=[1.2 1.4 7.8] dr=0.97 t=0.0ps kin=1.49 pot=19.77 Rg=7.726 SPS=2706
# chr10 loop
# ---
#
# bl=893 pos[1]=[1.1 1.7 7.8] dr=0.93 t=0.0ps kin=1.50 pot=19.79 Rg=7.721 SPS=2766
# chr10 loop
# ---
#
# bl=894 pos[1]=[1.7 2.4 8.2] dr=0.95 t=0.0ps kin=1.51 pot=19.78 Rg=7.717 SPS=2778
# chr10 loop
# ---
#
# bl=895 pos[1]=[1.4 3.3 10.1] dr=0.94 t=0.0ps kin=1.50 pot=19.75 Rg=7.732 SPS=2759
# chr10 loop
# ---
#
# bl=896 pos[1]=[2.2 1.5 11.9] dr=0.95 t=0.0ps kin=1.51 pot=19.78 Rg=7.744 SPS=2787
# chr10 loop
# ---
#
# bl=897 pos[1]=[2.8 1.6 10.5] dr=0.94 t=0.0ps kin=1.48 pot=19.80 Rg=7.730 SPS=2754
# chr10 loop
# ---
#
# bl=898 pos[1]=[0.6 2.6 11.0] dr=0.93 t=0.0ps kin=1.51 pot=19.76 Rg=7.682 SPS=2845
# chr10 loop
# ---
#
# bl=899 pos[1]=[-1.1 1.7 10.4] dr=0.93 t=0.0ps kin=1.50 pot=19.80 Rg=7.657 SPS=2845
# chr10 loop
# ---
#
#
# Statistics for the simulation chr10, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.00887381 -0.79539951  1.19140102]   Rg =  7.6568346
#      median bond size is  0.9627192720588661
#      three shortest/longest (<10)/ bonds are  [0.86931954 0.87406731 0.87786985]    [1.07802111 1.08297189 1.10128991]
#      95 percentile of distance to center is:    10.423409518250875
#      density of closest 95% monomers is:    0.5431193535858494
#      density of the core monomers is:    0.7271842018369572
#      min/median/mean/max coordinates are:
#      x: -9.48, -0.22, -0.01, 11.21
#      y: -11.36, -0.76, -0.80, 10.17
#      z: -9.96, 1.17, 1.19, 11.12
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4980404727693364 should be: 1.5
#      fastest particles are (in kT):  [ 7.78266555  8.51299712  8.70385051  8.80637463 13.14263596]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.797871727507374
# bl=900 pos[1]=[-1.1 2.3 9.8] dr=0.93 t=0.0ps kin=1.48 pot=19.80 Rg=7.683 SPS=2711
# chr10 loop
# ---
#
# bl=901 pos[1]=[-1.0 2.3 10.4] dr=0.93 t=0.0ps kin=1.48 pot=19.79 Rg=7.714 SPS=2708
# chr10 loop
# ---
#
# bl=902 pos[1]=[-0.7 2.1 10.9] dr=0.91 t=0.0ps kin=1.48 pot=19.77 Rg=7.758 SPS=2808
# chr10 loop
# ---
#
# bl=903 pos[1]=[0.7 1.6 9.7] dr=0.94 t=0.0ps kin=1.51 pot=19.76 Rg=7.747 SPS=2735
# chr10 loop
# ---
#
# bl=904 pos[1]=[0.6 1.3 9.1] dr=0.93 t=0.0ps kin=1.51 pot=19.79 Rg=7.716 SPS=2637
# chr10 loop
# ---
#
# bl=905 pos[1]=[-0.5 0.5 8.2] dr=0.94 t=0.0ps kin=1.49 pot=19.80 Rg=7.696 SPS=2669
# chr10 loop
# ---
#
# bl=906 pos[1]=[-1.7 0.5 7.5] dr=0.93 t=0.0ps kin=1.48 pot=19.79 Rg=7.688 SPS=2668
# chr10 loop
# ---
#
# bl=907 pos[1]=[-1.7 0.0 8.0] dr=0.95 t=0.0ps kin=1.53 pot=19.74 Rg=7.690 SPS=2746
# chr10 loop
# ---
#
# bl=908 pos[1]=[-2.1 0.3 8.2] dr=0.92 t=0.0ps kin=1.45 pot=19.80 Rg=7.692 SPS=2647
# chr10 loop
# ---
#
# bl=909 pos[1]=[-2.2 1.0 8.0] dr=0.93 t=0.0ps kin=1.48 pot=19.77 Rg=7.663 SPS=2660
# chr10 loop
# ---
#
# bl=910 pos[1]=[-1.5 0.4 9.0] dr=0.95 t=0.0ps kin=1.48 pot=19.71 Rg=7.633 SPS=2570
# chr10 loop
# ---
#
# bl=911 pos[1]=[-1.7 0.8 9.2] dr=0.94 t=0.0ps kin=1.46 pot=19.74 Rg=7.666 SPS=2747
# chr10 loop
# ---
#
# bl=912 pos[1]=[-2.3 1.2 8.3] dr=0.92 t=0.0ps kin=1.46 pot=19.78 Rg=7.679 SPS=2770
# chr10 loop
# ---
#
# bl=913 pos[1]=[-2.5 0.8 7.2] dr=0.90 t=0.0ps kin=1.50 pot=19.77 Rg=7.677 SPS=2724
# chr10 loop
# ---
#
# bl=914 pos[1]=[-2.6 0.0 7.2] dr=0.94 t=0.0ps kin=1.50 pot=19.80 Rg=7.699 SPS=2727
# chr10 loop
# ---
#
# bl=915 pos[1]=[-3.3 0.9 7.2] dr=0.95 t=0.0ps kin=1.51 pot=19.80 Rg=7.761 SPS=2720
# chr10 loop
# ---
#
# bl=916 pos[1]=[-1.5 0.2 7.7] dr=0.94 t=0.0ps kin=1.49 pot=19.82 Rg=7.784 SPS=2742
# chr10 loop
# ---
#
# bl=917 pos[1]=[-2.2 0.6 7.3] dr=0.95 t=0.0ps kin=1.53 pot=19.80 Rg=7.728 SPS=2733
# chr10 loop
# ---
#
# bl=918 pos[1]=[-2.2 -0.1 7.8] dr=0.96 t=0.0ps kin=1.49 pot=19.80 Rg=7.712 SPS=2661
# chr10 loop
# ---
#
# bl=919 pos[1]=[-2.3 -0.9 6.9] dr=0.93 t=0.0ps kin=1.50 pot=19.80 Rg=7.717 SPS=2631
# chr10 loop
# ---
#
# bl=920 pos[1]=[-2.0 -0.5 7.3] dr=0.93 t=0.0ps kin=1.44 pot=19.81 Rg=7.737 SPS=2766
# chr10 loop
# ---
#
# bl=921 pos[1]=[-2.6 -0.6 7.4] dr=0.95 t=0.0ps kin=1.50 pot=19.79 Rg=7.739 SPS=2668
# chr10 loop
# ---
#
# bl=922 pos[1]=[-2.3 -0.5 7.3] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=7.729 SPS=2754
# chr10 loop
# ---
#
# bl=923 pos[1]=[-2.4 -1.2 8.1] dr=0.95 t=0.0ps kin=1.52 pot=19.74 Rg=7.673 SPS=2686
# chr10 loop
# ---
#
# bl=924 pos[1]=[-2.7 -0.5 8.5] dr=0.96 t=0.0ps kin=1.51 pot=19.79 Rg=7.673 SPS=2718
# chr10 loop
# ---
#
# bl=925 pos[1]=[-2.1 0.4 8.0] dr=0.95 t=0.0ps kin=1.51 pot=19.74 Rg=7.698 SPS=2672
# chr10 loop
# ---
#
# bl=926 pos[1]=[-2.3 0.5 7.7] dr=0.95 t=0.0ps kin=1.45 pot=19.79 Rg=7.722 SPS=2851
# chr10 loop
# ---
#
# bl=927 pos[1]=[-2.4 0.1 7.3] dr=0.93 t=0.0ps kin=1.46 pot=19.77 Rg=7.728 SPS=2655
# chr10 loop
# ---
#
# bl=928 pos[1]=[-2.2 0.6 6.4] dr=0.94 t=0.0ps kin=1.50 pot=19.77 Rg=7.707 SPS=2845
# chr10 loop
# ---
#
# bl=929 pos[1]=[-2.3 0.9 6.6] dr=0.93 t=0.0ps kin=1.52 pot=19.74 Rg=7.718 SPS=2804
# chr10 loop
# ---
#
# bl=930 pos[1]=[-2.0 1.3 7.3] dr=0.92 t=0.0ps kin=1.49 pot=19.79 Rg=7.735 SPS=2722
# chr10 loop
# ---
#
# bl=931 pos[1]=[-2.3 1.1 7.1] dr=0.92 t=0.0ps kin=1.47 pot=19.79 Rg=7.720 SPS=2742
# chr10 loop
# ---
#
# bl=932 pos[1]=[-1.3 0.3 8.1] dr=0.94 t=0.0ps kin=1.48 pot=19.79 Rg=7.703 SPS=2671
# chr10 loop
# ---
#
# bl=933 pos[1]=[-1.3 0.2 7.8] dr=0.94 t=0.0ps kin=1.50 pot=19.75 Rg=7.724 SPS=2805
# chr10 loop
# ---
#
# bl=934 pos[1]=[-2.0 -0.6 8.0] dr=0.94 t=0.0ps kin=1.51 pot=19.76 Rg=7.715 SPS=2890
# chr10 loop
# ---
#
# bl=935 pos[1]=[-2.0 -1.1 9.2] dr=0.94 t=0.0ps kin=1.49 pot=19.79 Rg=7.684 SPS=2829
# chr10 loop
# ---
#
# bl=936 pos[1]=[-0.5 -1.9 9.4] dr=0.93 t=0.0ps kin=1.48 pot=19.79 Rg=7.701 SPS=2783
# chr10 loop
# ---
#
# bl=937 pos[1]=[-0.8 -2.3 9.0] dr=0.93 t=0.0ps kin=1.51 pot=19.78 Rg=7.718 SPS=2742
# chr10 loop
# ---
#
# bl=938 pos[1]=[-1.4 -1.8 9.0] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=7.706 SPS=2619
# chr10 loop
# ---
#
# bl=939 pos[1]=[-1.7 -2.1 9.1] dr=0.93 t=0.0ps kin=1.51 pot=19.76 Rg=7.686 SPS=2850
# chr10 loop
# ---
#
# bl=940 pos[1]=[-1.5 -2.4 8.6] dr=0.94 t=0.0ps kin=1.50 pot=19.77 Rg=7.720 SPS=2753
# chr10 loop
# ---
#
# bl=941 pos[1]=[-1.3 -2.4 7.9] dr=0.94 t=0.0ps kin=1.47 pot=19.78 Rg=7.786 SPS=2796
# chr10 loop
# ---
#
# bl=942 pos[1]=[-1.5 -3.0 9.0] dr=0.91 t=0.0ps kin=1.47 pot=19.79 Rg=7.795 SPS=2814
# chr10 loop
# ---
#
# bl=943 pos[1]=[-2.9 -2.0 8.0] dr=0.94 t=0.0ps kin=1.48 pot=19.76 Rg=7.785 SPS=2742
# chr10 loop
# ---
#
# bl=944 pos[1]=[-3.8 -1.1 8.4] dr=0.91 t=0.0ps kin=1.50 pot=19.74 Rg=7.753 SPS=2756
# chr10 loop
# ---
#
# bl=945 pos[1]=[-2.9 -1.6 8.3] dr=0.92 t=0.0ps kin=1.51 pot=19.74 Rg=7.768 SPS=2773
# chr10 loop
# ---
#
# bl=946 pos[1]=[-1.7 -1.5 8.2] dr=0.95 t=0.0ps kin=1.49 pot=19.78 Rg=7.787 SPS=2760
# chr10 loop
# ---
#
# bl=947 pos[1]=[-0.9 -0.3 9.1] dr=0.95 t=0.0ps kin=1.48 pot=19.77 Rg=7.813 SPS=2597
# chr10 loop
# ---
#
# bl=948 pos[1]=[-0.2 1.4 8.8] dr=0.94 t=0.0ps kin=1.47 pot=19.76 Rg=7.829 SPS=2686
# chr10 loop
# ---
#
# bl=949 pos[1]=[-0.5 -0.4 10.0] dr=0.96 t=0.0ps kin=1.47 pot=19.78 Rg=7.826 SPS=2754
# chr10 loop
# ---
#
#
# Statistics for the simulation chr10, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 0.16877289 -0.60978602  0.76999042]   Rg =  7.8257384
#      median bond size is  0.9645081137188658
#      three shortest/longest (<10)/ bonds are  [0.87463631 0.87489782 0.8758922 ]    [1.09113027 1.09241971 1.1030164 ]
#      95 percentile of distance to center is:    10.647071004106671
#      density of closest 95% monomers is:    0.509605645060301
#      density of the core monomers is:    0.7003943092627851
#      min/median/mean/max coordinates are:
#      x: -10.92, 0.10, 0.17, 12.56
#      y: -13.22, -0.64, -0.61, 10.69
#      z: -8.61, 0.61, 0.77, 10.00
#
# Statistics for velocities:
#      mean kinetic energy is:  1.470914898997359 should be: 1.5
#      fastest particles are (in kT):  [7.92657344 7.94811597 8.31709883 9.28416527 9.57204163]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.783897377396755
# bl=950 pos[1]=[-0.2 -0.8 8.8] dr=0.94 t=0.0ps kin=1.47 pot=19.76 Rg=7.809 SPS=2595
# chr10 loop
# ---
#
# bl=951 pos[1]=[0.9 -1.2 9.9] dr=0.92 t=0.0ps kin=1.54 pot=19.72 Rg=7.775 SPS=2626
# chr10 loop
# ---
#
# bl=952 pos[1]=[0.9 -1.5 8.2] dr=0.93 t=0.0ps kin=1.46 pot=19.75 Rg=7.768 SPS=2644
# chr10 loop
# ---
#
# bl=953 pos[1]=[0.5 -1.2 8.3] dr=0.93 t=0.0ps kin=1.54 pot=19.76 Rg=7.761 SPS=2703
# chr10 loop
# ---
#
# bl=954 pos[1]=[1.0 -2.0 8.0] dr=0.94 t=0.0ps kin=1.51 pot=19.83 Rg=7.797 SPS=2660
# chr10 loop
# ---
#
# bl=955 pos[1]=[0.5 -1.4 6.8] dr=0.95 t=0.0ps kin=1.49 pot=19.75 Rg=7.759 SPS=2701
# chr10 loop
# ---
#
# bl=956 pos[1]=[0.1 -1.9 7.1] dr=0.94 t=0.0ps kin=1.48 pot=19.77 Rg=7.737 SPS=2576
# chr10 loop
# ---
#
# bl=957 pos[1]=[0.5 -2.5 9.3] dr=0.92 t=0.0ps kin=1.51 pot=19.75 Rg=7.741 SPS=2716
# chr10 loop
# ---
#
# bl=958 pos[1]=[0.4 -1.6 11.0] dr=0.93 t=0.0ps kin=1.47 pot=19.75 Rg=7.775 SPS=2604
# chr10 loop
# ---
#
# bl=959 pos[1]=[-1.0 -1.1 10.8] dr=0.93 t=0.0ps kin=1.49 pot=19.75 Rg=7.755 SPS=2709
# chr10 loop
# ---
#
# bl=960 pos[1]=[-0.3 -2.5 10.3] dr=0.93 t=0.0ps kin=1.50 pot=19.74 Rg=7.732 SPS=2654
# chr10 loop
# ---
#
# bl=961 pos[1]=[-0.4 -3.1 9.7] dr=0.93 t=0.0ps kin=1.56 pot=19.73 Rg=7.713 SPS=2758
# chr10 loop
# ---
#
# bl=962 pos[1]=[-2.1 -3.3 9.4] dr=0.92 t=0.0ps kin=1.50 pot=19.75 Rg=7.736 SPS=2616
# chr10 loop
# ---
#
# bl=963 pos[1]=[-2.3 -2.3 10.5] dr=0.94 t=0.0ps kin=1.52 pot=19.78 Rg=7.774 SPS=2642
# chr10 loop
# ---
#
# bl=964 pos[1]=[-2.6 -0.9 8.6] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=7.800 SPS=2733
# chr10 loop
# ---
#
# bl=965 pos[1]=[-2.9 -1.6 8.9] dr=0.93 t=0.0ps kin=1.51 pot=19.80 Rg=7.809 SPS=2775
# chr10 loop
# ---
#
# bl=966 pos[1]=[-3.5 -1.7 10.4] dr=0.94 t=0.0ps kin=1.52 pot=19.81 Rg=7.758 SPS=2711
# chr10 loop
# ---
#
# bl=967 pos[1]=[-3.0 -1.7 9.4] dr=0.95 t=0.0ps kin=1.51 pot=19.78 Rg=7.746 SPS=2737
# chr10 loop
# ---
#
# bl=968 pos[1]=[-2.8 -2.6 10.8] dr=0.94 t=0.0ps kin=1.48 pot=19.75 Rg=7.751 SPS=2679
# chr10 loop
# ---
#
# bl=969 pos[1]=[-2.0 -2.6 11.3] dr=0.93 t=0.0ps kin=1.52 pot=19.75 Rg=7.769 SPS=2757
# chr10 loop
# ---
#
# bl=970 pos[1]=[-1.5 -2.7 9.6] dr=0.94 t=0.0ps kin=1.50 pot=19.80 Rg=7.799 SPS=2520
# chr10 loop
# ---
#
# bl=971 pos[1]=[-1.2 -2.9 8.9] dr=0.97 t=0.0ps kin=1.54 pot=19.79 Rg=7.776 SPS=2752
# chr10 loop
# ---
#
# bl=972 pos[1]=[-2.1 -3.3 9.2] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=7.750 SPS=2858
# chr10 loop
# ---
#
# bl=973 pos[1]=[-1.5 -3.0 10.1] dr=0.98 t=0.0ps kin=1.47 pot=19.81 Rg=7.769 SPS=2695
# chr10 loop
# ---
#
# bl=974 pos[1]=[-1.7 -4.1 9.9] dr=0.95 t=0.0ps kin=1.50 pot=19.79 Rg=7.766 SPS=2772
# chr10 loop
# ---
#
# bl=975 pos[1]=[-2.6 -3.7 10.5] dr=0.95 t=0.0ps kin=1.51 pot=19.80 Rg=7.767 SPS=2810
# chr10 loop
# ---
#
# bl=976 pos[1]=[-2.9 -3.1 11.1] dr=0.97 t=0.0ps kin=1.48 pot=19.83 Rg=7.737 SPS=2682
# chr10 loop
# ---
#
# bl=977 pos[1]=[-3.4 -2.6 10.6] dr=0.94 t=0.0ps kin=1.49 pot=19.73 Rg=7.729 SPS=2855
# chr10 loop
# ---
#
# bl=978 pos[1]=[-6.5 -3.1 10.4] dr=0.95 t=0.0ps kin=1.47 pot=19.80 Rg=7.754 SPS=2742
# chr10 loop
# ---
#
# bl=979 pos[1]=[-7.2 -4.6 9.0] dr=0.97 t=0.0ps kin=1.48 pot=19.78 Rg=7.787 SPS=2807
# chr10 loop
# ---
#
# bl=980 pos[1]=[-7.4 -4.2 8.0] dr=0.95 t=0.0ps kin=1.50 pot=19.76 Rg=7.758 SPS=2798
# chr10 loop
# ---
#
# bl=981 pos[1]=[-7.9 -3.1 8.8] dr=0.96 t=0.0ps kin=1.47 pot=19.75 Rg=7.725 SPS=2795
# chr10 loop
# ---
#
# bl=982 pos[1]=[-5.7 -2.3 9.6] dr=0.95 t=0.0ps kin=1.46 pot=19.76 Rg=7.711 SPS=2712
# chr10 loop
# ---
#
# bl=983 pos[1]=[-4.1 -2.4 10.7] dr=0.93 t=0.0ps kin=1.49 pot=19.73 Rg=7.707 SPS=2805
# chr10 loop
# ---
#
# bl=984 pos[1]=[-4.5 -2.4 10.8] dr=0.95 t=0.0ps kin=1.48 pot=19.76 Rg=7.675 SPS=2853
# chr10 loop
# ---
#
# bl=985 pos[1]=[-3.2 -4.0 11.2] dr=0.94 t=0.0ps kin=1.48 pot=19.76 Rg=7.643 SPS=2860
# chr10 loop
# ---
#
# bl=986 pos[1]=[-2.4 -3.4 10.4] dr=0.94 t=0.0ps kin=1.49 pot=19.76 Rg=7.662 SPS=2854
# chr10 loop
# ---
#
# bl=987 pos[1]=[-2.7 -1.9 10.3] dr=0.95 t=0.0ps kin=1.47 pot=19.81 Rg=7.695 SPS=2925
# chr10 loop
# ---
#
# bl=988 pos[1]=[-2.3 -2.6 10.4] dr=0.93 t=0.0ps kin=1.50 pot=19.76 Rg=7.708 SPS=2837
# chr10 loop
# ---
#
# bl=989 pos[1]=[-2.5 -3.7 10.4] dr=0.93 t=0.0ps kin=1.53 pot=19.82 Rg=7.664 SPS=2785
# chr10 loop
# ---
#
# bl=990 pos[1]=[-2.0 -4.1 10.3] dr=0.94 t=0.0ps kin=1.54 pot=19.78 Rg=7.647 SPS=2879
# chr10 loop
# ---
#
# bl=991 pos[1]=[-1.7 -5.0 10.3] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=7.688 SPS=2767
# chr10 loop
# ---
#
# bl=992 pos[1]=[-1.2 -3.8 10.7] dr=0.94 t=0.0ps kin=1.50 pot=19.79 Rg=7.731 SPS=2797
# chr10 loop
# ---
#
# bl=993 pos[1]=[-2.1 -4.4 11.5] dr=0.94 t=0.0ps kin=1.47 pot=19.84 Rg=7.725 SPS=2664
# chr10 loop
# ---
#
# bl=994 pos[1]=[-1.2 -4.7 11.8] dr=0.94 t=0.0ps kin=1.52 pot=19.78 Rg=7.719 SPS=2944
# chr10 loop
# ---
#
# bl=995 pos[1]=[-1.5 -5.2 10.2] dr=0.94 t=0.0ps kin=1.48 pot=19.84 Rg=7.692 SPS=2906
# chr10 loop
# ---
#
# bl=996 pos[1]=[-0.3 -3.5 10.5] dr=0.94 t=0.0ps kin=1.50 pot=19.80 Rg=7.696 SPS=2905
# chr10 loop
# ---
#
# bl=997 pos[1]=[-1.2 -3.2 10.7] dr=0.93 t=0.0ps kin=1.52 pot=19.81 Rg=7.698 SPS=2899
# chr10 loop
# ---
#
# bl=998 pos[1]=[-1.3 -3.2 11.0] dr=0.95 t=0.0ps kin=1.54 pot=19.77 Rg=7.667 SPS=2897
# chr10 loop
# ---
#
# bl=999 pos[1]=[-1.2 -2.1 11.5] dr=0.93 t=0.0ps kin=1.49 pot=19.77 Rg=7.679 SPS=2827
# chr10 loop
# ---
#
#
# Statistics for the simulation chr10, number of particles: 2712,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.28647436 -0.87393413  1.43741679]   Rg =  7.6790876
#      median bond size is  0.9636653121918541
#      three shortest/longest (<10)/ bonds are  [0.88077198 0.8820807  0.88354186]    [1.08376629 1.08848383 1.10021407]
#      95 percentile of distance to center is:    10.430832399630868
#      density of closest 95% monomers is:    0.541960680301555
#      density of the core monomers is:    0.735507197512713
#      min/median/mean/max coordinates are:
#      x: -9.39, -0.42, -0.29, 10.46
#      y: -11.24, -1.03, -0.87, 10.53
#      z: -9.17, 1.39, 1.44, 11.47
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4962103333401326 should be: 1.5
#      fastest particles are (in kT):  [ 8.1380177   8.45116197  8.48091296  9.88857404 13.04763776]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2711
#
# Potential Energy Ep =  19.7691567570059
# bl=1000 pos[1]=[-2.5 -2.3 12.0] dr=0.93 t=0.0ps kin=1.52 pot=19.77 Rg=7.729 SPS=2758
# chr10 loop
# ---
#
# 7.729182

# %% [markdown]
# **{ chr 11 } collapse simulation**

# %%
# chromosome 11 collapse simulation
sim_chr11 = MiChroM(name="chr11", temperature=1.0, time_step=0.01)
sim_chr11.setup(platform="cuda")
sim_chr11.saveFolder('multi_op_chr10_11_allFrames')
Chrom11 = sim_chr11.createSpringSpiral(ChromSeq='../inputs/chr11_beads.txt')
sim_chr11.loadStructure(Chrom11, center=True)

sim_chr11.addFENEBonds(kfb=30.0)
sim_chr11.addAngles(ka=2.0)
sim_chr11.addRepulsiveSoftCore(Ecut=4.0)
sim_chr11.addFlatBottomHarmonic()
sim_chr11.addTypetoType(mu=3.22, rc = 1.78)
sim_chr11.addIdealChromosome(mu=3.22, rc = 1.78, dinit=3, dend=500)

print('GENERATING CHR11 SIM', '\n---\n')
for _ in range(n_blocks):
    sim_chr11.runSimBlock(block, increment=False)
    print('chr11 loop', '\n---\n')

print(sim_chr11.chromRG())
sim_chr11.saveStructure(filename="chr11", mode="ndb")
sim_chr11.saveStructure(filename="chr11", mode="pdb")
del sim_chr11
# Out:
#     ***************************************************************************************
#      **** **** *** *** *** *** *** *** OpenMiChroM-1.0.5 *** *** *** *** *** *** **** ****
#
#          OpenMiChroM is a Python library for performing chromatin dynamics simulations.
#                             OpenMiChroM uses the OpenMM Python API,
#                 employing the MiChroM (Minimal Chromatin Model) energy function.
#       The chromatin dynamics simulations generate an ensemble of 3D chromosomal structures
#       that are consistent with experimental Hi-C maps, also allows simulations of a single
#                  or multiple chromosome chain using High-Performance Computing
#                             in different platforms (GPUs and CPUs).
#          OpenMiChroM documentation is available at https://open-michrom.readthedocs.io
#
#          OpenMiChroM is described in: Oliveira Junior, A. B & Contessoto, V, G et. al.
#       A Scalable Computational Approach for Simulating Complexes of Multiple Chromosomes.
#                   Journal of Molecular Biology. doi:10.1016/j.jmb.2020.10.034.
#                                               and
#                                  Oliveira Junior, A. B. et al.
#      Chromosome Modeling on Downsampled Hi-C Maps Enhances the Compartmentalization Signal.
#                         J. Phys. Chem. B, doi:10.1021/acs.jpcb.1c04174.
#
#                     Copyright (c) 2022, The OpenMiChroM development team at
#                                         Rice University
#     ***************************************************************************************
# GENERATING CHR11 SIM
# ---
#
# Number of exceptions: 2702
# adding force  FENEBond 0
# adding force  AngleForce 1
# Add exclusions for RepulsiveSoftCore force
# adding force  RepulsiveSoftCore 2
# adding force  FlatBottomHarmonic 3
# Add exclusions for TypetoType force
# adding force  TypetoType 4
# Add exclusions for IdealChromosome force
# adding force  IdealChromosome 5
# Positions...
#  loaded!
# potential energy is 67.212634
# bl=1 pos[1]=[208.4 -10.5 -0.5] dr=1.15 t=0.0ps kin=1.74 pot=67.25 Rg=145.780 SPS=3601
# chr11 loop
# ---
#
# bl=2 pos[1]=[206.3 -9.3 1.9] dr=2.46 t=0.0ps kin=2.65 pot=65.69 Rg=143.653 SPS=3616
# chr11 loop
# ---
#
# bl=3 pos[1]=[203.9 -6.7 3.5] dr=3.07 t=0.0ps kin=3.12 pot=63.87 Rg=140.876 SPS=3585
# chr11 loop
# ---
#
# bl=4 pos[1]=[197.9 -5.0 5.3] dr=3.32 t=0.0ps kin=3.36 pot=61.96 Rg=137.794 SPS=3532
# chr11 loop
# ---
#
# bl=5 pos[1]=[192.8 -3.5 5.9] dr=3.39 t=0.0ps kin=3.43 pot=60.01 Rg=134.609 SPS=3679
# chr11 loop
# ---
#
# bl=6 pos[1]=[186.8 -3.5 6.4] dr=3.41 t=0.0ps kin=3.42 pot=58.10 Rg=131.413 SPS=3578
# chr11 loop
# ---
#
# bl=7 pos[1]=[180.6 -5.1 9.6] dr=3.36 t=0.0ps kin=3.38 pot=56.27 Rg=128.269 SPS=3679
# chr11 loop
# ---
#
# bl=8 pos[1]=[176.7 -7.4 11.3] dr=3.32 t=0.0ps kin=3.31 pot=54.49 Rg=125.171 SPS=3700
# chr11 loop
# ---
#
# bl=9 pos[1]=[173.2 -8.0 12.2] dr=3.27 t=0.0ps kin=3.27 pot=52.75 Rg=122.130 SPS=3695
# chr11 loop
# ---
#
# bl=10 pos[1]=[169.6 -7.1 11.8] dr=3.21 t=0.0ps kin=3.15 pot=51.13 Rg=119.150 SPS=3587
# chr11 loop
# ---
#
# bl=11 pos[1]=[164.4 -7.5 12.3] dr=3.15 t=0.0ps kin=3.13 pot=49.54 Rg=116.244 SPS=3556
# chr11 loop
# ---
#
# bl=12 pos[1]=[158.6 -6.4 12.6] dr=3.08 t=0.0ps kin=2.99 pot=48.07 Rg=113.426 SPS=3574
# chr11 loop
# ---
#
# bl=13 pos[1]=[155.7 -5.3 13.2] dr=3.01 t=0.0ps kin=2.99 pot=46.67 Rg=110.688 SPS=3530
# chr11 loop
# ---
#
# bl=14 pos[1]=[150.6 -5.2 12.7] dr=2.94 t=0.0ps kin=2.84 pot=45.36 Rg=108.025 SPS=3559
# chr11 loop
# ---
#
# bl=15 pos[1]=[146.7 -6.0 13.8] dr=2.90 t=0.0ps kin=2.83 pot=44.06 Rg=105.408 SPS=3554
# chr11 loop
# ---
#
# bl=16 pos[1]=[141.7 -5.5 13.0] dr=2.84 t=0.0ps kin=2.77 pot=42.87 Rg=102.868 SPS=3561
# chr11 loop
# ---
#
# bl=17 pos[1]=[137.4 -5.6 12.9] dr=2.77 t=0.0ps kin=2.59 pot=41.75 Rg=100.405 SPS=3561
# chr11 loop
# ---
#
# bl=18 pos[1]=[135.6 -6.1 14.0] dr=2.71 t=0.0ps kin=2.64 pot=40.63 Rg=98.004 SPS=3523
# chr11 loop
# ---
#
# bl=19 pos[1]=[132.3 -3.0 13.4] dr=2.69 t=0.0ps kin=2.62 pot=39.62 Rg=95.638 SPS=3516
# chr11 loop
# ---
#
# bl=20 pos[1]=[127.7 -2.7 12.4] dr=2.63 t=0.0ps kin=2.53 pot=38.60 Rg=93.337 SPS=3521
# chr11 loop
# ---
#
# bl=21 pos[1]=[123.5 -2.1 12.8] dr=2.54 t=0.0ps kin=2.45 pot=37.69 Rg=91.128 SPS=3484
# chr11 loop
# ---
#
# bl=22 pos[1]=[119.8 -2.7 12.7] dr=2.47 t=0.0ps kin=2.36 pot=36.82 Rg=88.996 SPS=3564
# chr11 loop
# ---
#
# bl=23 pos[1]=[116.6 -2.5 12.7] dr=2.41 t=0.0ps kin=2.33 pot=35.98 Rg=86.922 SPS=3590
# chr11 loop
# ---
#
# bl=24 pos[1]=[115.2 -4.0 13.9] dr=2.38 t=0.0ps kin=2.33 pot=35.15 Rg=84.896 SPS=3452
# chr11 loop
# ---
#
# bl=25 pos[1]=[113.1 -3.7 15.2] dr=2.34 t=0.0ps kin=2.22 pot=34.45 Rg=82.922 SPS=3365
# chr11 loop
# ---
#
# bl=26 pos[1]=[109.6 -3.1 14.7] dr=2.31 t=0.0ps kin=2.31 pot=33.72 Rg=80.974 SPS=3486
# chr11 loop
# ---
#
# bl=27 pos[1]=[109.0 -2.7 14.1] dr=2.31 t=0.0ps kin=2.24 pot=33.03 Rg=79.027 SPS=3227
# chr11 loop
# ---
#
# bl=28 pos[1]=[106.7 -2.4 13.5] dr=2.26 t=0.0ps kin=2.20 pot=32.36 Rg=77.138 SPS=3371
# chr11 loop
# ---
#
# bl=29 pos[1]=[104.4 -1.4 12.4] dr=2.20 t=0.0ps kin=2.15 pot=31.72 Rg=75.321 SPS=3482
# chr11 loop
# ---
#
# bl=30 pos[1]=[101.6 -1.5 12.0] dr=2.16 t=0.0ps kin=2.13 pot=31.17 Rg=73.567 SPS=3499
# chr11 loop
# ---
#
# bl=31 pos[1]=[98.7 -0.5 11.0] dr=2.13 t=0.0ps kin=2.12 pot=30.63 Rg=71.840 SPS=3515
# chr11 loop
# ---
#
# bl=32 pos[1]=[95.1 -0.7 10.3] dr=2.10 t=0.0ps kin=2.06 pot=30.06 Rg=70.150 SPS=3411
# chr11 loop
# ---
#
# bl=33 pos[1]=[93.7 0.0 10.3] dr=2.02 t=0.0ps kin=2.00 pot=29.58 Rg=68.543 SPS=3232
# chr11 loop
# ---
#
# bl=34 pos[1]=[91.3 -0.0 9.6] dr=1.99 t=0.0ps kin=2.00 pot=29.10 Rg=66.986 SPS=3447
# chr11 loop
# ---
#
# bl=35 pos[1]=[88.0 -0.3 11.3] dr=1.92 t=0.0ps kin=1.96 pot=28.67 Rg=65.504 SPS=3466
# chr11 loop
# ---
#
# bl=36 pos[1]=[86.5 -0.9 10.4] dr=1.92 t=0.0ps kin=1.93 pot=28.23 Rg=64.048 SPS=3307
# chr11 loop
# ---
#
# bl=37 pos[1]=[85.4 -1.4 9.2] dr=1.86 t=0.0ps kin=1.90 pot=27.87 Rg=62.638 SPS=3458
# chr11 loop
# ---
#
# bl=38 pos[1]=[81.2 -0.8 9.2] dr=1.89 t=0.0ps kin=1.92 pot=27.49 Rg=61.209 SPS=3409
# chr11 loop
# ---
#
# bl=39 pos[1]=[78.8 -1.5 7.3] dr=1.84 t=0.0ps kin=1.90 pot=27.10 Rg=59.809 SPS=3357
# chr11 loop
# ---
#
# bl=40 pos[1]=[76.4 -1.3 5.7] dr=1.82 t=0.0ps kin=1.83 pot=26.79 Rg=58.454 SPS=3312
# chr11 loop
# ---
#
# bl=41 pos[1]=[74.6 0.6 4.3] dr=1.77 t=0.0ps kin=1.83 pot=26.41 Rg=57.153 SPS=3326
# chr11 loop
# ---
#
# bl=42 pos[1]=[72.2 1.0 2.7] dr=1.73 t=0.0ps kin=1.79 pot=26.10 Rg=55.907 SPS=3464
# chr11 loop
# ---
#
# bl=43 pos[1]=[68.9 0.2 4.5] dr=1.70 t=0.0ps kin=1.76 pot=25.83 Rg=54.707 SPS=3447
# chr11 loop
# ---
#
# bl=44 pos[1]=[65.8 0.4 4.6] dr=1.70 t=0.0ps kin=1.81 pot=25.53 Rg=53.528 SPS=3459
# chr11 loop
# ---
#
# bl=45 pos[1]=[63.3 -0.1 5.1] dr=1.69 t=0.0ps kin=1.80 pot=25.27 Rg=52.355 SPS=3364
# chr11 loop
# ---
#
# bl=46 pos[1]=[62.9 -0.2 6.1] dr=1.69 t=0.0ps kin=1.78 pot=25.00 Rg=51.175 SPS=3457
# chr11 loop
# ---
#
# bl=47 pos[1]=[62.9 -2.5 5.5] dr=1.66 t=0.0ps kin=1.76 pot=24.77 Rg=50.031 SPS=3455
# chr11 loop
# ---
#
# bl=48 pos[1]=[63.5 -3.1 4.6] dr=1.60 t=0.0ps kin=1.74 pot=24.53 Rg=48.971 SPS=3410
# chr11 loop
# ---
#
# bl=49 pos[1]=[63.4 -3.0 3.8] dr=1.58 t=0.0ps kin=1.76 pot=24.32 Rg=47.958 SPS=3219
# chr11 loop
# ---
#
#
# Statistics for the simulation chr11, number of particles: 2703,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.16718676  0.3832679   0.09050601]   Rg =  47.95778
#      median bond size is  0.9655537067636235
#      three shortest/longest (<10)/ bonds are  [0.88134252 0.88247719 0.88431091]    [1.11741493 1.12011832 1.12253975]
#      95 percentile of distance to center is:    60.35644240494358
#      density of closest 95% monomers is:    0.002788111527871993
#      density of the core monomers is:    0.000818459993210585
#      min/median/mean/max coordinates are:
#      x: -57.09, -5.22, -0.17, 63.44
#      y: -59.96, 4.03, 0.38, 55.06
#      z: -16.30, 0.14, 0.09, 15.80
#
# Statistics for velocities:
#      mean kinetic energy is:  1.7645865955733644 should be: 1.5
#      fastest particles are (in kT):  [ 9.48889095  9.80853835  9.8825086  11.30702122 11.75279235]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2702
#
# Potential Energy Ep =  24.322465778764336
# bl=50 pos[1]=[62.8 -2.4 3.3] dr=1.57 t=0.0ps kin=1.73 pot=24.10 Rg=46.958 SPS=3099
# chr11 loop
# ---
#
# bl=51 pos[1]=[58.8 -0.9 1.8] dr=1.58 t=0.0ps kin=1.67 pot=23.93 Rg=45.950 SPS=2923
# chr11 loop
# ---
#
# bl=52 pos[1]=[56.6 -1.2 1.6] dr=1.56 t=0.0ps kin=1.70 pot=23.74 Rg=44.967 SPS=3005
# chr11 loop
# ---
#
# bl=53 pos[1]=[55.2 0.7 2.7] dr=1.51 t=0.0ps kin=1.69 pot=23.56 Rg=44.034 SPS=3036
# chr11 loop
# ---
#
# bl=54 pos[1]=[53.4 1.4 3.7] dr=1.47 t=0.0ps kin=1.67 pot=23.36 Rg=43.159 SPS=3093
# chr11 loop
# ---
#
# bl=55 pos[1]=[51.8 1.0 5.4] dr=1.46 t=0.0ps kin=1.67 pot=23.23 Rg=42.294 SPS=2995
# chr11 loop
# ---
#
# bl=56 pos[1]=[51.2 -0.1 6.7] dr=1.44 t=0.0ps kin=1.64 pot=23.06 Rg=41.435 SPS=3138
# chr11 loop
# ---
#
# bl=57 pos[1]=[49.8 0.1 6.7] dr=1.43 t=0.0ps kin=1.67 pot=22.91 Rg=40.600 SPS=2942
# chr11 loop
# ---
#
# bl=58 pos[1]=[49.4 0.7 6.8] dr=1.44 t=0.0ps kin=1.65 pot=22.82 Rg=39.754 SPS=3052
# chr11 loop
# ---
#
# bl=59 pos[1]=[49.1 0.6 6.2] dr=1.42 t=0.0ps kin=1.66 pot=22.65 Rg=38.934 SPS=3004
# chr11 loop
# ---
#
# bl=60 pos[1]=[48.1 0.7 4.7] dr=1.38 t=0.0ps kin=1.61 pot=22.52 Rg=38.148 SPS=2919
# chr11 loop
# ---
#
# bl=61 pos[1]=[48.0 -1.8 5.8] dr=1.38 t=0.0ps kin=1.62 pot=22.35 Rg=37.390 SPS=2961
# chr11 loop
# ---
#
# bl=62 pos[1]=[46.9 -2.0 5.6] dr=1.37 t=0.0ps kin=1.63 pot=22.25 Rg=36.629 SPS=2834
# chr11 loop
# ---
#
# bl=63 pos[1]=[46.5 -1.3 4.7] dr=1.34 t=0.0ps kin=1.61 pot=22.12 Rg=35.911 SPS=2838
# chr11 loop
# ---
#
# bl=64 pos[1]=[46.9 -1.1 4.4] dr=1.30 t=0.0ps kin=1.57 pot=22.02 Rg=35.244 SPS=2971
# chr11 loop
# ---
#
# bl=65 pos[1]=[45.8 0.0 4.4] dr=1.28 t=0.0ps kin=1.56 pot=21.94 Rg=34.575 SPS=2974
# chr11 loop
# ---
#
# bl=66 pos[1]=[44.3 -0.3 4.3] dr=1.26 t=0.0ps kin=1.57 pot=21.83 Rg=33.953 SPS=2603
# chr11 loop
# ---
#
# bl=67 pos[1]=[44.6 0.7 4.3] dr=1.28 t=0.0ps kin=1.59 pot=21.73 Rg=33.330 SPS=2725
# chr11 loop
# ---
#
# bl=68 pos[1]=[43.3 0.9 4.4] dr=1.28 t=0.0ps kin=1.61 pot=21.65 Rg=32.679 SPS=2900
# chr11 loop
# ---
#
# bl=69 pos[1]=[42.3 0.4 4.8] dr=1.30 t=0.0ps kin=1.62 pot=21.59 Rg=32.052 SPS=2467
# chr11 loop
# ---
#
# bl=70 pos[1]=[42.6 0.2 5.3] dr=1.27 t=0.0ps kin=1.55 pot=21.53 Rg=31.444 SPS=2650
# chr11 loop
# ---
#
# bl=71 pos[1]=[42.4 0.8 4.5] dr=1.23 t=0.0ps kin=1.60 pot=21.39 Rg=30.870 SPS=2799
# chr11 loop
# ---
#
# bl=72 pos[1]=[41.7 0.9 5.0] dr=1.21 t=0.0ps kin=1.58 pot=21.36 Rg=30.322 SPS=2696
# chr11 loop
# ---
#
# bl=73 pos[1]=[39.9 0.3 4.2] dr=1.21 t=0.0ps kin=1.63 pot=21.32 Rg=29.784 SPS=2883
# chr11 loop
# ---
#
# bl=74 pos[1]=[38.7 1.1 5.3] dr=1.24 t=0.0ps kin=1.57 pot=21.23 Rg=29.267 SPS=2778
# chr11 loop
# ---
#
# bl=75 pos[1]=[38.5 1.1 6.1] dr=1.23 t=0.0ps kin=1.60 pot=21.16 Rg=28.730 SPS=2841
# chr11 loop
# ---
#
# bl=76 pos[1]=[37.2 1.3 4.7] dr=1.22 t=0.0ps kin=1.59 pot=21.08 Rg=28.204 SPS=2626
# chr11 loop
# ---
#
# bl=77 pos[1]=[36.4 1.6 5.2] dr=1.18 t=0.0ps kin=1.54 pot=21.08 Rg=27.712 SPS=2842
# chr11 loop
# ---
#
# bl=78 pos[1]=[34.8 2.6 6.0] dr=1.18 t=0.0ps kin=1.55 pot=21.02 Rg=27.256 SPS=2756
# chr11 loop
# ---
#
# bl=79 pos[1]=[35.0 3.3 5.4] dr=1.13 t=0.0ps kin=1.57 pot=20.95 Rg=26.853 SPS=2743
# chr11 loop
# ---
#
# bl=80 pos[1]=[35.2 3.4 4.4] dr=1.15 t=0.0ps kin=1.53 pot=20.92 Rg=26.469 SPS=2773
# chr11 loop
# ---
#
# bl=81 pos[1]=[34.8 2.6 4.2] dr=1.15 t=0.0ps kin=1.54 pot=20.88 Rg=26.058 SPS=2627
# chr11 loop
# ---
#
# bl=82 pos[1]=[34.0 2.6 4.2] dr=1.12 t=0.0ps kin=1.51 pot=20.85 Rg=25.676 SPS=2646
# chr11 loop
# ---
#
# bl=83 pos[1]=[33.7 1.2 4.1] dr=1.12 t=0.0ps kin=1.55 pot=20.83 Rg=25.271 SPS=2721
# chr11 loop
# ---
#
# bl=84 pos[1]=[32.3 -0.1 4.5] dr=1.13 t=0.0ps kin=1.56 pot=20.78 Rg=24.858 SPS=2759
# chr11 loop
# ---
#
# bl=85 pos[1]=[30.6 1.5 4.2] dr=1.14 t=0.0ps kin=1.55 pot=20.74 Rg=24.460 SPS=2776
# chr11 loop
# ---
#
# bl=86 pos[1]=[30.6 0.9 4.0] dr=1.14 t=0.0ps kin=1.54 pot=20.70 Rg=24.032 SPS=2675
# chr11 loop
# ---
#
# bl=87 pos[1]=[30.5 0.6 3.2] dr=1.14 t=0.0ps kin=1.58 pot=20.63 Rg=23.613 SPS=2728
# chr11 loop
# ---
#
# bl=88 pos[1]=[29.1 0.3 2.3] dr=1.13 t=0.0ps kin=1.59 pot=20.60 Rg=23.195 SPS=2671
# chr11 loop
# ---
#
# bl=89 pos[1]=[28.8 0.2 2.4] dr=1.13 t=0.0ps kin=1.57 pot=20.56 Rg=22.795 SPS=2665
# chr11 loop
# ---
#
# bl=90 pos[1]=[29.3 0.9 2.1] dr=1.12 t=0.0ps kin=1.54 pot=20.55 Rg=22.424 SPS=2642
# chr11 loop
# ---
#
# bl=91 pos[1]=[29.4 0.6 2.1] dr=1.12 t=0.0ps kin=1.57 pot=20.53 Rg=22.060 SPS=2717
# chr11 loop
# ---
#
# bl=92 pos[1]=[28.5 1.0 2.5] dr=1.12 t=0.0ps kin=1.58 pot=20.46 Rg=21.708 SPS=2666
# chr11 loop
# ---
#
# bl=93 pos[1]=[26.0 0.7 3.8] dr=1.11 t=0.0ps kin=1.55 pot=20.46 Rg=21.380 SPS=2662
# chr11 loop
# ---
#
# bl=94 pos[1]=[25.6 1.8 3.1] dr=1.09 t=0.0ps kin=1.53 pot=20.41 Rg=21.061 SPS=2732
# chr11 loop
# ---
#
# bl=95 pos[1]=[24.6 2.1 3.5] dr=1.07 t=0.0ps kin=1.54 pot=20.39 Rg=20.784 SPS=2664
# chr11 loop
# ---
#
# bl=96 pos[1]=[23.6 2.6 3.6] dr=1.08 t=0.0ps kin=1.55 pot=20.36 Rg=20.483 SPS=2690
# chr11 loop
# ---
#
# bl=97 pos[1]=[23.8 2.1 3.5] dr=1.07 t=0.0ps kin=1.52 pot=20.34 Rg=20.166 SPS=2718
# chr11 loop
# ---
#
# bl=98 pos[1]=[23.7 0.2 3.7] dr=1.05 t=0.0ps kin=1.51 pot=20.32 Rg=19.872 SPS=2780
# chr11 loop
# ---
#
# bl=99 pos[1]=[23.0 -0.3 3.1] dr=1.06 t=0.0ps kin=1.50 pot=20.24 Rg=19.586 SPS=2664
# chr11 loop
# ---
#
#
# Statistics for the simulation chr11, number of particles: 2703,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.37198455  1.20883786  0.42588213]   Rg =  19.585703
#      median bond size is  0.9637547652371495
#      three shortest/longest (<10)/ bonds are  [0.87937028 0.88655059 0.88778913]    [1.08712873 1.09425008 1.09756609]
#      95 percentile of distance to center is:    23.733324684363037
#      density of closest 95% monomers is:    0.045856964129946644
#      density of the core monomers is:    0.00911637144239072
#      min/median/mean/max coordinates are:
#      x: -22.91, -2.08, -0.37, 24.18
#      y: -23.11, 2.86, 1.21, 23.83
#      z: -6.45, 0.46, 0.43, 7.03
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5040303929982528 should be: 1.5
#      fastest particles are (in kT):  [ 7.39337719  7.45720898  7.5825785   7.62315689 10.94953518]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2702
#
# Potential Energy Ep =  20.23733756474288
# bl=100 pos[1]=[22.9 -1.5 2.5] dr=1.04 t=0.0ps kin=1.49 pot=20.23 Rg=19.332 SPS=2650
# chr11 loop
# ---
#
# bl=101 pos[1]=[22.3 -2.2 2.4] dr=1.04 t=0.0ps kin=1.50 pot=20.20 Rg=19.096 SPS=2762
# chr11 loop
# ---
#
# bl=102 pos[1]=[20.7 -1.1 1.5] dr=1.03 t=0.0ps kin=1.50 pot=20.24 Rg=18.862 SPS=2736
# chr11 loop
# ---
#
# bl=103 pos[1]=[20.0 -0.5 1.7] dr=1.04 t=0.0ps kin=1.51 pot=20.26 Rg=18.650 SPS=2709
# chr11 loop
# ---
#
# bl=104 pos[1]=[20.0 -0.9 1.3] dr=1.03 t=0.0ps kin=1.50 pot=20.25 Rg=18.434 SPS=2729
# chr11 loop
# ---
#
# bl=105 pos[1]=[19.7 -0.2 1.1] dr=1.00 t=0.0ps kin=1.53 pot=20.18 Rg=18.205 SPS=2657
# chr11 loop
# ---
#
# bl=106 pos[1]=[19.9 0.9 1.7] dr=1.02 t=0.0ps kin=1.52 pot=20.19 Rg=18.001 SPS=2749
# chr11 loop
# ---
#
# bl=107 pos[1]=[19.3 1.4 2.1] dr=1.01 t=0.0ps kin=1.49 pot=20.21 Rg=17.795 SPS=2717
# chr11 loop
# ---
#
# bl=108 pos[1]=[18.6 1.4 2.3] dr=1.05 t=0.0ps kin=1.50 pot=20.16 Rg=17.554 SPS=2618
# chr11 loop
# ---
#
# bl=109 pos[1]=[18.5 1.7 1.9] dr=1.01 t=0.0ps kin=1.49 pot=20.14 Rg=17.311 SPS=2582
# chr11 loop
# ---
#
# bl=110 pos[1]=[17.3 1.4 2.4] dr=1.02 t=0.0ps kin=1.51 pot=20.12 Rg=17.085 SPS=2721
# chr11 loop
# ---
#
# bl=111 pos[1]=[16.6 1.6 1.5] dr=1.02 t=0.0ps kin=1.52 pot=20.14 Rg=16.880 SPS=2621
# chr11 loop
# ---
#
# bl=112 pos[1]=[16.3 0.6 1.8] dr=1.00 t=0.0ps kin=1.54 pot=20.16 Rg=16.727 SPS=2732
# chr11 loop
# ---
#
# bl=113 pos[1]=[17.1 0.1 1.2] dr=1.01 t=0.0ps kin=1.51 pot=20.15 Rg=16.589 SPS=2694
# chr11 loop
# ---
#
# bl=114 pos[1]=[16.5 0.5 1.1] dr=1.02 t=0.0ps kin=1.50 pot=20.12 Rg=16.458 SPS=2701
# chr11 loop
# ---
#
# bl=115 pos[1]=[15.6 1.1 0.3] dr=0.97 t=0.0ps kin=1.51 pot=20.10 Rg=16.341 SPS=2684
# chr11 loop
# ---
#
# bl=116 pos[1]=[15.9 0.8 1.3] dr=0.99 t=0.0ps kin=1.53 pot=20.09 Rg=16.179 SPS=2711
# chr11 loop
# ---
#
# bl=117 pos[1]=[15.8 0.7 0.6] dr=1.00 t=0.0ps kin=1.50 pot=20.06 Rg=16.031 SPS=2714
# chr11 loop
# ---
#
# bl=118 pos[1]=[15.9 0.9 0.6] dr=1.00 t=0.0ps kin=1.50 pot=20.04 Rg=15.900 SPS=2791
# chr11 loop
# ---
#
# bl=119 pos[1]=[15.6 0.7 0.4] dr=1.00 t=0.0ps kin=1.49 pot=20.03 Rg=15.802 SPS=2668
# chr11 loop
# ---
#
# bl=120 pos[1]=[17.0 0.7 1.3] dr=1.00 t=0.0ps kin=1.46 pot=20.04 Rg=15.707 SPS=2684
# chr11 loop
# ---
#
# bl=121 pos[1]=[16.9 0.1 0.4] dr=0.99 t=0.0ps kin=1.46 pot=20.07 Rg=15.600 SPS=2759
# chr11 loop
# ---
#
# bl=122 pos[1]=[18.1 0.1 0.7] dr=0.99 t=0.0ps kin=1.49 pot=20.05 Rg=15.451 SPS=2796
# chr11 loop
# ---
#
# bl=123 pos[1]=[20.5 -1.6 0.7] dr=1.00 t=0.0ps kin=1.52 pot=20.04 Rg=15.310 SPS=2721
# chr11 loop
# ---
#
# bl=124 pos[1]=[20.3 -3.2 2.8] dr=1.00 t=0.0ps kin=1.52 pot=19.98 Rg=15.166 SPS=2734
# chr11 loop
# ---
#
# bl=125 pos[1]=[19.3 -0.6 4.7] dr=1.02 t=0.0ps kin=1.48 pot=20.02 Rg=14.954 SPS=2588
# chr11 loop
# ---
#
# bl=126 pos[1]=[17.2 0.1 5.1] dr=1.00 t=0.0ps kin=1.48 pot=19.97 Rg=14.772 SPS=2634
# chr11 loop
# ---
#
# bl=127 pos[1]=[15.8 -0.2 5.2] dr=0.98 t=0.0ps kin=1.45 pot=19.98 Rg=14.615 SPS=2628
# chr11 loop
# ---
#
# bl=128 pos[1]=[15.2 0.1 6.4] dr=0.97 t=0.0ps kin=1.48 pot=19.97 Rg=14.466 SPS=2482
# chr11 loop
# ---
#
# bl=129 pos[1]=[15.1 0.2 6.0] dr=1.01 t=0.0ps kin=1.47 pot=20.00 Rg=14.331 SPS=2340
# chr11 loop
# ---
#
# bl=130 pos[1]=[15.9 1.5 6.1] dr=0.97 t=0.0ps kin=1.50 pot=19.97 Rg=14.199 SPS=2699
# chr11 loop
# ---
#
# bl=131 pos[1]=[17.8 1.3 7.2] dr=0.97 t=0.0ps kin=1.49 pot=19.96 Rg=14.066 SPS=2653
# chr11 loop
# ---
#
# bl=132 pos[1]=[17.4 3.2 7.4] dr=0.98 t=0.0ps kin=1.50 pot=19.98 Rg=13.927 SPS=2584
# chr11 loop
# ---
#
# bl=133 pos[1]=[16.7 2.9 8.5] dr=1.00 t=0.0ps kin=1.51 pot=19.95 Rg=13.802 SPS=2499
# chr11 loop
# ---
#
# bl=134 pos[1]=[18.2 2.5 8.5] dr=0.97 t=0.0ps kin=1.47 pot=20.01 Rg=13.726 SPS=2716
# chr11 loop
# ---
#
# bl=135 pos[1]=[16.9 2.7 7.1] dr=0.97 t=0.0ps kin=1.48 pot=19.98 Rg=13.680 SPS=2621
# chr11 loop
# ---
#
# bl=136 pos[1]=[15.0 2.9 7.1] dr=0.98 t=0.0ps kin=1.51 pot=19.94 Rg=13.636 SPS=2726
# chr11 loop
# ---
#
# bl=137 pos[1]=[15.4 2.6 7.2] dr=0.96 t=0.0ps kin=1.48 pot=19.93 Rg=13.601 SPS=2646
# chr11 loop
# ---
#
# bl=138 pos[1]=[13.8 2.1 7.9] dr=0.96 t=0.0ps kin=1.47 pot=19.95 Rg=13.545 SPS=2772
# chr11 loop
# ---
#
# bl=139 pos[1]=[13.8 3.1 8.7] dr=0.99 t=0.0ps kin=1.52 pot=19.95 Rg=13.498 SPS=2678
# chr11 loop
# ---
#
# bl=140 pos[1]=[12.7 1.2 6.9] dr=1.00 t=0.0ps kin=1.52 pot=19.98 Rg=13.429 SPS=2680
# chr11 loop
# ---
#
# bl=141 pos[1]=[13.1 1.3 6.5] dr=0.99 t=0.0ps kin=1.49 pot=20.02 Rg=13.351 SPS=2776
# chr11 loop
# ---
#
# bl=142 pos[1]=[14.7 2.0 6.9] dr=0.98 t=0.0ps kin=1.51 pot=19.99 Rg=13.275 SPS=2709
# chr11 loop
# ---
#
# bl=143 pos[1]=[13.4 3.1 7.4] dr=0.98 t=0.0ps kin=1.55 pot=20.00 Rg=13.208 SPS=2804
# chr11 loop
# ---
#
# bl=144 pos[1]=[12.6 2.6 6.8] dr=0.99 t=0.0ps kin=1.53 pot=19.98 Rg=13.123 SPS=2850
# chr11 loop
# ---
#
# bl=145 pos[1]=[12.1 2.6 7.9] dr=0.98 t=0.0ps kin=1.48 pot=19.97 Rg=13.056 SPS=2800
# chr11 loop
# ---
#
# bl=146 pos[1]=[11.5 4.4 7.6] dr=0.97 t=0.0ps kin=1.48 pot=19.94 Rg=12.995 SPS=2900
# chr11 loop
# ---
#
# bl=147 pos[1]=[13.5 3.8 6.9] dr=0.97 t=0.0ps kin=1.53 pot=19.94 Rg=12.904 SPS=2632
# chr11 loop
# ---
#
# bl=148 pos[1]=[13.2 3.6 4.8] dr=0.98 t=0.0ps kin=1.52 pot=19.96 Rg=12.811 SPS=2772
# chr11 loop
# ---
#
# bl=149 pos[1]=[14.8 4.5 5.5] dr=0.99 t=0.0ps kin=1.50 pot=19.96 Rg=12.707 SPS=2734
# chr11 loop
# ---
#
#
# Statistics for the simulation chr11, number of particles: 2703,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.5751661   1.01594624  0.11191578]   Rg =  12.707281
#      median bond size is  0.9647185792474906
#      three shortest/longest (<10)/ bonds are  [0.87278215 0.87442232 0.8756919 ]    [1.10025709 1.10687942 1.10983671]
#      95 percentile of distance to center is:    16.67543026123925
#      density of closest 95% monomers is:    0.1322056136520275
#      density of the core monomers is:    0.0602658834634984
#      min/median/mean/max coordinates are:
#      x: -16.25, -1.44, -0.58, 16.74
#      y: -18.56, 3.15, 1.02, 18.03
#      z: -7.05, 0.14, 0.11, 7.28
#
# Statistics for velocities:
#      mean kinetic energy is:  1.502311553409428 should be: 1.5
#      fastest particles are (in kT):  [ 7.54163351  7.71426988  7.7363247   8.03231103 10.87968126]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2702
#
# Potential Energy Ep =  19.964047470403255
# bl=150 pos[1]=[14.4 4.9 5.2] dr=1.00 t=0.0ps kin=1.50 pot=19.96 Rg=12.622 SPS=2650
# chr11 loop
# ---
#
# bl=151 pos[1]=[15.2 4.0 4.0] dr=0.99 t=0.0ps kin=1.47 pot=19.99 Rg=12.539 SPS=2781
# chr11 loop
# ---
#
# bl=152 pos[1]=[14.8 3.1 3.7] dr=0.98 t=0.0ps kin=1.52 pot=19.96 Rg=12.413 SPS=2872
# chr11 loop
# ---
#
# bl=153 pos[1]=[13.2 3.1 3.9] dr=1.01 t=0.0ps kin=1.55 pot=19.97 Rg=12.306 SPS=2846
# chr11 loop
# ---
#
# bl=154 pos[1]=[13.2 3.3 3.5] dr=0.99 t=0.0ps kin=1.52 pot=19.98 Rg=12.218 SPS=2836
# chr11 loop
# ---
#
# bl=155 pos[1]=[13.0 2.7 4.6] dr=0.97 t=0.0ps kin=1.53 pot=19.97 Rg=12.137 SPS=2943
# chr11 loop
# ---
#
# bl=156 pos[1]=[13.0 3.0 5.0] dr=0.98 t=0.0ps kin=1.52 pot=19.94 Rg=12.075 SPS=2909
# chr11 loop
# ---
#
# bl=157 pos[1]=[14.6 2.5 5.4] dr=0.97 t=0.0ps kin=1.49 pot=19.94 Rg=12.022 SPS=2874
# chr11 loop
# ---
#
# bl=158 pos[1]=[13.5 2.6 5.0] dr=0.96 t=0.0ps kin=1.49 pot=19.93 Rg=11.950 SPS=2823
# chr11 loop
# ---
#
# bl=159 pos[1]=[14.3 2.7 2.5] dr=0.97 t=0.0ps kin=1.49 pot=19.92 Rg=11.848 SPS=2910
# chr11 loop
# ---
#
# bl=160 pos[1]=[14.3 2.6 2.1] dr=0.97 t=0.0ps kin=1.48 pot=19.92 Rg=11.755 SPS=2837
# chr11 loop
# ---
#
# bl=161 pos[1]=[14.1 2.9 1.8] dr=0.99 t=0.0ps kin=1.49 pot=19.98 Rg=11.663 SPS=2865
# chr11 loop
# ---
#
# bl=162 pos[1]=[12.4 2.0 1.1] dr=1.00 t=0.0ps kin=1.55 pot=19.95 Rg=11.575 SPS=2867
# chr11 loop
# ---
#
# bl=163 pos[1]=[13.7 1.7 0.9] dr=0.98 t=0.0ps kin=1.50 pot=19.96 Rg=11.515 SPS=2913
# chr11 loop
# ---
#
# bl=164 pos[1]=[14.9 1.8 0.9] dr=0.98 t=0.0ps kin=1.50 pot=19.90 Rg=11.468 SPS=2889
# chr11 loop
# ---
#
# bl=165 pos[1]=[13.7 2.4 1.0] dr=0.98 t=0.0ps kin=1.53 pot=19.86 Rg=11.429 SPS=2884
# chr11 loop
# ---
#
# bl=166 pos[1]=[12.0 1.0 0.9] dr=0.96 t=0.0ps kin=1.47 pot=19.93 Rg=11.376 SPS=2846
# chr11 loop
# ---
#
# bl=167 pos[1]=[11.2 2.0 0.6] dr=0.98 t=0.0ps kin=1.49 pot=19.90 Rg=11.299 SPS=2848
# chr11 loop
# ---
#
# bl=168 pos[1]=[10.7 1.8 0.3] dr=0.96 t=0.0ps kin=1.50 pot=19.86 Rg=11.210 SPS=2873
# chr11 loop
# ---
#
# bl=169 pos[1]=[11.5 2.1 -0.3] dr=0.96 t=0.0ps kin=1.50 pot=19.88 Rg=11.155 SPS=2809
# chr11 loop
# ---
#
# bl=170 pos[1]=[11.7 2.3 -0.3] dr=0.96 t=0.0ps kin=1.50 pot=19.88 Rg=11.094 SPS=2852
# chr11 loop
# ---
#
# bl=171 pos[1]=[11.7 2.6 -0.0] dr=0.98 t=0.0ps kin=1.51 pot=19.84 Rg=11.021 SPS=2797
# chr11 loop
# ---
#
# bl=172 pos[1]=[11.1 3.1 0.4] dr=0.96 t=0.0ps kin=1.53 pot=19.85 Rg=10.960 SPS=2789
# chr11 loop
# ---
#
# bl=173 pos[1]=[11.2 4.2 1.2] dr=0.96 t=0.0ps kin=1.48 pot=19.90 Rg=10.943 SPS=2813
# chr11 loop
# ---
#
# bl=174 pos[1]=[11.0 5.1 2.6] dr=0.97 t=0.0ps kin=1.47 pot=19.88 Rg=10.909 SPS=2752
# chr11 loop
# ---
#
# bl=175 pos[1]=[10.8 6.0 2.3] dr=0.97 t=0.0ps kin=1.53 pot=19.90 Rg=10.854 SPS=2791
# chr11 loop
# ---
#
# bl=176 pos[1]=[11.0 6.3 2.7] dr=0.98 t=0.0ps kin=1.53 pot=19.86 Rg=10.782 SPS=2777
# chr11 loop
# ---
#
# bl=177 pos[1]=[12.0 6.8 2.8] dr=0.98 t=0.0ps kin=1.51 pot=19.90 Rg=10.697 SPS=2767
# chr11 loop
# ---
#
# bl=178 pos[1]=[12.9 6.7 2.2] dr=0.97 t=0.0ps kin=1.48 pot=19.94 Rg=10.649 SPS=2746
# chr11 loop
# ---
#
# bl=179 pos[1]=[10.9 5.2 1.1] dr=0.97 t=0.0ps kin=1.53 pot=19.92 Rg=10.583 SPS=2785
# chr11 loop
# ---
#
# bl=180 pos[1]=[11.2 4.6 0.3] dr=0.96 t=0.0ps kin=1.54 pot=19.87 Rg=10.524 SPS=2802
# chr11 loop
# ---
#
# bl=181 pos[1]=[11.9 4.2 -0.7] dr=0.95 t=0.0ps kin=1.51 pot=19.84 Rg=10.478 SPS=2779
# chr11 loop
# ---
#
# bl=182 pos[1]=[11.7 3.7 -0.2] dr=0.96 t=0.0ps kin=1.48 pot=19.87 Rg=10.444 SPS=2795
# chr11 loop
# ---
#
# bl=183 pos[1]=[11.2 4.0 0.3] dr=0.96 t=0.0ps kin=1.47 pot=19.89 Rg=10.410 SPS=2786
# chr11 loop
# ---
#
# bl=184 pos[1]=[11.1 2.8 0.0] dr=0.97 t=0.0ps kin=1.51 pot=19.86 Rg=10.374 SPS=2782
# chr11 loop
# ---
#
# bl=185 pos[1]=[10.8 4.2 0.4] dr=0.97 t=0.0ps kin=1.51 pot=19.89 Rg=10.347 SPS=2801
# chr11 loop
# ---
#
# bl=186 pos[1]=[10.7 5.1 -0.3] dr=0.97 t=0.0ps kin=1.50 pot=19.91 Rg=10.329 SPS=2776
# chr11 loop
# ---
#
# bl=187 pos[1]=[10.9 5.1 -0.4] dr=0.96 t=0.0ps kin=1.50 pot=19.88 Rg=10.314 SPS=2802
# chr11 loop
# ---
#
# bl=188 pos[1]=[10.8 4.8 -0.9] dr=0.99 t=0.0ps kin=1.52 pot=19.91 Rg=10.271 SPS=2774
# chr11 loop
# ---
#
# bl=189 pos[1]=[10.4 5.0 -1.4] dr=1.00 t=0.0ps kin=1.50 pot=19.90 Rg=10.225 SPS=2814
# chr11 loop
# ---
#
# bl=190 pos[1]=[11.3 3.6 -2.1] dr=0.96 t=0.0ps kin=1.52 pot=19.84 Rg=10.172 SPS=2789
# chr11 loop
# ---
#
# bl=191 pos[1]=[11.6 4.6 -1.0] dr=0.97 t=0.0ps kin=1.49 pot=19.87 Rg=10.135 SPS=2786
# chr11 loop
# ---
#
# bl=192 pos[1]=[12.9 5.1 -0.7] dr=0.98 t=0.0ps kin=1.53 pot=19.84 Rg=10.115 SPS=2773
# chr11 loop
# ---
#
# bl=193 pos[1]=[14.7 4.1 -2.2] dr=0.99 t=0.0ps kin=1.51 pot=19.90 Rg=10.074 SPS=2784
# chr11 loop
# ---
#
# bl=194 pos[1]=[13.5 3.5 -2.3] dr=0.98 t=0.0ps kin=1.49 pot=19.92 Rg=10.013 SPS=2766
# chr11 loop
# ---
#
# bl=195 pos[1]=[12.1 3.4 -0.8] dr=0.97 t=0.0ps kin=1.50 pot=19.88 Rg=9.999 SPS=2802
# chr11 loop
# ---
#
# bl=196 pos[1]=[11.7 5.1 -0.5] dr=0.98 t=0.0ps kin=1.48 pot=19.90 Rg=9.949 SPS=2782
# chr11 loop
# ---
#
# bl=197 pos[1]=[11.5 5.1 1.4] dr=0.98 t=0.0ps kin=1.53 pot=19.86 Rg=9.868 SPS=2790
# chr11 loop
# ---
#
# bl=198 pos[1]=[10.4 6.1 1.6] dr=0.99 t=0.0ps kin=1.50 pot=19.89 Rg=9.787 SPS=2788
# chr11 loop
# ---
#
# bl=199 pos[1]=[9.9 6.6 1.9] dr=0.96 t=0.0ps kin=1.50 pot=19.91 Rg=9.706 SPS=2797
# chr11 loop
# ---
#
#
# Statistics for the simulation chr11, number of particles: 2703,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.25911117  1.00229998  0.66675931]   Rg =  9.705785
#      median bond size is  0.9637387129330953
#      three shortest/longest (<10)/ bonds are  [0.87973669 0.88382497 0.88432675]    [1.07402724 1.07664895 1.10109022]
#      95 percentile of distance to center is:    13.437912168934895
#      density of closest 95% monomers is:    0.2526304217652214
#      density of the core monomers is:    0.29533689724632856
#      min/median/mean/max coordinates are:
#      x: -12.41, -0.06, -0.26, 12.56
#      y: -13.18, 1.47, 1.00, 15.99
#      z: -7.37, 0.65, 0.67, 8.08
#
# Statistics for velocities:
#      mean kinetic energy is:  1.49955874160708 should be: 1.5
#      fastest particles are (in kT):  [8.39220926 8.39277337 8.51654409 8.69685069 8.86794556]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2702
#
# Potential Energy Ep =  19.912582662782093
# bl=200 pos[1]=[9.6 6.5 1.8] dr=0.99 t=0.0ps kin=1.53 pot=19.83 Rg=9.646 SPS=2730
# chr11 loop
# ---
#
# bl=201 pos[1]=[9.7 5.4 2.1] dr=0.97 t=0.0ps kin=1.48 pot=19.87 Rg=9.598 SPS=2766
# chr11 loop
# ---
#
# bl=202 pos[1]=[11.0 4.5 1.3] dr=0.96 t=0.0ps kin=1.50 pot=19.84 Rg=9.574 SPS=2786
# chr11 loop
# ---
#
# bl=203 pos[1]=[11.9 3.7 0.7] dr=0.96 t=0.0ps kin=1.50 pot=19.83 Rg=9.530 SPS=2821
# chr11 loop
# ---
#
# bl=204 pos[1]=[11.7 3.0 -0.5] dr=0.95 t=0.0ps kin=1.49 pot=19.87 Rg=9.500 SPS=2773
# chr11 loop
# ---
#
# bl=205 pos[1]=[12.1 2.7 1.2] dr=0.97 t=0.0ps kin=1.51 pot=19.86 Rg=9.447 SPS=2786
# chr11 loop
# ---
#
# bl=206 pos[1]=[12.0 3.2 1.0] dr=0.97 t=0.0ps kin=1.50 pot=19.85 Rg=9.392 SPS=2809
# chr11 loop
# ---
#
# bl=207 pos[1]=[11.9 3.2 1.3] dr=0.99 t=0.0ps kin=1.52 pot=19.88 Rg=9.379 SPS=2678
# chr11 loop
# ---
#
# bl=208 pos[1]=[13.4 3.2 1.7] dr=0.95 t=0.0ps kin=1.49 pot=19.90 Rg=9.386 SPS=2706
# chr11 loop
# ---
#
# bl=209 pos[1]=[12.5 3.7 1.2] dr=0.95 t=0.0ps kin=1.51 pot=19.90 Rg=9.390 SPS=2652
# chr11 loop
# ---
#
# bl=210 pos[1]=[11.8 3.3 -0.4] dr=0.99 t=0.0ps kin=1.53 pot=19.92 Rg=9.395 SPS=2765
# chr11 loop
# ---
#
# bl=211 pos[1]=[12.2 2.5 -0.4] dr=1.01 t=0.0ps kin=1.55 pot=19.95 Rg=9.331 SPS=2754
# chr11 loop
# ---
#
# bl=212 pos[1]=[12.8 2.0 2.0] dr=1.00 t=0.0ps kin=1.54 pot=19.94 Rg=9.286 SPS=2771
# chr11 loop
# ---
#
# bl=213 pos[1]=[12.7 2.2 3.2] dr=0.99 t=0.0ps kin=1.51 pot=19.91 Rg=9.276 SPS=2767
# chr11 loop
# ---
#
# bl=214 pos[1]=[13.0 2.7 4.6] dr=0.98 t=0.0ps kin=1.52 pot=19.84 Rg=9.222 SPS=2757
# chr11 loop
# ---
#
# bl=215 pos[1]=[11.4 1.9 5.0] dr=0.96 t=0.0ps kin=1.49 pot=19.87 Rg=9.203 SPS=2754
# chr11 loop
# ---
#
# bl=216 pos[1]=[11.4 1.1 3.2] dr=0.97 t=0.0ps kin=1.50 pot=19.84 Rg=9.226 SPS=2815
# chr11 loop
# ---
#
# bl=217 pos[1]=[11.0 0.8 2.9] dr=0.94 t=0.0ps kin=1.51 pot=19.84 Rg=9.225 SPS=2813
# chr11 loop
# ---
#
# bl=218 pos[1]=[10.7 1.1 3.2] dr=0.96 t=0.0ps kin=1.48 pot=19.86 Rg=9.211 SPS=2830
# chr11 loop
# ---
#
# bl=219 pos[1]=[11.6 -0.4 3.4] dr=0.96 t=0.0ps kin=1.47 pot=19.88 Rg=9.196 SPS=2850
# chr11 loop
# ---
#
# bl=220 pos[1]=[12.0 -0.6 5.2] dr=0.97 t=0.0ps kin=1.52 pot=19.83 Rg=9.115 SPS=2818
# chr11 loop
# ---
#
# bl=221 pos[1]=[12.0 0.7 5.4] dr=0.95 t=0.0ps kin=1.47 pot=19.83 Rg=9.057 SPS=2810
# chr11 loop
# ---
#
# bl=222 pos[1]=[11.4 -0.1 4.5] dr=0.95 t=0.0ps kin=1.47 pot=19.87 Rg=9.020 SPS=2799
# chr11 loop
# ---
#
# bl=223 pos[1]=[12.1 1.7 3.8] dr=0.97 t=0.0ps kin=1.46 pot=19.82 Rg=8.962 SPS=2854
# chr11 loop
# ---
#
# bl=224 pos[1]=[12.0 1.7 3.6] dr=0.95 t=0.0ps kin=1.52 pot=19.79 Rg=8.910 SPS=2827
# chr11 loop
# ---
#
# bl=225 pos[1]=[9.7 2.2 4.4] dr=0.97 t=0.0ps kin=1.47 pot=19.85 Rg=8.876 SPS=2830
# chr11 loop
# ---
#
# bl=226 pos[1]=[9.9 3.5 3.1] dr=0.98 t=0.0ps kin=1.53 pot=19.82 Rg=8.807 SPS=2802
# chr11 loop
# ---
#
# bl=227 pos[1]=[9.9 3.4 2.6] dr=0.96 t=0.0ps kin=1.50 pot=19.80 Rg=8.768 SPS=2834
# chr11 loop
# ---
#
# bl=228 pos[1]=[9.8 2.7 2.7] dr=0.94 t=0.0ps kin=1.51 pot=19.84 Rg=8.720 SPS=2874
# chr11 loop
# ---
#
# bl=229 pos[1]=[10.8 3.9 2.2] dr=0.95 t=0.0ps kin=1.52 pot=19.83 Rg=8.730 SPS=2874
# chr11 loop
# ---
#
# bl=230 pos[1]=[12.1 3.5 1.9] dr=0.96 t=0.0ps kin=1.53 pot=19.84 Rg=8.721 SPS=2853
# chr11 loop
# ---
#
# bl=231 pos[1]=[12.3 2.8 1.0] dr=0.94 t=0.0ps kin=1.53 pot=19.83 Rg=8.701 SPS=2830
# chr11 loop
# ---
#
# bl=232 pos[1]=[12.3 1.2 1.9] dr=0.96 t=0.0ps kin=1.48 pot=19.84 Rg=8.664 SPS=2804
# chr11 loop
# ---
#
# bl=233 pos[1]=[11.6 1.3 2.4] dr=0.96 t=0.0ps kin=1.53 pot=19.78 Rg=8.607 SPS=2845
# chr11 loop
# ---
#
# bl=234 pos[1]=[11.4 -0.2 2.3] dr=0.95 t=0.0ps kin=1.49 pot=19.82 Rg=8.618 SPS=2834
# chr11 loop
# ---
#
# bl=235 pos[1]=[10.7 -0.9 2.8] dr=0.94 t=0.0ps kin=1.51 pot=19.80 Rg=8.635 SPS=2846
# chr11 loop
# ---
#
# bl=236 pos[1]=[9.4 -1.0 2.0] dr=0.95 t=0.0ps kin=1.51 pot=19.81 Rg=8.638 SPS=2876
# chr11 loop
# ---
#
# bl=237 pos[1]=[10.0 -1.3 1.8] dr=0.96 t=0.0ps kin=1.51 pot=19.80 Rg=8.635 SPS=2846
# chr11 loop
# ---
#
# bl=238 pos[1]=[10.8 -0.2 1.7] dr=0.94 t=0.0ps kin=1.49 pot=19.85 Rg=8.649 SPS=2862
# chr11 loop
# ---
#
# bl=239 pos[1]=[11.1 0.4 2.0] dr=0.97 t=0.0ps kin=1.53 pot=19.79 Rg=8.635 SPS=2874
# chr11 loop
# ---
#
# bl=240 pos[1]=[9.7 0.5 2.1] dr=0.93 t=0.0ps kin=1.50 pot=19.81 Rg=8.649 SPS=2823
# chr11 loop
# ---
#
# bl=241 pos[1]=[10.5 0.3 3.0] dr=0.93 t=0.0ps kin=1.50 pot=19.79 Rg=8.661 SPS=2825
# chr11 loop
# ---
#
# bl=242 pos[1]=[9.6 1.2 2.0] dr=0.97 t=0.0ps kin=1.48 pot=19.80 Rg=8.614 SPS=2856
# chr11 loop
# ---
#
# bl=243 pos[1]=[9.1 1.9 1.1] dr=0.94 t=0.0ps kin=1.48 pot=19.80 Rg=8.590 SPS=2845
# chr11 loop
# ---
#
# bl=244 pos[1]=[9.2 1.5 1.1] dr=0.93 t=0.0ps kin=1.52 pot=19.80 Rg=8.589 SPS=2809
# chr11 loop
# ---
#
# bl=245 pos[1]=[7.8 1.9 1.8] dr=0.96 t=0.0ps kin=1.53 pot=19.80 Rg=8.608 SPS=2755
# chr11 loop
# ---
#
# bl=246 pos[1]=[8.1 1.6 1.9] dr=0.93 t=0.0ps kin=1.46 pot=19.87 Rg=8.629 SPS=2828
# chr11 loop
# ---
#
# bl=247 pos[1]=[9.3 1.0 2.5] dr=0.96 t=0.0ps kin=1.50 pot=19.83 Rg=8.625 SPS=2837
# chr11 loop
# ---
#
# bl=248 pos[1]=[9.0 1.9 2.2] dr=0.96 t=0.0ps kin=1.50 pot=19.86 Rg=8.578 SPS=2806
# chr11 loop
# ---
#
# bl=249 pos[1]=[9.6 0.7 1.9] dr=0.96 t=0.0ps kin=1.50 pot=19.84 Rg=8.543 SPS=2828
# chr11 loop
# ---
#
#
# Statistics for the simulation chr11, number of particles: 2703,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.08348392  0.20150563  0.46964928]   Rg =  8.543105
#      median bond size is  0.9639370727755467
#      three shortest/longest (<10)/ bonds are  [0.87611107 0.88503215 0.88619612]    [1.0807649  1.08567361 1.10081717]
#      95 percentile of distance to center is:    11.698208240207409
#      density of closest 95% monomers is:    0.3829331795101749
#      density of the core monomers is:    0.6382305259324612
#      min/median/mean/max coordinates are:
#      x: -11.74, -0.43, -0.08, 13.19
#      y: -12.58, 0.16, 0.20, 14.70
#      z: -8.55, 0.48, 0.47, 8.41
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5005920042263208 should be: 1.5
#      fastest particles are (in kT):  [ 7.95236415  8.13325382 10.16713356 10.28433776 10.88036851]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2702
#
# Potential Energy Ep =  19.842145879578247
# bl=250 pos[1]=[10.2 0.6 2.2] dr=0.94 t=0.0ps kin=1.49 pot=19.83 Rg=8.490 SPS=2790
# chr11 loop
# ---
#
# bl=251 pos[1]=[11.0 0.1 2.7] dr=0.95 t=0.0ps kin=1.52 pot=19.84 Rg=8.415 SPS=2859
# chr11 loop
# ---
#
# bl=252 pos[1]=[12.3 0.2 3.2] dr=0.95 t=0.0ps kin=1.52 pot=19.78 Rg=8.356 SPS=2838
# chr11 loop
# ---
#
# bl=253 pos[1]=[12.5 1.4 3.7] dr=0.94 t=0.0ps kin=1.49 pot=19.83 Rg=8.345 SPS=2863
# chr11 loop
# ---
#
# bl=254 pos[1]=[13.9 1.5 4.0] dr=0.95 t=0.0ps kin=1.51 pot=19.84 Rg=8.365 SPS=2851
# chr11 loop
# ---
#
# bl=255 pos[1]=[12.4 1.5 3.7] dr=0.95 t=0.0ps kin=1.51 pot=19.81 Rg=8.387 SPS=2847
# chr11 loop
# ---
#
# bl=256 pos[1]=[13.5 2.5 2.4] dr=0.95 t=0.0ps kin=1.45 pot=19.80 Rg=8.376 SPS=2838
# chr11 loop
# ---
#
# bl=257 pos[1]=[12.0 2.8 2.2] dr=0.95 t=0.0ps kin=1.49 pot=19.80 Rg=8.352 SPS=2877
# chr11 loop
# ---
#
# bl=258 pos[1]=[12.2 2.7 2.0] dr=0.94 t=0.0ps kin=1.48 pot=19.81 Rg=8.348 SPS=2873
# chr11 loop
# ---
#
# bl=259 pos[1]=[10.4 4.1 1.9] dr=0.93 t=0.0ps kin=1.46 pot=19.84 Rg=8.343 SPS=2871
# chr11 loop
# ---
#
# bl=260 pos[1]=[10.7 5.1 2.4] dr=0.95 t=0.0ps kin=1.52 pot=19.81 Rg=8.325 SPS=2926
# chr11 loop
# ---
#
# bl=261 pos[1]=[11.2 4.4 3.7] dr=0.94 t=0.0ps kin=1.50 pot=19.84 Rg=8.341 SPS=2901
# chr11 loop
# ---
#
# bl=262 pos[1]=[11.0 4.6 3.1] dr=0.97 t=0.0ps kin=1.53 pot=19.81 Rg=8.320 SPS=2827
# chr11 loop
# ---
#
# bl=263 pos[1]=[11.0 4.8 2.6] dr=0.97 t=0.0ps kin=1.51 pot=19.81 Rg=8.283 SPS=2929
# chr11 loop
# ---
#
# bl=264 pos[1]=[11.4 5.0 2.7] dr=0.97 t=0.0ps kin=1.51 pot=19.81 Rg=8.265 SPS=2797
# chr11 loop
# ---
#
# bl=265 pos[1]=[11.5 4.3 2.4] dr=0.96 t=0.0ps kin=1.53 pot=19.82 Rg=8.253 SPS=2863
# chr11 loop
# ---
#
# bl=266 pos[1]=[11.1 3.0 2.0] dr=0.97 t=0.0ps kin=1.50 pot=19.80 Rg=8.276 SPS=2896
# chr11 loop
# ---
#
# bl=267 pos[1]=[9.5 2.4 2.6] dr=0.95 t=0.0ps kin=1.51 pot=19.81 Rg=8.230 SPS=2891
# chr11 loop
# ---
#
# bl=268 pos[1]=[9.8 2.5 1.7] dr=0.97 t=0.0ps kin=1.50 pot=19.80 Rg=8.167 SPS=2859
# chr11 loop
# ---
#
# bl=269 pos[1]=[10.0 2.8 1.0] dr=0.95 t=0.0ps kin=1.47 pot=19.82 Rg=8.118 SPS=2767
# chr11 loop
# ---
#
# bl=270 pos[1]=[10.0 2.4 1.5] dr=0.95 t=0.0ps kin=1.51 pot=19.78 Rg=8.108 SPS=2937
# chr11 loop
# ---
#
# bl=271 pos[1]=[10.9 1.6 1.0] dr=0.95 t=0.0ps kin=1.53 pot=19.79 Rg=8.088 SPS=2866
# chr11 loop
# ---
#
# bl=272 pos[1]=[11.7 1.2 0.7] dr=0.95 t=0.0ps kin=1.52 pot=19.82 Rg=8.089 SPS=2840
# chr11 loop
# ---
#
# bl=273 pos[1]=[12.1 0.7 2.4] dr=0.95 t=0.0ps kin=1.52 pot=19.79 Rg=8.118 SPS=2895
# chr11 loop
# ---
#
# bl=274 pos[1]=[12.8 0.0 2.8] dr=0.97 t=0.0ps kin=1.51 pot=19.78 Rg=8.128 SPS=2910
# chr11 loop
# ---
#
# bl=275 pos[1]=[12.2 -0.1 3.8] dr=0.93 t=0.0ps kin=1.52 pot=19.81 Rg=8.146 SPS=2807
# chr11 loop
# ---
#
# bl=276 pos[1]=[12.6 1.4 6.1] dr=0.94 t=0.0ps kin=1.52 pot=19.83 Rg=8.094 SPS=2794
# chr11 loop
# ---
#
# bl=277 pos[1]=[11.6 3.0 6.3] dr=0.95 t=0.0ps kin=1.49 pot=19.82 Rg=8.082 SPS=2682
# chr11 loop
# ---
#
# bl=278 pos[1]=[13.6 1.8 5.5] dr=0.95 t=0.0ps kin=1.50 pot=19.79 Rg=8.075 SPS=2826
# chr11 loop
# ---
#
# bl=279 pos[1]=[14.0 0.2 5.6] dr=0.96 t=0.0ps kin=1.48 pot=19.81 Rg=8.057 SPS=2870
# chr11 loop
# ---
#
# bl=280 pos[1]=[11.4 -0.3 5.9] dr=0.95 t=0.0ps kin=1.50 pot=19.78 Rg=8.036 SPS=2719
# chr11 loop
# ---
#
# bl=281 pos[1]=[11.1 -0.2 5.0] dr=0.96 t=0.0ps kin=1.48 pot=19.82 Rg=8.010 SPS=2880
# chr11 loop
# ---
#
# bl=282 pos[1]=[11.8 0.0 5.4] dr=0.95 t=0.0ps kin=1.52 pot=19.78 Rg=7.951 SPS=2866
# chr11 loop
# ---
#
# bl=283 pos[1]=[13.1 1.4 6.1] dr=0.93 t=0.0ps kin=1.48 pot=19.78 Rg=7.932 SPS=2849
# chr11 loop
# ---
#
# bl=284 pos[1]=[11.7 1.5 6.7] dr=0.92 t=0.0ps kin=1.52 pot=19.76 Rg=7.936 SPS=2866
# chr11 loop
# ---
#
# bl=285 pos[1]=[12.0 0.7 5.6] dr=0.92 t=0.0ps kin=1.52 pot=19.77 Rg=7.987 SPS=2801
# chr11 loop
# ---
#
# bl=286 pos[1]=[11.7 1.6 6.3] dr=0.95 t=0.0ps kin=1.49 pot=19.79 Rg=8.002 SPS=2895
# chr11 loop
# ---
#
# bl=287 pos[1]=[9.5 1.3 5.8] dr=0.95 t=0.0ps kin=1.52 pot=19.80 Rg=7.977 SPS=2854
# chr11 loop
# ---
#
# bl=288 pos[1]=[9.6 0.8 6.4] dr=0.96 t=0.0ps kin=1.53 pot=19.82 Rg=7.981 SPS=2905
# chr11 loop
# ---
#
# bl=289 pos[1]=[9.1 1.6 7.6] dr=0.94 t=0.0ps kin=1.55 pot=19.82 Rg=7.982 SPS=2868
# chr11 loop
# ---
#
# bl=290 pos[1]=[11.0 2.9 6.8] dr=0.96 t=0.0ps kin=1.56 pot=19.79 Rg=7.960 SPS=2788
# chr11 loop
# ---
#
# bl=291 pos[1]=[11.7 2.2 6.0] dr=0.96 t=0.0ps kin=1.56 pot=19.82 Rg=7.997 SPS=2892
# chr11 loop
# ---
#
# bl=292 pos[1]=[11.7 1.5 6.6] dr=0.95 t=0.0ps kin=1.50 pot=19.84 Rg=8.031 SPS=2813
# chr11 loop
# ---
#
# bl=293 pos[1]=[11.1 0.5 6.8] dr=0.97 t=0.0ps kin=1.54 pot=19.82 Rg=7.991 SPS=2862
# chr11 loop
# ---
#
# bl=294 pos[1]=[11.6 0.5 4.6] dr=0.95 t=0.0ps kin=1.51 pot=19.79 Rg=7.959 SPS=2859
# chr11 loop
# ---
#
# bl=295 pos[1]=[12.4 -0.9 3.2] dr=0.96 t=0.0ps kin=1.48 pot=19.81 Rg=7.975 SPS=2888
# chr11 loop
# ---
#
# bl=296 pos[1]=[11.4 -3.0 3.2] dr=0.97 t=0.0ps kin=1.51 pot=19.82 Rg=7.991 SPS=2873
# chr11 loop
# ---
#
# bl=297 pos[1]=[10.4 -4.5 3.3] dr=0.95 t=0.0ps kin=1.48 pot=19.78 Rg=7.982 SPS=2847
# chr11 loop
# ---
#
# bl=298 pos[1]=[10.4 -4.2 3.4] dr=0.91 t=0.0ps kin=1.46 pot=19.77 Rg=7.940 SPS=2786
# chr11 loop
# ---
#
# bl=299 pos[1]=[10.4 -3.7 3.5] dr=0.93 t=0.0ps kin=1.47 pot=19.76 Rg=7.905 SPS=2861
# chr11 loop
# ---
#
#
# Statistics for the simulation chr11, number of particles: 2703,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.21416777 -0.4671276   0.7038924 ]   Rg =  7.9051285
#      median bond size is  0.9651907733737219
#      three shortest/longest (<10)/ bonds are  [0.87135073 0.87716082 0.88012867]    [1.08570299 1.0859808  1.09513294]
#      95 percentile of distance to center is:    11.00694886798648
#      density of closest 95% monomers is:    0.4597060238987885
#      density of the core monomers is:    0.7441085749880917
#      min/median/mean/max coordinates are:
#      x: -11.74, -0.41, -0.21, 12.23
#      y: -12.02, -0.37, -0.47, 10.06
#      z: -10.10, 0.86, 0.70, 9.09
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4715075468591745 should be: 1.5
#      fastest particles are (in kT):  [7.31569978 7.40044838 7.80693253 8.07639171 8.08598373]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2702
#
# Potential Energy Ep =  19.764674088975212
# bl=300 pos[1]=[10.0 -4.1 3.5] dr=0.95 t=0.0ps kin=1.49 pot=19.79 Rg=7.858 SPS=2728
# chr11 loop
# ---
#
# bl=301 pos[1]=[11.3 -3.8 2.4] dr=0.95 t=0.0ps kin=1.50 pot=19.77 Rg=7.858 SPS=2822
# chr11 loop
# ---
#
# bl=302 pos[1]=[11.6 -2.9 2.5] dr=0.95 t=0.0ps kin=1.47 pot=19.77 Rg=7.848 SPS=2829
# chr11 loop
# ---
#
# bl=303 pos[1]=[9.6 -2.7 2.7] dr=0.93 t=0.0ps kin=1.47 pot=19.77 Rg=7.845 SPS=2680
# chr11 loop
# ---
#
# bl=304 pos[1]=[7.7 -2.6 2.8] dr=0.93 t=0.0ps kin=1.49 pot=19.74 Rg=7.860 SPS=2861
# chr11 loop
# ---
#
# bl=305 pos[1]=[7.6 -3.3 2.3] dr=0.94 t=0.0ps kin=1.48 pot=19.75 Rg=7.876 SPS=2859
# chr11 loop
# ---
#
# bl=306 pos[1]=[8.0 -3.2 2.2] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=7.875 SPS=2924
# chr11 loop
# ---
#
# bl=307 pos[1]=[9.0 -3.6 1.7] dr=0.94 t=0.0ps kin=1.50 pot=19.79 Rg=7.892 SPS=2879
# chr11 loop
# ---
#
# bl=308 pos[1]=[10.2 -3.4 2.3] dr=0.93 t=0.0ps kin=1.44 pot=19.80 Rg=7.902 SPS=2947
# chr11 loop
# ---
#
# bl=309 pos[1]=[10.9 -2.7 2.8] dr=0.91 t=0.0ps kin=1.47 pot=19.76 Rg=7.916 SPS=2950
# chr11 loop
# ---
#
# bl=310 pos[1]=[10.8 -2.7 1.8] dr=0.94 t=0.0ps kin=1.47 pot=19.75 Rg=7.922 SPS=2907
# chr11 loop
# ---
#
# bl=311 pos[1]=[10.7 -3.2 1.4] dr=0.94 t=0.0ps kin=1.53 pot=19.73 Rg=7.900 SPS=2971
# chr11 loop
# ---
#
# bl=312 pos[1]=[12.0 -3.1 3.0] dr=0.95 t=0.0ps kin=1.47 pot=19.77 Rg=7.908 SPS=2949
# chr11 loop
# ---
#
# bl=313 pos[1]=[12.1 -3.4 4.1] dr=0.93 t=0.0ps kin=1.50 pot=19.76 Rg=7.909 SPS=2947
# chr11 loop
# ---
#
# bl=314 pos[1]=[10.6 -3.1 4.2] dr=0.95 t=0.0ps kin=1.48 pot=19.79 Rg=7.879 SPS=2963
# chr11 loop
# ---
#
# bl=315 pos[1]=[10.3 -2.9 4.0] dr=0.93 t=0.0ps kin=1.48 pot=19.79 Rg=7.869 SPS=3035
# chr11 loop
# ---
#
# bl=316 pos[1]=[10.4 -2.9 5.7] dr=0.94 t=0.0ps kin=1.51 pot=19.78 Rg=7.862 SPS=3035
# chr11 loop
# ---
#
# bl=317 pos[1]=[9.1 -3.0 5.9] dr=0.96 t=0.0ps kin=1.52 pot=19.76 Rg=7.892 SPS=2987
# chr11 loop
# ---
#
# bl=318 pos[1]=[9.0 -4.1 6.2] dr=0.94 t=0.0ps kin=1.49 pot=19.80 Rg=7.932 SPS=2999
# chr11 loop
# ---
#
# bl=319 pos[1]=[8.4 -4.2 5.8] dr=0.98 t=0.0ps kin=1.50 pot=19.79 Rg=7.924 SPS=2937
# chr11 loop
# ---
#
# bl=320 pos[1]=[7.8 -3.5 6.9] dr=0.96 t=0.0ps kin=1.53 pot=19.76 Rg=7.865 SPS=2940
# chr11 loop
# ---
#
# bl=321 pos[1]=[6.0 -5.0 6.9] dr=0.96 t=0.0ps kin=1.51 pot=19.75 Rg=7.854 SPS=2882
# chr11 loop
# ---
#
# bl=322 pos[1]=[7.1 -5.0 4.8] dr=0.95 t=0.0ps kin=1.48 pot=19.79 Rg=7.884 SPS=2933
# chr11 loop
# ---
#
# bl=323 pos[1]=[7.2 -5.2 5.5] dr=0.95 t=0.0ps kin=1.53 pot=19.78 Rg=7.868 SPS=2939
# chr11 loop
# ---
#
# bl=324 pos[1]=[7.6 -6.1 5.5] dr=0.95 t=0.0ps kin=1.50 pot=19.81 Rg=7.874 SPS=2918
# chr11 loop
# ---
#
# bl=325 pos[1]=[7.0 -6.0 6.5] dr=0.96 t=0.0ps kin=1.51 pot=19.82 Rg=7.876 SPS=2928
# chr11 loop
# ---
#
# bl=326 pos[1]=[5.9 -5.6 5.9] dr=0.95 t=0.0ps kin=1.48 pot=19.81 Rg=7.870 SPS=2968
# chr11 loop
# ---
#
# bl=327 pos[1]=[5.5 -5.7 4.3] dr=0.94 t=0.0ps kin=1.50 pot=19.79 Rg=7.876 SPS=2958
# chr11 loop
# ---
#
# bl=328 pos[1]=[6.6 -5.2 4.7] dr=0.95 t=0.0ps kin=1.47 pot=19.79 Rg=7.835 SPS=2963
# chr11 loop
# ---
#
# bl=329 pos[1]=[5.2 -5.6 4.4] dr=0.94 t=0.0ps kin=1.51 pot=19.78 Rg=7.786 SPS=2971
# chr11 loop
# ---
#
# bl=330 pos[1]=[4.8 -6.2 3.2] dr=0.96 t=0.0ps kin=1.48 pot=19.77 Rg=7.769 SPS=3013
# chr11 loop
# ---
#
# bl=331 pos[1]=[4.8 -6.6 3.5] dr=0.94 t=0.0ps kin=1.47 pot=19.80 Rg=7.785 SPS=2999
# chr11 loop
# ---
#
# bl=332 pos[1]=[4.0 -6.5 3.1] dr=0.95 t=0.0ps kin=1.48 pot=19.78 Rg=7.820 SPS=2888
# chr11 loop
# ---
#
# bl=333 pos[1]=[3.3 -6.0 2.7] dr=0.92 t=0.0ps kin=1.50 pot=19.76 Rg=7.836 SPS=2995
# chr11 loop
# ---
#
# bl=334 pos[1]=[4.5 -6.4 2.6] dr=0.95 t=0.0ps kin=1.46 pot=19.78 Rg=7.826 SPS=2813
# chr11 loop
# ---
#
# bl=335 pos[1]=[6.8 -5.5 3.1] dr=0.99 t=0.0ps kin=1.51 pot=19.78 Rg=7.813 SPS=2914
# chr11 loop
# ---
#
# bl=336 pos[1]=[6.8 -5.0 3.5] dr=0.95 t=0.0ps kin=1.49 pot=19.78 Rg=7.832 SPS=2979
# chr11 loop
# ---
#
# bl=337 pos[1]=[6.1 -4.8 3.1] dr=0.91 t=0.0ps kin=1.50 pot=19.82 Rg=7.835 SPS=2955
# chr11 loop
# ---
#
# bl=338 pos[1]=[5.6 -5.4 3.6] dr=0.96 t=0.0ps kin=1.52 pot=19.80 Rg=7.842 SPS=2864
# chr11 loop
# ---
#
# bl=339 pos[1]=[5.2 -5.6 3.2] dr=0.95 t=0.0ps kin=1.54 pot=19.82 Rg=7.861 SPS=2800
# chr11 loop
# ---
#
# bl=340 pos[1]=[4.9 -5.1 5.2] dr=0.94 t=0.0ps kin=1.49 pot=19.85 Rg=7.891 SPS=2929
# chr11 loop
# ---
#
# bl=341 pos[1]=[5.4 -6.4 4.4] dr=0.95 t=0.0ps kin=1.55 pot=19.79 Rg=7.861 SPS=2895
# chr11 loop
# ---
#
# bl=342 pos[1]=[6.6 -7.4 5.0] dr=0.94 t=0.0ps kin=1.53 pot=19.76 Rg=7.851 SPS=2965
# chr11 loop
# ---
#
# bl=343 pos[1]=[5.3 -6.7 2.9] dr=0.95 t=0.0ps kin=1.49 pot=19.77 Rg=7.823 SPS=2960
# chr11 loop
# ---
#
# bl=344 pos[1]=[5.9 -6.0 3.9] dr=0.97 t=0.0ps kin=1.48 pot=19.78 Rg=7.870 SPS=2941
# chr11 loop
# ---
#
# bl=345 pos[1]=[5.7 -6.9 5.2] dr=0.93 t=0.0ps kin=1.46 pot=19.81 Rg=7.878 SPS=2930
# chr11 loop
# ---
#
# bl=346 pos[1]=[5.6 -6.9 6.6] dr=0.93 t=0.0ps kin=1.48 pot=19.83 Rg=7.858 SPS=3007
# chr11 loop
# ---
#
# bl=347 pos[1]=[6.0 -6.0 6.4] dr=0.93 t=0.0ps kin=1.50 pot=19.80 Rg=7.848 SPS=3014
# chr11 loop
# ---
#
# bl=348 pos[1]=[5.5 -6.2 6.3] dr=0.93 t=0.0ps kin=1.52 pot=19.77 Rg=7.821 SPS=2705
# chr11 loop
# ---
#
# bl=349 pos[1]=[7.0 -6.0 7.0] dr=0.93 t=0.0ps kin=1.50 pot=19.80 Rg=7.841 SPS=2674
# chr11 loop
# ---
#
#
# Statistics for the simulation chr11, number of particles: 2703,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 0.14352519 -0.14372675  0.4501646 ]   Rg =  7.8408775
#      median bond size is  0.9648833921874516
#      three shortest/longest (<10)/ bonds are  [0.86782607 0.88114447 0.88115794]    [1.08930012 1.09507098 1.09567474]
#      95 percentile of distance to center is:    10.728080456756052
#      density of closest 95% monomers is:    0.4964951105605951
#      density of the core monomers is:    0.7458103499543399
#      min/median/mean/max coordinates are:
#      x: -11.09, -0.01, 0.14, 12.58
#      y: -10.17, -0.27, -0.14, 10.41
#      z: -9.54, 0.39, 0.45, 11.03
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4974088729109956 should be: 1.5
#      fastest particles are (in kT):  [ 7.98230219  8.49694125  8.83236088 10.53161152 10.62884351]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2702
#
# Potential Energy Ep =  19.803626757306695
# bl=350 pos[1]=[8.2 -4.7 6.4] dr=0.96 t=0.0ps kin=1.51 pot=19.74 Rg=7.868 SPS=2856
# chr11 loop
# ---
#
# bl=351 pos[1]=[9.3 -3.6 6.3] dr=0.93 t=0.0ps kin=1.51 pot=19.79 Rg=7.857 SPS=2910
# chr11 loop
# ---
#
# bl=352 pos[1]=[9.3 -3.4 7.9] dr=0.95 t=0.0ps kin=1.50 pot=19.81 Rg=7.861 SPS=2663
# chr11 loop
# ---
#
# bl=353 pos[1]=[9.0 -3.0 7.5] dr=0.96 t=0.0ps kin=1.54 pot=19.78 Rg=7.855 SPS=2902
# chr11 loop
# ---
#
# bl=354 pos[1]=[9.2 -1.2 7.9] dr=0.95 t=0.0ps kin=1.51 pot=19.84 Rg=7.855 SPS=2801
# chr11 loop
# ---
#
# bl=355 pos[1]=[9.1 -0.1 5.9] dr=0.95 t=0.0ps kin=1.50 pot=19.83 Rg=7.846 SPS=2906
# chr11 loop
# ---
#
# bl=356 pos[1]=[8.4 -0.4 6.1] dr=0.95 t=0.0ps kin=1.52 pot=19.77 Rg=7.824 SPS=2805
# chr11 loop
# ---
#
# bl=357 pos[1]=[9.3 0.5 6.0] dr=0.94 t=0.0ps kin=1.54 pot=19.81 Rg=7.798 SPS=2825
# chr11 loop
# ---
#
# bl=358 pos[1]=[8.6 0.9 5.8] dr=0.94 t=0.0ps kin=1.49 pot=19.82 Rg=7.828 SPS=2744
# chr11 loop
# ---
#
# bl=359 pos[1]=[10.6 0.7 6.9] dr=0.94 t=0.0ps kin=1.52 pot=19.78 Rg=7.882 SPS=2860
# chr11 loop
# ---
#
# bl=360 pos[1]=[10.3 -0.7 7.7] dr=0.96 t=0.0ps kin=1.49 pot=19.80 Rg=7.921 SPS=2751
# chr11 loop
# ---
#
# bl=361 pos[1]=[10.5 -0.7 6.4] dr=0.98 t=0.0ps kin=1.51 pot=19.80 Rg=7.895 SPS=2751
# chr11 loop
# ---
#
# bl=362 pos[1]=[9.6 -2.5 5.8] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=7.869 SPS=2844
# chr11 loop
# ---
#
# bl=363 pos[1]=[9.0 -3.0 6.5] dr=0.92 t=0.0ps kin=1.51 pot=19.77 Rg=7.841 SPS=2440
# chr11 loop
# ---
#
# bl=364 pos[1]=[9.2 -3.4 5.8] dr=0.94 t=0.0ps kin=1.53 pot=19.76 Rg=7.810 SPS=2294
# chr11 loop
# ---
#
# bl=365 pos[1]=[8.2 -3.4 7.3] dr=0.94 t=0.0ps kin=1.52 pot=19.79 Rg=7.825 SPS=2749
# chr11 loop
# ---
#
# bl=366 pos[1]=[7.4 -2.7 7.5] dr=0.94 t=0.0ps kin=1.46 pot=19.79 Rg=7.861 SPS=2796
# chr11 loop
# ---
#
# bl=367 pos[1]=[7.6 -3.1 7.2] dr=0.95 t=0.0ps kin=1.50 pot=19.75 Rg=7.862 SPS=2730
# chr11 loop
# ---
#
# bl=368 pos[1]=[6.8 -3.1 6.5] dr=0.94 t=0.0ps kin=1.48 pot=19.78 Rg=7.827 SPS=2808
# chr11 loop
# ---
#
# bl=369 pos[1]=[7.7 -3.5 6.5] dr=0.93 t=0.0ps kin=1.50 pot=19.75 Rg=7.838 SPS=2776
# chr11 loop
# ---
#
# bl=370 pos[1]=[7.4 -4.0 6.5] dr=0.94 t=0.0ps kin=1.47 pot=19.79 Rg=7.839 SPS=2906
# chr11 loop
# ---
#
# bl=371 pos[1]=[6.7 -4.0 7.0] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=7.848 SPS=2854
# chr11 loop
# ---
#
# bl=372 pos[1]=[7.2 -3.7 7.0] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=7.836 SPS=2843
# chr11 loop
# ---
#
# bl=373 pos[1]=[7.1 -2.9 7.2] dr=0.92 t=0.0ps kin=1.51 pot=19.73 Rg=7.827 SPS=2945
# chr11 loop
# ---
#
# bl=374 pos[1]=[8.5 -2.4 7.9] dr=0.97 t=0.0ps kin=1.44 pot=19.79 Rg=7.857 SPS=2904
# chr11 loop
# ---
#
# bl=375 pos[1]=[8.0 -2.9 5.7] dr=0.94 t=0.0ps kin=1.48 pot=19.78 Rg=7.858 SPS=2930
# chr11 loop
# ---
#
# bl=376 pos[1]=[8.2 -2.3 5.5] dr=0.93 t=0.0ps kin=1.44 pot=19.80 Rg=7.866 SPS=2893
# ...
# chr11 loop
# ---
#
# bl=875 pos[1]=[9.6 -2.9 -4.9] dr=0.96 t=0.0ps kin=1.50 pot=19.78 Rg=7.763 SPS=2972
# chr11 loop
# ---
#
# bl=876 pos[1]=[7.6 -4.2 -4.7] dr=0.96 t=0.0ps kin=1.48 pot=19.77 Rg=7.764 SPS=2782
# chr11 loop
# ---
#
# bl=877 pos[1]=[7.2 -3.6 -4.7] dr=0.95 t=0.0ps kin=1.50 pot=19.75 Rg=7.764 SPS=2915
# chr11 loop
# ---
#
# bl=878 pos[1]=[7.3 -4.0 -4.3] dr=0.94 t=0.0ps kin=1.50 pot=19.81 Rg=7.690 SPS=2889
# chr11 loop
# ---
#
# bl=879 pos[1]=[6.8 -4.1 -5.4] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=7.664 SPS=2672
# chr11 loop
# ---
#
# bl=880 pos[1]=[7.0 -3.9 -6.0] dr=0.93 t=0.0ps kin=1.54 pot=19.75 Rg=7.664 SPS=2726
# chr11 loop
# ---
#
# bl=881 pos[1]=[7.6 -2.5 -5.8] dr=0.93 t=0.0ps kin=1.50 pot=19.75 Rg=7.709 SPS=2837
# chr11 loop
# ---
#
# bl=882 pos[1]=[8.1 -2.2 -5.4] dr=0.95 t=0.0ps kin=1.48 pot=19.74 Rg=7.735 SPS=2759
# chr11 loop
# ---
#
# bl=883 pos[1]=[8.7 -1.8 -4.1] dr=0.93 t=0.0ps kin=1.50 pot=19.74 Rg=7.708 SPS=2744
# chr11 loop
# ---
#
# bl=884 pos[1]=[11.3 -2.7 -3.9] dr=0.93 t=0.0ps kin=1.50 pot=19.75 Rg=7.695 SPS=2679
# chr11 loop
# ---
#
# bl=885 pos[1]=[10.7 -3.5 -3.2] dr=0.95 t=0.0ps kin=1.51 pot=19.74 Rg=7.687 SPS=2912
# chr11 loop
# ---
#
# bl=886 pos[1]=[10.8 -4.0 -3.0] dr=0.93 t=0.0ps kin=1.46 pot=19.74 Rg=7.713 SPS=2901
# chr11 loop
# ---
#
# bl=887 pos[1]=[10.8 -2.3 -2.7] dr=0.93 t=0.0ps kin=1.48 pot=19.78 Rg=7.712 SPS=2876
# chr11 loop
# ---
#
# bl=888 pos[1]=[10.7 -2.3 -0.8] dr=0.95 t=0.0ps kin=1.53 pot=19.74 Rg=7.683 SPS=2978
# chr11 loop
# ---
#
# bl=889 pos[1]=[10.3 -1.5 0.3] dr=0.95 t=0.0ps kin=1.49 pot=19.80 Rg=7.669 SPS=2878
# chr11 loop
# ---
#
# bl=890 pos[1]=[10.6 -1.4 -0.6] dr=0.95 t=0.0ps kin=1.47 pot=19.78 Rg=7.706 SPS=2980
# chr11 loop
# ---
#
# bl=891 pos[1]=[11.1 -2.4 0.0] dr=0.95 t=0.0ps kin=1.47 pot=19.77 Rg=7.721 SPS=2906
# chr11 loop
# ---
#
# bl=892 pos[1]=[10.5 -3.5 0.3] dr=0.97 t=0.0ps kin=1.50 pot=19.80 Rg=7.727 SPS=2643
# chr11 loop
# ---
#
# bl=893 pos[1]=[9.4 -4.1 -0.3] dr=0.95 t=0.0ps kin=1.52 pot=19.78 Rg=7.736 SPS=2825
# chr11 loop
# ---
#
# bl=894 pos[1]=[7.3 -3.6 0.1] dr=0.96 t=0.0ps kin=1.48 pot=19.80 Rg=7.718 SPS=2762
# chr11 loop
# ---
#
# bl=895 pos[1]=[6.2 -2.7 -0.5] dr=0.95 t=0.0ps kin=1.52 pot=19.76 Rg=7.688 SPS=2828
# chr11 loop
# ---
#
# bl=896 pos[1]=[6.8 -3.8 -0.0] dr=0.93 t=0.0ps kin=1.47 pot=19.78 Rg=7.706 SPS=2927
# chr11 loop
# ---
#
# bl=897 pos[1]=[7.0 -3.6 -0.6] dr=0.94 t=0.0ps kin=1.49 pot=19.83 Rg=7.744 SPS=2926
# chr11 loop
# ---
#
# bl=898 pos[1]=[6.9 -3.9 0.7] dr=0.98 t=0.0ps kin=1.49 pot=19.81 Rg=7.764 SPS=2864
# chr11 loop
# ---
#
# bl=899 pos[1]=[7.0 -3.4 1.6] dr=0.95 t=0.0ps kin=1.46 pot=19.79 Rg=7.687 SPS=2875
# chr11 loop
# ---
#
#
# Statistics for the simulation chr11, number of particles: 2703,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 0.03374725 -1.19876528  0.47010073]   Rg =  7.687455
#      median bond size is  0.9653403173462141
#      three shortest/longest (<10)/ bonds are  [0.876458   0.88003298 0.88439356]    [1.08097293 1.08350223 1.11865327]
#      95 percentile of distance to center is:    10.419284424660516
#      density of closest 95% monomers is:    0.5419601585025948
#      density of the core monomers is:    0.7016668528817535
#      min/median/mean/max coordinates are:
#      x: -9.98, 0.09, 0.03, 10.51
#      y: -11.72, -1.14, -1.20, 8.68
#      z: -11.13, 0.46, 0.47, 11.83
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4659956939822019 should be: 1.5
#      fastest particles are (in kT):  [ 6.54297788  7.02045921  7.07703295  7.16964514 10.24624139]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2702
#
# Potential Energy Ep =  19.78658695199778
# bl=900 pos[1]=[6.2 -3.3 1.3] dr=0.94 t=0.0ps kin=1.44 pot=19.77 Rg=7.630 SPS=2676
# chr11 loop
# ---
#
# bl=901 pos[1]=[6.5 -3.5 0.7] dr=0.92 t=0.0ps kin=1.48 pot=19.74 Rg=7.613 SPS=2867
# chr11 loop
# ---
#
# bl=902 pos[1]=[6.8 -3.5 0.5] dr=0.92 t=0.0ps kin=1.47 pot=19.78 Rg=7.648 SPS=2862
# chr11 loop
# ---
#
# bl=903 pos[1]=[7.6 -3.1 -0.2] dr=0.94 t=0.0ps kin=1.49 pot=19.83 Rg=7.723 SPS=2842
# chr11 loop
# ---
#
# bl=904 pos[1]=[8.0 -2.5 0.5] dr=0.96 t=0.0ps kin=1.54 pot=19.79 Rg=7.730 SPS=2834
# chr11 loop
# ---
#
# bl=905 pos[1]=[7.2 -2.0 -0.3] dr=0.96 t=0.0ps kin=1.53 pot=19.82 Rg=7.738 SPS=2796
# chr11 loop
# ---
#
# bl=906 pos[1]=[8.1 -2.6 0.6] dr=0.94 t=0.0ps kin=1.52 pot=19.79 Rg=7.717 SPS=2824
# chr11 loop
# ---
#
# bl=907 pos[1]=[8.4 -1.4 -0.6] dr=0.95 t=0.0ps kin=1.51 pot=19.81 Rg=7.700 SPS=2907
# chr11 loop
# ---
#
# bl=908 pos[1]=[10.0 -2.0 -0.1] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=7.706 SPS=2619
# chr11 loop
# ---
#
# bl=909 pos[1]=[10.8 -1.9 1.5] dr=0.95 t=0.0ps kin=1.48 pot=19.76 Rg=7.681 SPS=2733
# chr11 loop
# ---
#
# bl=910 pos[1]=[10.4 -1.7 1.5] dr=0.93 t=0.0ps kin=1.46 pot=19.76 Rg=7.684 SPS=2781
# chr11 loop
# ---
#
# bl=911 pos[1]=[11.5 0.2 1.6] dr=0.94 t=0.0ps kin=1.48 pot=19.74 Rg=7.686 SPS=2818
# chr11 loop
# ---
#
# bl=912 pos[1]=[9.9 0.6 1.7] dr=0.93 t=0.0ps kin=1.50 pot=19.69 Rg=7.683 SPS=2870
# chr11 loop
# ---
#
# bl=913 pos[1]=[10.0 1.0 1.7] dr=0.92 t=0.0ps kin=1.48 pot=19.69 Rg=7.721 SPS=2878
# chr11 loop
# ---
#
# bl=914 pos[1]=[9.5 2.4 0.8] dr=0.92 t=0.0ps kin=1.47 pot=19.75 Rg=7.765 SPS=2674
# chr11 loop
# ---
#
# bl=915 pos[1]=[8.4 2.3 2.4] dr=0.96 t=0.0ps kin=1.50 pot=19.75 Rg=7.768 SPS=2606
# chr11 loop
# ---
#
# bl=916 pos[1]=[8.2 2.8 2.5] dr=0.92 t=0.0ps kin=1.48 pot=19.75 Rg=7.778 SPS=2894
# chr11 loop
# ---
#
# bl=917 pos[1]=[8.0 3.4 2.6] dr=0.93 t=0.0ps kin=1.49 pot=19.81 Rg=7.797 SPS=2829
# chr11 loop
# ---
#
# bl=918 pos[1]=[8.5 3.0 2.0] dr=0.94 t=0.0ps kin=1.52 pot=19.78 Rg=7.803 SPS=2809
# chr11 loop
# ---
#
# bl=919 pos[1]=[10.3 0.8 3.5] dr=0.91 t=0.0ps kin=1.49 pot=19.79 Rg=7.793 SPS=2828
# chr11 loop
# ---
#
# bl=920 pos[1]=[8.8 -0.0 4.1] dr=0.93 t=0.0ps kin=1.48 pot=19.75 Rg=7.748 SPS=2849
# chr11 loop
# ---
#
# bl=921 pos[1]=[9.3 0.8 3.7] dr=0.94 t=0.0ps kin=1.46 pot=19.78 Rg=7.726 SPS=2723
# chr11 loop
# ---
#
# bl=922 pos[1]=[10.1 0.1 2.7] dr=0.92 t=0.0ps kin=1.47 pot=19.78 Rg=7.732 SPS=2551
# chr11 loop
# ---
#
# bl=923 pos[1]=[9.6 0.2 3.1] dr=0.95 t=0.0ps kin=1.53 pot=19.73 Rg=7.759 SPS=2834
# chr11 loop
# ---
#
# bl=924 pos[1]=[8.2 -0.9 3.8] dr=0.93 t=0.0ps kin=1.49 pot=19.75 Rg=7.741 SPS=2770
# chr11 loop
# ---
#
# bl=925 pos[1]=[9.3 -0.6 3.6] dr=0.95 t=0.0ps kin=1.49 pot=19.76 Rg=7.763 SPS=2741
# chr11 loop
# ---
#
# bl=926 pos[1]=[9.4 -2.8 3.4] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=7.791 SPS=2721
# chr11 loop
# ---
#
# bl=927 pos[1]=[9.1 -3.9 3.8] dr=0.96 t=0.0ps kin=1.53 pot=19.75 Rg=7.795 SPS=2782
# chr11 loop
# ---
#
# bl=928 pos[1]=[9.2 -4.7 3.4] dr=0.93 t=0.0ps kin=1.52 pot=19.78 Rg=7.809 SPS=2606
# chr11 loop
# ---
#
# bl=929 pos[1]=[10.1 -3.0 1.7] dr=0.96 t=0.0ps kin=1.48 pot=19.76 Rg=7.776 SPS=2768
# chr11 loop
# ---
#
# bl=930 pos[1]=[8.6 -0.7 0.9] dr=0.97 t=0.0ps kin=1.48 pot=19.78 Rg=7.754 SPS=2832
# chr11 loop
# ---
#
# bl=931 pos[1]=[8.4 -2.4 1.3] dr=0.93 t=0.0ps kin=1.50 pot=19.75 Rg=7.749 SPS=2742
# chr11 loop
# ---
#
# bl=932 pos[1]=[8.5 -1.7 1.5] dr=0.93 t=0.0ps kin=1.50 pot=19.77 Rg=7.742 SPS=2660
# chr11 loop
# ---
#
# bl=933 pos[1]=[8.2 -2.3 1.7] dr=0.96 t=0.0ps kin=1.46 pot=19.76 Rg=7.733 SPS=2941
# chr11 loop
# ---
#
# bl=934 pos[1]=[8.8 -0.4 2.1] dr=0.94 t=0.0ps kin=1.48 pot=19.78 Rg=7.725 SPS=2732
# chr11 loop
# ---
#
# bl=935 pos[1]=[9.6 0.5 1.6] dr=0.92 t=0.0ps kin=1.53 pot=19.77 Rg=7.741 SPS=2827
# chr11 loop
# ---
#
# bl=936 pos[1]=[9.8 0.5 1.5] dr=0.95 t=0.0ps kin=1.50 pot=19.81 Rg=7.751 SPS=2683
# chr11 loop
# ---
#
# bl=937 pos[1]=[10.2 1.8 0.5] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=7.748 SPS=2753
# chr11 loop
# ---
#
# bl=938 pos[1]=[9.2 1.4 1.0] dr=0.94 t=0.0ps kin=1.50 pot=19.73 Rg=7.740 SPS=2856
# chr11 loop
# ---
#
# bl=939 pos[1]=[7.5 -1.0 1.0] dr=0.92 t=0.0ps kin=1.50 pot=19.74 Rg=7.737 SPS=2959
# chr11 loop
# ---
#
# bl=940 pos[1]=[7.5 -1.6 0.1] dr=0.93 t=0.0ps kin=1.45 pot=19.77 Rg=7.739 SPS=2658
# chr11 loop
# ---
#
# bl=941 pos[1]=[7.2 -2.3 0.2] dr=0.94 t=0.0ps kin=1.47 pot=19.78 Rg=7.752 SPS=2876
# chr11 loop
# ---
#
# bl=942 pos[1]=[7.5 -1.8 0.5] dr=0.94 t=0.0ps kin=1.48 pot=19.80 Rg=7.737 SPS=2777
# chr11 loop
# ---
#
# bl=943 pos[1]=[7.9 -1.5 0.5] dr=0.92 t=0.0ps kin=1.51 pot=19.76 Rg=7.711 SPS=2753
# chr11 loop
# ---
#
# bl=944 pos[1]=[8.7 -0.3 0.9] dr=0.96 t=0.0ps kin=1.51 pot=19.75 Rg=7.683 SPS=2823
# chr11 loop
# ---
#
# bl=945 pos[1]=[8.6 1.2 1.5] dr=0.95 t=0.0ps kin=1.50 pot=19.74 Rg=7.710 SPS=2860
# chr11 loop
# ---
#
# bl=946 pos[1]=[7.7 1.6 0.5] dr=0.93 t=0.0ps kin=1.46 pot=19.79 Rg=7.789 SPS=2978
# chr11 loop
# ---
#
# bl=947 pos[1]=[6.6 2.8 1.8] dr=0.94 t=0.0ps kin=1.54 pot=19.78 Rg=7.809 SPS=2823
# chr11 loop
# ---
#
# bl=948 pos[1]=[7.3 3.2 2.4] dr=0.95 t=0.0ps kin=1.50 pot=19.82 Rg=7.815 SPS=2627
# chr11 loop
# ---
#
# bl=949 pos[1]=[6.8 3.3 1.3] dr=0.95 t=0.0ps kin=1.47 pot=19.82 Rg=7.818 SPS=2909
# chr11 loop
# ---
#
#
# Statistics for the simulation chr11, number of particles: 2703,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.16717016 -0.83235189  0.17953186]   Rg =  7.8182583
#      median bond size is  0.9649773782911717
#      three shortest/longest (<10)/ bonds are  [0.87033937 0.87489686 0.88094811]    [1.09554544 1.12268342 1.12654944]
#      95 percentile of distance to center is:    10.893925651830585
#      density of closest 95% monomers is:    0.47416317325279933
#      density of the core monomers is:    0.6803486007208971
#      min/median/mean/max coordinates are:
#      x: -9.67, -0.29, -0.17, 10.26
#      y: -11.53, -0.71, -0.83, 8.77
#      z: -11.67, 0.47, 0.18, 12.68
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4749665914476344 should be: 1.5
#      fastest particles are (in kT):  [6.91522191 7.43698846 7.61905975 7.7979177  8.6152771 ]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2702
#
# Potential Energy Ep =  19.816095541990382
# bl=950 pos[1]=[7.9 2.8 0.4] dr=0.96 t=0.0ps kin=1.49 pot=19.77 Rg=7.792 SPS=2802
# chr11 loop
# ---
#
# bl=951 pos[1]=[8.4 2.3 1.2] dr=0.94 t=0.0ps kin=1.53 pot=19.76 Rg=7.791 SPS=2941
# chr11 loop
# ---
#
# bl=952 pos[1]=[8.1 2.0 0.7] dr=0.96 t=0.0ps kin=1.45 pot=19.76 Rg=7.831 SPS=2941
# chr11 loop
# ---
#
# bl=953 pos[1]=[7.4 0.8 0.7] dr=0.95 t=0.0ps kin=1.45 pot=19.76 Rg=7.830 SPS=2907
# chr11 loop
# ---
#
# bl=954 pos[1]=[6.7 0.8 0.3] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=7.763 SPS=2660
# chr11 loop
# ---
#
# bl=955 pos[1]=[7.1 0.1 0.2] dr=0.95 t=0.0ps kin=1.51 pot=19.75 Rg=7.775 SPS=2762
# chr11 loop
# ---
#
# bl=956 pos[1]=[7.0 0.4 0.6] dr=0.94 t=0.0ps kin=1.52 pot=19.75 Rg=7.802 SPS=2941
# chr11 loop
# ---
#
# bl=957 pos[1]=[6.4 -0.2 0.5] dr=0.94 t=0.0ps kin=1.48 pot=19.78 Rg=7.826 SPS=2857
# chr11 loop
# ---
#
# bl=958 pos[1]=[7.8 0.4 0.8] dr=0.96 t=0.0ps kin=1.51 pot=19.75 Rg=7.821 SPS=2890
# chr11 loop
# ---
#
# bl=959 pos[1]=[7.6 -0.4 0.4] dr=0.95 t=0.0ps kin=1.49 pot=19.77 Rg=7.794 SPS=2793
# chr11 loop
# ---
#
# bl=960 pos[1]=[8.1 1.2 0.9] dr=0.93 t=0.0ps kin=1.52 pot=19.76 Rg=7.744 SPS=2841
# chr11 loop
# ---
#
# bl=961 pos[1]=[7.9 0.3 0.7] dr=0.95 t=0.0ps kin=1.50 pot=19.76 Rg=7.760 SPS=2646
# chr11 loop
# ---
#
# bl=962 pos[1]=[7.5 0.1 0.0] dr=0.96 t=0.0ps kin=1.51 pot=19.78 Rg=7.773 SPS=2778
# chr11 loop
# ---
#
# bl=963 pos[1]=[8.0 0.7 -0.1] dr=0.95 t=0.0ps kin=1.50 pot=19.77 Rg=7.736 SPS=2762
# chr11 loop
# ---
#
# bl=964 pos[1]=[8.4 1.6 -0.8] dr=0.95 t=0.0ps kin=1.52 pot=19.77 Rg=7.682 SPS=2825
# chr11 loop
# ---
#
# bl=965 pos[1]=[7.9 3.5 0.2] dr=0.95 t=0.0ps kin=1.51 pot=19.75 Rg=7.679 SPS=2793
# chr11 loop
# ---
#
# bl=966 pos[1]=[7.8 2.1 0.8] dr=0.95 t=0.0ps kin=1.51 pot=19.78 Rg=7.726 SPS=2701
# chr11 loop
# ---
#
# bl=967 pos[1]=[9.7 4.0 1.0] dr=0.93 t=0.0ps kin=1.53 pot=19.78 Rg=7.735 SPS=2557
# chr11 loop
# ---
#
# bl=968 pos[1]=[9.5 3.3 2.4] dr=0.94 t=0.0ps kin=1.52 pot=19.73 Rg=7.715 SPS=2706
# chr11 loop
# ---
#
# bl=969 pos[1]=[9.3 3.9 3.0] dr=0.97 t=0.0ps kin=1.54 pot=19.75 Rg=7.739 SPS=2774
# chr11 loop
# ---
#
# bl=970 pos[1]=[8.9 3.4 2.3] dr=0.93 t=0.0ps kin=1.51 pot=19.76 Rg=7.790 SPS=2760
# chr11 loop
# ---
#
# bl=971 pos[1]=[9.0 4.0 3.3] dr=0.93 t=0.0ps kin=1.51 pot=19.78 Rg=7.804 SPS=2747
# chr11 loop
# ---
#
# bl=972 pos[1]=[9.0 3.9 3.4] dr=0.95 t=0.0ps kin=1.55 pot=19.74 Rg=7.782 SPS=2714
# chr11 loop
# ---
#
# bl=973 pos[1]=[9.5 2.2 3.5] dr=0.92 t=0.0ps kin=1.48 pot=19.75 Rg=7.786 SPS=2603
# chr11 loop
# ---
#
# bl=974 pos[1]=[8.7 3.4 4.3] dr=0.93 t=0.0ps kin=1.48 pot=19.75 Rg=7.763 SPS=2742
# chr11 loop
# ---
#
# bl=975 pos[1]=[8.9 3.6 2.9] dr=0.95 t=0.0ps kin=1.47 pot=19.76 Rg=7.740 SPS=2715
# chr11 loop
# ---
#
# bl=976 pos[1]=[8.9 3.4 3.6] dr=0.93 t=0.0ps kin=1.48 pot=19.70 Rg=7.733 SPS=2751
# chr11 loop
# ---
#
# bl=977 pos[1]=[8.1 3.5 3.0] dr=0.93 t=0.0ps kin=1.47 pot=19.72 Rg=7.709 SPS=2784
# chr11 loop
# ---
#
# bl=978 pos[1]=[7.3 4.0 3.6] dr=0.93 t=0.0ps kin=1.43 pot=19.75 Rg=7.711 SPS=2701
# chr11 loop
# ---
#
# bl=979 pos[1]=[8.3 3.5 3.6] dr=0.93 t=0.0ps kin=1.48 pot=19.72 Rg=7.718 SPS=2627
# chr11 loop
# ---
#
# bl=980 pos[1]=[9.6 2.9 4.0] dr=0.94 t=0.0ps kin=1.49 pot=19.74 Rg=7.738 SPS=2736
# chr11 loop
# ---
#
# bl=981 pos[1]=[8.5 3.7 3.9] dr=0.95 t=0.0ps kin=1.46 pot=19.74 Rg=7.742 SPS=2724
# chr11 loop
# ---
#
# bl=982 pos[1]=[8.1 3.4 5.8] dr=0.93 t=0.0ps kin=1.47 pot=19.73 Rg=7.745 SPS=2677
# chr11 loop
# ---
#
# bl=983 pos[1]=[6.3 3.9 4.9] dr=0.93 t=0.0ps kin=1.49 pot=19.73 Rg=7.743 SPS=2633
# chr11 loop
# ---
#
# bl=984 pos[1]=[5.7 5.6 5.1] dr=0.95 t=0.0ps kin=1.47 pot=19.75 Rg=7.764 SPS=2708
# chr11 loop
# ---
#
# bl=985 pos[1]=[5.7 5.1 4.0] dr=0.95 t=0.0ps kin=1.50 pot=19.81 Rg=7.788 SPS=2604
# chr11 loop
# ---
#
# bl=986 pos[1]=[4.8 3.7 4.6] dr=0.97 t=0.0ps kin=1.51 pot=19.75 Rg=7.776 SPS=2750
# chr11 loop
# ---
#
# bl=987 pos[1]=[3.5 2.4 4.9] dr=0.96 t=0.0ps kin=1.46 pot=19.75 Rg=7.768 SPS=2749
# chr11 loop
# ---
#
# bl=988 pos[1]=[4.4 2.6 4.8] dr=0.92 t=0.0ps kin=1.48 pot=19.74 Rg=7.762 SPS=2724
# chr11 loop
# ---
#
# bl=989 pos[1]=[5.4 4.4 5.4] dr=0.93 t=0.0ps kin=1.49 pot=19.74 Rg=7.719 SPS=2696
# chr11 loop
# ---
#
# bl=990 pos[1]=[4.5 3.6 5.7] dr=0.93 t=0.0ps kin=1.52 pot=19.75 Rg=7.718 SPS=2466
# chr11 loop
# ---
#
# bl=991 pos[1]=[5.3 2.7 5.8] dr=0.95 t=0.0ps kin=1.49 pot=19.77 Rg=7.752 SPS=2754
# chr11 loop
# ---
#
# bl=992 pos[1]=[5.8 2.6 5.3] dr=0.95 t=0.0ps kin=1.53 pot=19.72 Rg=7.762 SPS=2793
# chr11 loop
# ---
#
# bl=993 pos[1]=[6.5 1.1 6.0] dr=0.94 t=0.0ps kin=1.54 pot=19.72 Rg=7.751 SPS=2688
# chr11 loop
# ---
#
# bl=994 pos[1]=[6.7 0.8 5.7] dr=0.94 t=0.0ps kin=1.50 pot=19.77 Rg=7.718 SPS=2747
# chr11 loop
# ---
#
# bl=995 pos[1]=[7.0 1.2 5.0] dr=0.94 t=0.0ps kin=1.50 pot=19.74 Rg=7.711 SPS=2762
# chr11 loop
# ---
#
# bl=996 pos[1]=[7.2 1.2 3.9] dr=0.94 t=0.0ps kin=1.49 pot=19.74 Rg=7.716 SPS=2577
# chr11 loop
# ---
#
# bl=997 pos[1]=[8.0 1.4 3.7] dr=0.94 t=0.0ps kin=1.47 pot=19.74 Rg=7.696 SPS=2818
# chr11 loop
# ---
#
# bl=998 pos[1]=[9.9 1.6 2.0] dr=0.95 t=0.0ps kin=1.49 pot=19.75 Rg=7.702 SPS=2833
# chr11 loop
# ---
#
# bl=999 pos[1]=[10.4 1.4 3.1] dr=0.95 t=0.0ps kin=1.49 pot=19.80 Rg=7.747 SPS=2825
# chr11 loop
# ---
#
#
# Statistics for the simulation chr11, number of particles: 2703,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.18914361 -0.52706387 -0.1624549 ]   Rg =  7.74661
#      median bond size is  0.9635508832109887
#      three shortest/longest (<10)/ bonds are  [0.86690312 0.87897883 0.88172718]    [1.09415897 1.09422408 1.11266439]
#      95 percentile of distance to center is:    10.564294900882093
#      density of closest 95% monomers is:    0.5199474992495524
#      density of the core monomers is:    0.7345888181903557
#      min/median/mean/max coordinates are:
#      x: -10.31, -0.21, -0.19, 11.72
#      y: -11.03, -0.42, -0.53, 9.17
#      z: -10.73, -0.20, -0.16, 9.97
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4951761512690347 should be: 1.5
#      fastest particles are (in kT):  [7.98919643 8.1181098  8.3651123  8.39327012 9.07127779]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosome']
#      Number of exceptions:   2702
#
# Potential Energy Ep =  19.795883624676286
# bl=1000 pos[1]=[9.4 0.9 2.5] dr=0.97 t=0.0ps kin=1.48 pot=19.77 Rg=7.777 SPS=2837
# chr11 loop
# ---
#
# 7.776944

# %% [markdown]
# ___

# %% [markdown]
# **SYSTEM SIM**
# this is done after setting up the collapse simulations of both chromosome 10 and 11 separately

# %%
# once the collapse simulations are done, the collapsed structures of each chromosome should be included in the same simulation system
# SETTING UP SIMULATION VARIABLE INIT
sim_chr10_chr11 = MiChroM(name="chr10_chr11", temperature=1.0, time_step=0.01)
sim_chr10_chr11.setup(platform="cuda")
sim_chr10_chr11.saveFolder('multi_op_chr10_11_allFrames')


# The function loadNDB receives a list of files and saves the chromosome collapse structures in the variable Struc_chr10_chr11.
struc_chr10_chr11 = sim_chr10_chr11.loadNDB(NDBfiles=[
    'multi_op_chr10_11_allFrames/chr10_0_block1000.ndb', 
    'multi_op_chr10_11_allFrames/chr11_0_block1000.ndb'
])
# Out:
#     ***************************************************************************************
#      **** **** *** *** *** *** *** *** OpenMiChroM-1.0.5 *** *** *** *** *** *** **** ****
#
#          OpenMiChroM is a Python library for performing chromatin dynamics simulations.
#                             OpenMiChroM uses the OpenMM Python API,
#                 employing the MiChroM (Minimal Chromatin Model) energy function.
#       The chromatin dynamics simulations generate an ensemble of 3D chromosomal structures
#       that are consistent with experimental Hi-C maps, also allows simulations of a single
#                  or multiple chromosome chain using High-Performance Computing
#                             in different platforms (GPUs and CPUs).
#          OpenMiChroM documentation is available at https://open-michrom.readthedocs.io
#
#          OpenMiChroM is described in: Oliveira Junior, A. B & Contessoto, V, G et. al.
#       A Scalable Computational Approach for Simulating Complexes of Multiple Chromosomes.
#                   Journal of Molecular Biology. doi:10.1016/j.jmb.2020.10.034.
#                                               and
#                                  Oliveira Junior, A. B. et al.
#      Chromosome Modeling on Downsampled Hi-C Maps Enhances the Compartmentalization Signal.
#                         J. Phys. Chem. B, doi:10.1021/acs.jpcb.1c04174.
#
#                     Copyright (c) 2022, The OpenMiChroM development team at
#                                         Rice University
#     ***************************************************************************************
# Chains:  [(0, 2711, 0), (2712, 5414, 0)]

# %% [markdown]
# **Chains:  [(0, 2711, 0), (2712, 5414, 0)]**
# * mol_1 from idx = 0 &rarr; idx = 2711
# * mol_2 from idx = 2712 &rarr; idx = 5414
# ___

# %%
# distribute the chromosome chains
# essential for randomizing the initial condition when simulating different replicas

# Struc_chr10_chr11 = sim_chr10_chr11.setFibPosition(Struc_chr10_chr11, dist=(1.5,3.0))
# 'dist' PARAMETER IS NOT DEFINED IN THE LIBRARY

struc_chr10_chr11 = sim_chr10_chr11.setFibPosition(struc_chr10_chr11)
sim_chr10_chr11.loadStructure(struc_chr10_chr11, center=True)
sim_chr10_chr11.saveStructure(mode='ndb')
sim_chr10_chr11.saveStructure(mode='pdb')

# %%
# ADDING FORCES TO THE SIM STRUCTURES
sim_chr10_chr11.addFENEBonds(kfb=30.0)
sim_chr10_chr11.addAngles(ka=2.0)
sim_chr10_chr11.addRepulsiveSoftCore(Ecut=4.0)
sim_chr10_chr11.addFlatBottomHarmonic(n_rad=20)

# The addTypetoType interaction is independent of the chromosome chain and only depends on the loci types. This potential is added for both chains simultaneously.
sim_chr10_chr11.addTypetoType(mu=3.22, rc = 1.78)

# The function addMultiChainIC receives the chromosome chain and adds the IC potential.
sim_chr10_chr11.addMultiChainIC(chainIndex=0, mu=3.22, rc = 1.78, dinit=3, dend=500)
sim_chr10_chr11.addMultiChainIC(chainIndex=1, mu=3.22, rc = 1.78, dinit=3, dend=500)

# %%
# run the production simulation
sim_chr10_chr11.initStorage('traj_chr10_chr11_allFrames', mode='w')
pdb = PDBFile(
    'multi_op_chr10_11_allFrames/chr10_chr11_0_block0.pdb',
    'multi_op_chr10_11_allFrames/chr10_chr11_1_block0.pdb'
) # check file path

top = pdb.getTopology()
top_file = 'multi_top_allFrames.dcd'

with open(top_file, 'wb') as f:
    dcd = DCDFile(f, top, 0.01)
    print('RUNNING SIMULATION', '\n---\n')
    for _ in range(n_blocks):
        sim_chr10_chr11.runSimBlock(block) 
        sim_chr10_chr11.saveStructure()
        sim_chr10_chr11.saveStructure(mode='pdb')
        dcd.writeModel(sim_chr10_chr11.getPositions())
        print('3rd loop', '\n---\n')

sim_chr10_chr11.storage[0].close() #close the cndb file for chr10
sim_chr10_chr11.storage[1].close() #close the cndb file for chr11
sim_chr10_chr11.saveStructure(mode="ndb")
sim_chr10_chr11.saveStructure(mode="pdb")
# Out:
# RUNNING SIMULATION
# ---
#
# Number of exceptions: 5413
# adding force  FENEBond 0
# adding force  AngleForce 1
# Add exclusions for RepulsiveSoftCore force
# adding force  RepulsiveSoftCore 2
# adding force  FlatBottomHarmonic 3
# Add exclusions for TypetoType force
# adding force  TypetoType 4
# Add exclusions for IdealChromosomeChain0 force
# adding force  IdealChromosomeChain0 5
# Add exclusions for IdealChromosomeChain1 force
# adding force  IdealChromosomeChain1 6
# Positions...
#  loaded!
# potential energy is 19.788648
# bl=1 pos[1]=[-5.5 -9.7 25.1] dr=0.93 t=0.0ps kin=1.50 pot=19.81 Rg=20.228 SPS=1861
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3760\2272066737.py in <module>
#      16         sim_chr10_chr11.saveStructure()
#      17         sim_chr10_chr11.saveStructure(mode='pdb')
# ---> 18         dcd.writeModel(sim_chr10_chr11.getPositions())
#      19         print('3rd loop', '\n---\n')
#      20
#
# ~\anaconda3\lib\site-packages\openmm\app\dcdfile.py in writeModel(self, positions, unitCellDimensions, periodicBoxVectors)
#     119         """
#     120         if len(list(self._topology.atoms())) != len(positions):
# --> 121             raise ValueError('The number of positions must match the number of atoms')
#     122         if is_quantity(positions):
#     123             positions = positions.value_in_unit(nanometers)
#
# ValueError: The number of positions must match the number of atoms

# %% [markdown]
# **ERROR**
# previous cell gives this error &rarr; `ValueError: The number of positions must match the number of atoms`
# at this line &rarr; `dcd.writeModel(sim_chr10_chr11.getPositions())`
# ___

# %% [markdown]
# **checking a few things**

# %%
# TESTING WITH loadNDB
struc_chr10_chr11 = sim_chr10_chr11.loadNDB(NDBfiles=[
    'multi_op_chr10_11_allFrames/chr10_0_block1000.ndb', 
    'multi_op_chr10_11_allFrames/chr11_0_block1000.ndb'
])
print('with loadNDB():')
print(struc_chr10_chr11.shape)
print(type(struc_chr10_chr11))
print(struc_chr10_chr11)
# Out:
# Chains:  [(0, 2711, 0), (2712, 5414, 0)]
# with loadNDB():
# (5415, 3)
# <class 'numpy.ndarray'>
# [[ -2.466  -2.271  11.98 ]
#  [ -1.975  -3.083  11.722]
#  [ -1.353  -3.381  11.076]
#  ...
#  [  6.258 -10.274  -0.412]
#  [  5.321 -10.233  -0.633]
#  [  4.458 -10.783  -0.787]]

# %%
# TESTING WITH loadPDB
struc_chr10_chr11 = sim_chr10_chr11.loadPDB(PDBfiles=[
    'multi_op_chr10_11_allFrames/chr10_0_block1000.pdb', 
    'multi_op_chr10_11_allFrames/chr11_0_block1000.pdb'
])
print('with loadPDB():')
print(struc_chr10_chr11.shape)
print(type(struc_chr10_chr11))
print(struc_chr10_chr11)
# Out:
# Chains:  [(0, 2711, 0), (2712, 5414, 0)]
# with loadPDB():
# (5415, 3)
# <class 'numpy.ndarray'>
# [[ -2.466  -2.271  11.98 ]
#  [ -1.975  -3.083  11.722]
#  [ -1.353  -3.381  11.076]
#  ...
#  [  6.258 -10.274  -0.412]
#  [  5.321 -10.233  -0.633]
#  [  4.458 -10.783  -0.787]]

# %% [markdown]
# ---
# so now we know that both file loaders load the same values with the same structures

# %%
print(type(sim_chr10_chr11))
print(sim_chr10_chr11)
# Out:
# <class 'OpenMiChroM.ChromDynamics.MiChroM'>
# <OpenMiChroM.ChromDynamics.MiChroM object at 0x0000028CACA52730>

# %% [markdown]
# `struc_chr10_chr11` &rarr; array of molecule structure
# `sim_chr10_chr11` &rarr; simulation variable &rarr; loads variable of array structure

# %%
positions = sim_chr10_chr11.getPositions()
print('concerning sim_chr10_chr11:')
print(type(positions))
print(positions.shape)
print(positions)
# Out:
# concerning sim_chr10_chr11:
# <class 'numpy.ndarray'>
# (5415, 3)
# [[ -5.4840245   -9.707231    25.119858  ]
#  [ -5.335743   -10.554476    25.484241  ]
#  [ -5.1677423  -11.397454    25.014368  ]
#  ...
#  [  8.778797     0.43869022 -17.10517   ]
#  [  8.29467      0.42137846 -16.229094  ]
#  [  7.625365     0.8336093  -15.681841  ]]

# %% [markdown]
# **Remember :** `Chains` end at idx 5414 &rarr; `shape[0]` = 5415

# %%
pdb = PDBFile(
    'multi_op_chr10_11_allFrames/chr10_chr11_0_block0.pdb',
    'multi_op_chr10_11_allFrames/chr10_chr11_1_block0.pdb'
)
print('concerning PDBFile method:')
print(pdb)
print(len(pdb.getPositions()))
# Out:
# concerning PDBFile method:
# <openmm.app.pdbfile.PDBFile object at 0x0000028CACA619A0>
# 2712

# %% [markdown]
# **Notice :**
# * pdb variable has `shape[0]` = 2712 &rarr; only reading first file
# * `loadPDB` &rarr; returns array
# * `PDBFile` &rarr; returns PDBFile object

# %% [markdown]
# **POSSIBLE SOLUTIONS :**
# 1. read each file separately as `.pdb` &rarr; concatenate both files as `.pdb`
# 2. read both files together as arrays &rarr; convert array to pdb object
# ___

# %% [markdown]
# **FIRST APPROACH**
# read each file separately as `.pdb` &rarr; concatenate both files as `.pdb`

# %%
pdb_10 = PDBFile('multi_op_chr10_11_allFrames/chr10_chr11_0_block0.pdb')
pdb_11 = PDBFile('multi_op_chr10_11_allFrames/chr10_chr11_1_block0.pdb')
print('pdb_10 length = ', len(pdb_10.getPositions()))
print('pdb_11 length = ', len(pdb_11.getPositions()))

temp_arr = np.array(pdb_10.getPositions())
print('temp_arr shape = ', temp_arr.shape)
# temp_pdb = PDBFile(temp_arr)    # 'numpy.ndarray' object has no attribute 'decode'

top_10 = pdb_10.getTopology()
top_11 = pdb_11.getTopology()
print('top_10 type = ', type(top_10))
print(top_10.chains)
# Out:
# pdb_10 length =  2712
# pdb_11 length =  2703
# temp_arr shape =  (2712, 3)
# top_10 type =  <class 'openmm.app.topology.Topology'>
# <bound method Topology.chains of <Topology; 1 chains, 2712 residues, 2712 atoms, 0 bonds>>

# %% [markdown]
# ___

# %%
from Bio import PDB

pdb_io = PDB.PDBIO()

structures = ['multi_op_chr10_11_allFrames/chr10_chr11_0_block0.pdb','multi_op_chr10_11_allFrames/chr10_chr11_1_block0.pdb']

pdb_file = 'all_struc.pdb'
with pdb_file as open_file:
    for struct in structures:
        pdb_io.set_structure(struct)
        pdb_io.save(open_file)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3760\3968088220.py in <module>
#       6
#       7 pdb_file = 'all_struc.pdb'
# ----> 8 with pdb_file as open_file:
#       9     for struct in structures:
#      10         pdb_io.set_structure(struct)
#
# AttributeError: __enter__

# %% [markdown]
# &uarr; undiagnosed error
# ___

# %%
from Bio.PDB import PDBParser
from Bio.PDB.PDBIO import PDBIO
parser = PDBParser()
structure = parser.get_structure("ch10", "multi_op_chr10_11_allFrames/chr10_chr11_0_block0.pdb")
structure2 = parser.get_structure("ch11", "multi_op_chr10_11_allFrames/chr10_chr11_1_block0.pdb")

io=PDBIO()
io.set_structure(structure)
io.save("bio-pdb-pdbio-out.pdb")
io.set_structure(structure2)
io.save("bio-pdb-pdbio-out.pdb")

# %% [markdown]
# &uarr; overwrites exsiting file
# ___

# %% [markdown]
# **when trying to combine `.pdb` files with _Chimera_**

# %%
test_pdb = PDBFile('multi_op_chr10_11_allFrames/comb.pdb')
test_pos = test_pdb.getPositions()
len(test_pos)
# Out:
# 2712

# %% [markdown]
# **Notice :** _Chimera_'s saved file has a similar issue of saving only the first file
# ___

# %% [markdown]
# **when trying to combine `.pdb` files with _PyMOL_**

# %%
test_pdb = PDBFile('multi_op_chr10_11_allFrames/chr10_chr11_combined_pymol.pdb')
test_pos = test_pdb.getPositions()
len(test_pos)
# Out:
# 5415

# %% [markdown]
# **Notice :** _PyMOL_'s saved file has successfully combined both files into one **BUT** with the wrong dimensions
# ___

# %% [markdown]
# **SECOND APPROACH**
# read both files together as arrays &rarr; convert array to pdb object

# %% [markdown]
# ___

# %% [markdown]
# **Testing production simulation with newly generated `.pdb` file**

# %%
sim_chr10_chr11 = MiChroM(name="chr10_chr11", temperature=1.0, time_step=0.01)
sim_chr10_chr11.setup(platform="cuda")
sim_chr10_chr11.saveFolder('multi_op_chr10_11_allFrames')
struc_chr10_chr11 = sim_chr10_chr11.loadNDB(NDBfiles=[
    'multi_op_chr10_11_allFrames/chr10_0_block1000.ndb', 
    'multi_op_chr10_11_allFrames/chr11_0_block1000.ndb'
])
# Out:
#     ***************************************************************************************
#      **** **** *** *** *** *** *** *** OpenMiChroM-1.0.5 *** *** *** *** *** *** **** ****
#
#          OpenMiChroM is a Python library for performing chromatin dynamics simulations.
#                             OpenMiChroM uses the OpenMM Python API,
#                 employing the MiChroM (Minimal Chromatin Model) energy function.
#       The chromatin dynamics simulations generate an ensemble of 3D chromosomal structures
#       that are consistent with experimental Hi-C maps, also allows simulations of a single
#                  or multiple chromosome chain using High-Performance Computing
#                             in different platforms (GPUs and CPUs).
#          OpenMiChroM documentation is available at https://open-michrom.readthedocs.io
#
#          OpenMiChroM is described in: Oliveira Junior, A. B & Contessoto, V, G et. al.
#       A Scalable Computational Approach for Simulating Complexes of Multiple Chromosomes.
#                   Journal of Molecular Biology. doi:10.1016/j.jmb.2020.10.034.
#                                               and
#                                  Oliveira Junior, A. B. et al.
#      Chromosome Modeling on Downsampled Hi-C Maps Enhances the Compartmentalization Signal.
#                         J. Phys. Chem. B, doi:10.1021/acs.jpcb.1c04174.
#
#                     Copyright (c) 2022, The OpenMiChroM development team at
#                                         Rice University
#     ***************************************************************************************
# Chains:  [(0, 2711, 0), (2712, 5414, 0)]

# %%
struc_chr10_chr11 = sim_chr10_chr11.setFibPosition(struc_chr10_chr11)
sim_chr10_chr11.loadStructure(struc_chr10_chr11, center=True)
sim_chr10_chr11.saveStructure(mode='ndb')
sim_chr10_chr11.saveStructure(mode='pdb')

# %%
sim_chr10_chr11.addFENEBonds(kfb=30.0)
sim_chr10_chr11.addAngles(ka=2.0)
sim_chr10_chr11.addRepulsiveSoftCore(Ecut=4.0)
sim_chr10_chr11.addFlatBottomHarmonic(n_rad=20)
sim_chr10_chr11.addTypetoType(mu=3.22, rc = 1.78)
sim_chr10_chr11.addMultiChainIC(chainIndex=0, mu=3.22, rc = 1.78, dinit=3, dend=500)
sim_chr10_chr11.addMultiChainIC(chainIndex=1, mu=3.22, rc = 1.78, dinit=3, dend=500)

# %%
# run the production simulation
sim_chr10_chr11.initStorage('traj_chr10_chr11_allFrames', mode='w')
pdb = PDBFile('multi_op_chr10_11_allFrames/chr10_chr11_combined_pymol.pdb')

top = pdb.getTopology()
top_file = 'multi_top_allFrames.dcd'

with open(top_file, 'wb') as f:
    dcd = DCDFile(f, top, 0.01)
    print('RUNNING SIMULATION', '\n---\n')
    for _ in range(n_blocks):
        sim_chr10_chr11.runSimBlock(block) 
        sim_chr10_chr11.saveStructure()
        sim_chr10_chr11.saveStructure(mode='pdb')
        dcd.writeModel(sim_chr10_chr11.getPositions())
        print('3rd loop', '\n---\n')

sim_chr10_chr11.storage[0].close() #close the cndb file for chr10
sim_chr10_chr11.storage[1].close() #close the cndb file for chr11
sim_chr10_chr11.saveStructure(mode="ndb")
sim_chr10_chr11.saveStructure(mode="pdb")
# Out:
# RUNNING SIMULATION
# ---
#
# Number of exceptions: 5413
# adding force  FENEBond 0
# adding force  AngleForce 1
# Add exclusions for RepulsiveSoftCore force
# adding force  RepulsiveSoftCore 2
# adding force  FlatBottomHarmonic 3
# Add exclusions for TypetoType force
# adding force  TypetoType 4
# Add exclusions for IdealChromosomeChain0 force
# adding force  IdealChromosomeChain0 5
# Add exclusions for IdealChromosomeChain1 force
# adding force  IdealChromosomeChain1 6
# Positions...
#  loaded!
# potential energy is 19.779928
# bl=1 pos[1]=[-14.9 -11.3 3.8] dr=0.96 t=0.0ps kin=1.55 pot=19.75 Rg=19.427 SPS=1929
# 3rd loop
# ---
#
# bl=2 pos[1]=[-14.9 -12.2 4.6] dr=0.94 t=0.0ps kin=1.51 pot=19.80 Rg=19.419 SPS=2166
# 3rd loop
# ---
#
# bl=3 pos[1]=[-17.9 -14.2 4.4] dr=0.95 t=0.0ps kin=1.53 pot=19.77 Rg=19.400 SPS=2131
# 3rd loop
# ---
#
# bl=4 pos[1]=[-15.8 -12.8 4.2] dr=0.95 t=0.0ps kin=1.50 pot=19.78 Rg=19.393 SPS=2222
# 3rd loop
# ---
#
# bl=5 pos[1]=[-16.9 -13.6 3.9] dr=0.95 t=0.0ps kin=1.47 pot=19.80 Rg=19.376 SPS=2252
# 3rd loop
# ---
#
# bl=6 pos[1]=[-16.7 -13.3 2.9] dr=0.94 t=0.0ps kin=1.52 pot=19.78 Rg=19.319 SPS=2374
# 3rd loop
# ---
#
# bl=7 pos[1]=[-16.0 -13.9 2.3] dr=0.94 t=0.0ps kin=1.51 pot=19.79 Rg=19.273 SPS=2301
# 3rd loop
# ---
#
# bl=8 pos[1]=[-15.7 -14.5 2.2] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=19.229 SPS=2346
# 3rd loop
# ---
#
# bl=9 pos[1]=[-15.7 -14.6 3.6] dr=0.93 t=0.0ps kin=1.52 pot=19.78 Rg=19.183 SPS=2309
# 3rd loop
# ---
#
# bl=10 pos[1]=[-15.1 -15.0 5.0] dr=0.94 t=0.0ps kin=1.51 pot=19.76 Rg=19.147 SPS=2276
# 3rd loop
# ---
#
# bl=11 pos[1]=[-15.2 -15.5 6.1] dr=0.94 t=0.0ps kin=1.48 pot=19.76 Rg=19.116 SPS=2278
# 3rd loop
# ---
#
# bl=12 pos[1]=[-16.0 -14.8 6.4] dr=0.92 t=0.0ps kin=1.48 pot=19.75 Rg=19.076 SPS=2339
# 3rd loop
# ---
#
# bl=13 pos[1]=[-15.5 -14.5 4.6] dr=0.93 t=0.0ps kin=1.51 pot=19.75 Rg=19.044 SPS=2309
# 3rd loop
# ---
#
# bl=14 pos[1]=[-15.6 -14.6 3.7] dr=0.93 t=0.0ps kin=1.48 pot=19.77 Rg=19.028 SPS=2327
# 3rd loop
# ---
#
# bl=15 pos[1]=[-16.5 -14.2 2.4] dr=0.93 t=0.0ps kin=1.48 pot=19.80 Rg=19.013 SPS=2291
# 3rd loop
# ---
#
# bl=16 pos[1]=[-17.2 -15.0 2.6] dr=0.95 t=0.0ps kin=1.53 pot=19.78 Rg=18.982 SPS=2288
# 3rd loop
# ---
#
# bl=17 pos[1]=[-15.9 -15.6 2.4] dr=0.96 t=0.0ps kin=1.51 pot=19.81 Rg=18.938 SPS=2299
# 3rd loop
# ---
#
# bl=18 pos[1]=[-15.4 -15.1 3.6] dr=0.95 t=0.0ps kin=1.50 pot=19.81 Rg=18.875 SPS=2360
# 3rd loop
# ---
#
# bl=19 pos[1]=[-15.4 -12.8 4.2] dr=0.93 t=0.0ps kin=1.48 pot=19.80 Rg=18.827 SPS=2269
# 3rd loop
# ---
#
# bl=20 pos[1]=[-14.0 -11.3 4.5] dr=0.94 t=0.0ps kin=1.48 pot=19.80 Rg=18.798 SPS=2353
# 3rd loop
# ---
#
# bl=21 pos[1]=[-14.6 -12.0 5.9] dr=0.95 t=0.0ps kin=1.52 pot=19.76 Rg=18.745 SPS=2318
# 3rd loop
# ---
#
# bl=22 pos[1]=[-14.2 -12.7 5.4] dr=0.94 t=0.0ps kin=1.53 pot=19.77 Rg=18.690 SPS=2302
# 3rd loop
# ---
#
# bl=23 pos[1]=[-15.3 -14.3 5.2] dr=0.94 t=0.0ps kin=1.50 pot=19.77 Rg=18.669 SPS=2285
# 3rd loop
# ---
#
# bl=24 pos[1]=[-16.1 -15.4 2.9] dr=0.95 t=0.0ps kin=1.51 pot=19.79 Rg=18.655 SPS=2264
# 3rd loop
# ---
#
# bl=25 pos[1]=[-15.5 -14.8 4.6] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=18.646 SPS=2257
# 3rd loop
# ---
#
# bl=26 pos[1]=[-14.0 -15.0 4.0] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=18.656 SPS=2266
# 3rd loop
# ---
#
# bl=27 pos[1]=[-12.7 -14.8 3.2] dr=0.95 t=0.0ps kin=1.52 pot=19.78 Rg=18.669 SPS=2247
# 3rd loop
# ---
#
# bl=28 pos[1]=[-12.7 -16.0 2.3] dr=0.95 t=0.0ps kin=1.51 pot=19.79 Rg=18.655 SPS=2352
# 3rd loop
# ---
#
# bl=29 pos[1]=[-11.6 -16.9 3.2] dr=0.95 t=0.0ps kin=1.49 pot=19.80 Rg=18.619 SPS=2324
# 3rd loop
# ---
#
# bl=30 pos[1]=[-11.0 -14.4 3.7] dr=0.94 t=0.0ps kin=1.52 pot=19.76 Rg=18.589 SPS=2306
# 3rd loop
# ---
#
# bl=31 pos[1]=[-11.1 -15.1 2.7] dr=0.96 t=0.0ps kin=1.51 pot=19.78 Rg=18.548 SPS=2317
# 3rd loop
# ---
#
# bl=32 pos[1]=[-11.7 -14.1 2.4] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=18.504 SPS=2215
# 3rd loop
# ---
#
# bl=33 pos[1]=[-11.9 -14.5 1.5] dr=0.94 t=0.0ps kin=1.51 pot=19.82 Rg=18.473 SPS=2164
# 3rd loop
# ---
#
# bl=34 pos[1]=[-12.2 -14.5 2.8] dr=0.92 t=0.0ps kin=1.54 pot=19.74 Rg=18.433 SPS=2308
# 3rd loop
# ---
#
# bl=35 pos[1]=[-13.3 -13.8 2.2] dr=0.94 t=0.0ps kin=1.50 pot=19.74 Rg=18.414 SPS=2290
# 3rd loop
# ---
#
# bl=36 pos[1]=[-12.7 -13.5 2.4] dr=0.92 t=0.0ps kin=1.47 pot=19.75 Rg=18.382 SPS=2322
# 3rd loop
# ---
#
# bl=37 pos[1]=[-12.7 -13.4 2.1] dr=0.92 t=0.0ps kin=1.49 pot=19.76 Rg=18.349 SPS=2301
# 3rd loop
# ---
#
# bl=38 pos[1]=[-13.4 -13.8 1.9] dr=0.95 t=0.0ps kin=1.51 pot=19.76 Rg=18.325 SPS=2274
# 3rd loop
# ---
#
# bl=39 pos[1]=[-12.7 -15.4 2.1] dr=0.95 t=0.0ps kin=1.51 pot=19.78 Rg=18.321 SPS=2314
# 3rd loop
# ---
#
# bl=40 pos[1]=[-12.7 -15.5 2.4] dr=0.97 t=0.0ps kin=1.49 pot=19.78 Rg=18.308 SPS=2328
# 3rd loop
# ---
#
# bl=41 pos[1]=[-13.0 -16.6 2.2] dr=0.95 t=0.0ps kin=1.48 pot=19.80 Rg=18.300 SPS=2254
# 3rd loop
# ---
#
# bl=42 pos[1]=[-12.4 -15.7 2.6] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=18.270 SPS=2235
# 3rd loop
# ---
#
# bl=43 pos[1]=[-11.3 -14.7 3.3] dr=0.93 t=0.0ps kin=1.51 pot=19.76 Rg=18.245 SPS=2276
# 3rd loop
# ---
#
# bl=44 pos[1]=[-9.4 -13.9 3.2] dr=0.94 t=0.0ps kin=1.53 pot=19.76 Rg=18.217 SPS=2343
# 3rd loop
# ---
#
# bl=45 pos[1]=[-8.9 -14.1 2.7] dr=0.94 t=0.0ps kin=1.49 pot=19.79 Rg=18.194 SPS=2252
# 3rd loop
# ---
#
# bl=46 pos[1]=[-10.2 -13.3 1.5] dr=0.93 t=0.0ps kin=1.45 pot=19.78 Rg=18.166 SPS=2278
# 3rd loop
# ---
#
# bl=47 pos[1]=[-9.0 -14.0 2.0] dr=0.94 t=0.0ps kin=1.47 pot=19.76 Rg=18.118 SPS=2271
# 3rd loop
# ---
#
# bl=48 pos[1]=[-9.4 -14.3 2.6] dr=0.92 t=0.0ps kin=1.47 pot=19.77 Rg=18.068 SPS=2338
# 3rd loop
# ---
#
# bl=49 pos[1]=[-10.2 -14.8 2.0] dr=0.94 t=0.0ps kin=1.50 pot=19.73 Rg=18.034 SPS=2259
# 3rd loop
# ---
#
#
# Statistics for the simulation chr10_chr11, number of particles: 5415,  number of chains: 2
#
# Statistics for particle position
#      mean position is:  [-0.24216368  0.27209654  0.16864704]   Rg =  18.034105
#      median bond size is  0.9638969170639674
#      three shortest/longest (<10)/ bonds are  [0.87679123 0.8777848  0.88259559]    [1.09163827 1.10794987 1.13310187]
#      95 percentile of distance to center is:    23.7283009239356
#      density of closest 95% monomers is:    0.0919249775618405
#      density of the core monomers is:    0.0526096490324508
#      min/median/mean/max coordinates are:
#      x: -23.75, -3.66, -0.24, 22.66
#      y: -18.93, 1.11, 0.27, 19.50
#      z: -15.10, -0.59, 0.17, 18.35
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5013027971226882 should be: 1.5
#      fastest particles are (in kT):  [9.14930811 9.19523034 9.24078932 9.6912653  9.87623197]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosomeChain0', 'IdealChromosomeChain1']
#      Number of exceptions:   5413
#
# Potential Energy Ep =  19.73038867728532
# bl=50 pos[1]=[-9.4 -16.6 2.0] dr=0.94 t=0.0ps kin=1.48 pot=19.78 Rg=18.022 SPS=2350
# 3rd loop
# ---
#
# bl=51 pos[1]=[-11.2 -15.2 1.8] dr=0.93 t=0.0ps kin=1.51 pot=19.78 Rg=18.018 SPS=2260
# 3rd loop
# ---
#
# bl=52 pos[1]=[-10.6 -15.6 3.1] dr=0.94 t=0.0ps kin=1.51 pot=19.79 Rg=18.044 SPS=2323
# 3rd loop
# ---
#
# bl=53 pos[1]=[-9.7 -15.5 2.6] dr=0.97 t=0.0ps kin=1.50 pot=19.79 Rg=18.063 SPS=2271
# 3rd loop
# ---
#
# bl=54 pos[1]=[-9.8 -17.3 3.1] dr=0.95 t=0.0ps kin=1.50 pot=19.78 Rg=18.052 SPS=2323
# 3rd loop
# ---
#
# bl=55 pos[1]=[-9.2 -16.8 2.8] dr=0.94 t=0.0ps kin=1.51 pot=19.75 Rg=18.050 SPS=2334
# 3rd loop
# ---
#
# bl=56 pos[1]=[-9.0 -16.6 1.2] dr=0.92 t=0.0ps kin=1.50 pot=19.77 Rg=18.055 SPS=2335
# 3rd loop
# ---
#
# bl=57 pos[1]=[-9.3 -15.7 0.3] dr=0.93 t=0.0ps kin=1.48 pot=19.78 Rg=18.037 SPS=2363
# 3rd loop
# ---
#
# bl=58 pos[1]=[-8.3 -13.9 1.4] dr=0.93 t=0.0ps kin=1.49 pot=19.79 Rg=18.004 SPS=2241
# 3rd loop
# ---
#
# bl=59 pos[1]=[-7.3 -12.8 2.4] dr=0.94 t=0.0ps kin=1.52 pot=19.76 Rg=17.956 SPS=2289
# 3rd loop
# ---
#
# bl=60 pos[1]=[-6.6 -11.6 2.0] dr=0.95 t=0.0ps kin=1.51 pot=19.74 Rg=17.937 SPS=2322
# 3rd loop
# ---
#
# bl=61 pos[1]=[-8.1 -10.2 2.7] dr=0.93 t=0.0ps kin=1.53 pot=19.76 Rg=17.936 SPS=2297
# 3rd loop
# ---
#
# bl=62 pos[1]=[-8.8 -11.0 2.6] dr=0.95 t=0.0ps kin=1.49 pot=19.77 Rg=17.916 SPS=2299
# 3rd loop
# ---
#
# bl=63 pos[1]=[-8.4 -11.9 2.0] dr=0.93 t=0.0ps kin=1.49 pot=19.76 Rg=17.862 SPS=2394
# 3rd loop
# ---
#
# bl=64 pos[1]=[-7.2 -12.0 2.4] dr=0.92 t=0.0ps kin=1.48 pot=19.76 Rg=17.829 SPS=2387
# 3rd loop
# ---
#
# bl=65 pos[1]=[-8.0 -11.6 4.6] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=17.824 SPS=2235
# 3rd loop
# ---
#
# bl=66 pos[1]=[-6.4 -12.5 3.6] dr=0.93 t=0.0ps kin=1.50 pot=19.79 Rg=17.802 SPS=2312
# 3rd loop
# ---
#
# bl=67 pos[1]=[-7.2 -12.5 1.9] dr=0.93 t=0.0ps kin=1.51 pot=19.76 Rg=17.769 SPS=2279
# 3rd loop
# ---
#
# bl=68 pos[1]=[-7.2 -13.4 2.6] dr=0.94 t=0.0ps kin=1.50 pot=19.77 Rg=17.744 SPS=2372
# 3rd loop
# ---
#
# bl=69 pos[1]=[-7.9 -13.4 1.5] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=17.729 SPS=2376
# 3rd loop
# ---
#
# bl=70 pos[1]=[-7.7 -13.6 2.0] dr=0.96 t=0.0ps kin=1.49 pot=19.82 Rg=17.698 SPS=2347
# 3rd loop
# ---
#
# bl=71 pos[1]=[-7.2 -13.4 1.7] dr=0.95 t=0.0ps kin=1.53 pot=19.78 Rg=17.683 SPS=2347
# 3rd loop
# ---
#
# bl=72 pos[1]=[-5.9 -13.0 1.3] dr=0.96 t=0.0ps kin=1.50 pot=19.78 Rg=17.686 SPS=2332
# 3rd loop
# ---
#
# bl=73 pos[1]=[-5.8 -14.1 0.9] dr=0.95 t=0.0ps kin=1.51 pot=19.78 Rg=17.676 SPS=2320
# 3rd loop
# ---
#
# bl=74 pos[1]=[-6.6 -13.7 0.8] dr=0.96 t=0.0ps kin=1.53 pot=19.76 Rg=17.648 SPS=2291
# 3rd loop
# ---
#
# bl=75 pos[1]=[-6.1 -15.1 -0.4] dr=0.92 t=0.0ps kin=1.48 pot=19.78 Rg=17.641 SPS=2267
# 3rd loop
# ---
#
# bl=76 pos[1]=[-6.5 -16.3 -0.6] dr=0.93 t=0.0ps kin=1.49 pot=19.78 Rg=17.649 SPS=2298
# 3rd loop
# ---
#
# bl=77 pos[1]=[-7.7 -16.8 0.1] dr=0.94 t=0.0ps kin=1.52 pot=19.77 Rg=17.668 SPS=2349
# 3rd loop
# ---
#
# bl=78 pos[1]=[-9.4 -17.4 -1.2] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=17.686 SPS=2238
# 3rd loop
# ---
#
# bl=79 pos[1]=[-10.0 -18.0 -1.4] dr=0.94 t=0.0ps kin=1.52 pot=19.77 Rg=17.688 SPS=2338
# 3rd loop
# ---
#
# bl=80 pos[1]=[-11.7 -18.1 -2.6] dr=0.95 t=0.0ps kin=1.52 pot=19.79 Rg=17.703 SPS=2277
# 3rd loop
# ---
#
# bl=81 pos[1]=[-12.0 -18.4 -1.8] dr=0.95 t=0.0ps kin=1.51 pot=19.80 Rg=17.710 SPS=2258
# 3rd loop
# ---
#
# bl=82 pos[1]=[-11.6 -19.0 -0.6] dr=0.96 t=0.0ps kin=1.50 pot=19.80 Rg=17.722 SPS=2307
# 3rd loop
# ---
#
# bl=83 pos[1]=[-10.4 -18.8 -2.1] dr=0.95 t=0.0ps kin=1.51 pot=19.79 Rg=17.749 SPS=2280
# 3rd loop
# ---
#
# bl=84 pos[1]=[-7.5 -17.1 -1.0] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=17.737 SPS=2372
# 3rd loop
# ---
#
# bl=85 pos[1]=[-7.1 -17.0 -1.6] dr=0.94 t=0.0ps kin=1.52 pot=19.79 Rg=17.733 SPS=2251
# 3rd loop
# ---
#
# bl=86 pos[1]=[-7.0 -17.9 -0.5] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=17.712 SPS=2162
# 3rd loop
# ---
#
# bl=87 pos[1]=[-7.2 -16.7 -0.7] dr=0.96 t=0.0ps kin=1.51 pot=19.75 Rg=17.696 SPS=2266
# 3rd loop
# ---
#
# bl=88 pos[1]=[-7.3 -15.0 0.6] dr=0.94 t=0.0ps kin=1.47 pot=19.78 Rg=17.681 SPS=2235
# 3rd loop
# ---
#
# bl=89 pos[1]=[-7.0 -16.1 1.9] dr=0.96 t=0.0ps kin=1.49 pot=19.75 Rg=17.628 SPS=2259
# 3rd loop
# ---
#
# bl=90 pos[1]=[-7.0 -16.4 1.0] dr=0.93 t=0.0ps kin=1.48 pot=19.77 Rg=17.595 SPS=2233
# 3rd loop
# ---
#
# bl=91 pos[1]=[-7.5 -16.1 0.2] dr=0.93 t=0.0ps kin=1.49 pot=19.75 Rg=17.601 SPS=2212
# 3rd loop
# ---
#
# bl=92 pos[1]=[-7.2 -16.1 -1.5] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=17.599 SPS=2284
# 3rd loop
# ---
#
# bl=93 pos[1]=[-5.9 -16.7 -1.9] dr=0.93 t=0.0ps kin=1.49 pot=19.77 Rg=17.577 SPS=2280
# 3rd loop
# ---
#
# bl=94 pos[1]=[-8.5 -17.1 -1.1] dr=0.93 t=0.0ps kin=1.51 pot=19.74 Rg=17.549 SPS=2272
# 3rd loop
# ---
#
# bl=95 pos[1]=[-10.1 -17.9 0.3] dr=0.94 t=0.0ps kin=1.49 pot=19.76 Rg=17.546 SPS=2285
# 3rd loop
# ---
#
# bl=96 pos[1]=[-9.8 -17.7 0.4] dr=0.94 t=0.0ps kin=1.50 pot=19.77 Rg=17.545 SPS=2274
# 3rd loop
# ---
#
# bl=97 pos[1]=[-8.3 -16.6 0.4] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=17.525 SPS=2303
# 3rd loop
# ---
#
# bl=98 pos[1]=[-7.6 -15.5 -0.4] dr=0.94 t=0.0ps kin=1.50 pot=19.75 Rg=17.519 SPS=2260
# 3rd loop
# ---
#
# bl=99 pos[1]=[-8.2 -15.2 -1.1] dr=0.94 t=0.0ps kin=1.50 pot=19.77 Rg=17.509 SPS=2302
# 3rd loop
# ---
#
#
# Statistics for the simulation chr10_chr11, number of particles: 5415,  number of chains: 2
#
# Statistics for particle position
#      mean position is:  [-0.50881058  0.39117183 -0.01465986]   Rg =  17.508888
#      median bond size is  0.9638691101122208
#      three shortest/longest (<10)/ bonds are  [0.86259591 0.87161853 0.87869396]    [1.10485571 1.12808603 1.15779135]
#      95 percentile of distance to center is:    22.76164044941095
#      density of closest 95% monomers is:    0.10414124865206417
#      density of the core monomers is:    0.05641592404529381
#      min/median/mean/max coordinates are:
#      x: -22.39, -3.27, -0.51, 22.30
#      y: -18.87, 0.23, 0.39, 19.43
#      z: -17.59, -0.15, -0.01, 17.34
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5047804327527627 should be: 1.5
#      fastest particles are (in kT):  [7.89279353 7.98819798 8.06014687 8.25493046 8.8119173 ]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosomeChain0', 'IdealChromosomeChain1']
#      Number of exceptions:   5413
#
# Potential Energy Ep =  19.77139167820868
# bl=100 pos[1]=[-8.1 -15.5 -0.2] dr=0.93 t=0.0ps kin=1.49 pot=19.78 Rg=17.490 SPS=2267
# 3rd loop
# ---
#
# bl=101 pos[1]=[-7.3 -15.7 -0.3] dr=0.93 t=0.0ps kin=1.50 pot=19.76 Rg=17.463 SPS=2284
# 3rd loop
# ---
#
# bl=102 pos[1]=[-7.7 -16.7 0.4] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=17.450 SPS=2361
# 3rd loop
# ---
#
# bl=103 pos[1]=[-7.9 -16.6 2.4] dr=0.95 t=0.0ps kin=1.50 pot=19.79 Rg=17.404 SPS=2215
# 3rd loop
# ---
#
# bl=104 pos[1]=[-9.1 -14.1 2.2] dr=0.92 t=0.0ps kin=1.50 pot=19.78 Rg=17.360 SPS=2290
# 3rd loop
# ---
#
# bl=105 pos[1]=[-8.6 -15.1 2.6] dr=0.93 t=0.0ps kin=1.51 pot=19.80 Rg=17.360 SPS=2292
# 3rd loop
# ---
#
# bl=106 pos[1]=[-9.0 -14.5 1.2] dr=0.95 t=0.0ps kin=1.49 pot=19.80 Rg=17.350 SPS=2331
# 3rd loop
# ---
#
# bl=107 pos[1]=[-6.7 -13.8 3.1] dr=0.94 t=0.0ps kin=1.51 pot=19.75 Rg=17.292 SPS=2317
# 3rd loop
# ---
#
# bl=108 pos[1]=[-4.5 -15.0 1.8] dr=0.96 t=0.0ps kin=1.46 pot=19.76 Rg=17.253 SPS=2357
# 3rd loop
# ---
#
# bl=109 pos[1]=[-3.9 -16.4 -0.2] dr=0.95 t=0.0ps kin=1.48 pot=19.77 Rg=17.214 SPS=2288
# 3rd loop
# ---
#
# bl=110 pos[1]=[-4.0 -15.9 -1.9] dr=0.94 t=0.0ps kin=1.49 pot=19.74 Rg=17.168 SPS=2329
# 3rd loop
# ---
#
# bl=111 pos[1]=[-3.9 -15.8 -3.4] dr=0.93 t=0.0ps kin=1.50 pot=19.75 Rg=17.143 SPS=2240
# 3rd loop
# ---
#
# bl=112 pos[1]=[-3.4 -14.5 -4.0] dr=0.95 t=0.0ps kin=1.52 pot=19.75 Rg=17.144 SPS=2319
# 3rd loop
# ---
#
# bl=113 pos[1]=[-3.5 -14.8 -1.9] dr=0.96 t=0.0ps kin=1.49 pot=19.79 Rg=17.132 SPS=2257
# 3rd loop
# ---
#
# bl=114 pos[1]=[-3.3 -14.7 -0.6] dr=0.96 t=0.0ps kin=1.51 pot=19.77 Rg=17.105 SPS=2303
# 3rd loop
# ---
#
# bl=115 pos[1]=[-3.6 -13.4 0.3] dr=0.97 t=0.0ps kin=1.53 pot=19.75 Rg=17.076 SPS=2317
# 3rd loop
# ---
#
# bl=116 pos[1]=[-3.6 -14.2 -0.6] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=17.091 SPS=2265
# 3rd loop
# ---
#
# bl=117 pos[1]=[-3.6 -14.8 -0.4] dr=0.93 t=0.0ps kin=1.50 pot=19.76 Rg=17.107 SPS=2295
# 3rd loop
# ---
#
# bl=118 pos[1]=[-5.3 -14.2 -0.9] dr=0.96 t=0.0ps kin=1.49 pot=19.77 Rg=17.099 SPS=2268
# 3rd loop
# ---
#
# bl=119 pos[1]=[-7.0 -13.7 -2.1] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=17.092 SPS=2224
# 3rd loop
# ---
#
# bl=120 pos[1]=[-7.1 -13.8 -0.8] dr=0.96 t=0.0ps kin=1.51 pot=19.80 Rg=17.076 SPS=2301
# 3rd loop
# ---
#
# bl=121 pos[1]=[-7.9 -14.3 -2.1] dr=0.94 t=0.0ps kin=1.49 pot=19.76 Rg=17.080 SPS=2296
# 3rd loop
# ---
#
# bl=122 pos[1]=[-7.2 -14.0 -2.0] dr=0.94 t=0.0ps kin=1.52 pot=19.78 Rg=17.057 SPS=2300
# 3rd loop
# ---
#
# bl=123 pos[1]=[-6.6 -14.3 -2.7] dr=0.95 t=0.0ps kin=1.54 pot=19.76 Rg=17.044 SPS=2362
# 3rd loop
# ---
#
# bl=124 pos[1]=[-4.9 -13.5 -2.3] dr=0.94 t=0.0ps kin=1.52 pot=19.76 Rg=17.042 SPS=2321
# 3rd loop
# ---
#
# bl=125 pos[1]=[-6.5 -13.8 -1.7] dr=0.95 t=0.0ps kin=1.50 pot=19.78 Rg=17.030 SPS=2288
# 3rd loop
# ---
#
# bl=126 pos[1]=[-5.9 -14.0 -2.9] dr=0.95 t=0.0ps kin=1.50 pot=19.79 Rg=17.017 SPS=2332
# 3rd loop
# ---
#
# bl=127 pos[1]=[-6.3 -14.0 -3.2] dr=0.95 t=0.0ps kin=1.50 pot=19.78 Rg=17.011 SPS=2250
# 3rd loop
# ---
#
# bl=128 pos[1]=[-7.5 -13.5 -3.7] dr=0.95 t=0.0ps kin=1.49 pot=19.79 Rg=17.005 SPS=2248
# 3rd loop
# ---
#
# bl=129 pos[1]=[-8.0 -14.3 -4.2] dr=0.92 t=0.0ps kin=1.50 pot=19.77 Rg=17.003 SPS=2258
# 3rd loop
# ---
#
# bl=130 pos[1]=[-8.2 -13.5 -4.2] dr=0.95 t=0.0ps kin=1.50 pot=19.80 Rg=17.010 SPS=2264
# 3rd loop
# ---
#
# bl=131 pos[1]=[-8.3 -13.5 -3.3] dr=0.94 t=0.0ps kin=1.50 pot=19.77 Rg=17.007 SPS=2211
# 3rd loop
# ---
#
# bl=132 pos[1]=[-7.9 -13.6 -3.0] dr=0.94 t=0.0ps kin=1.48 pot=19.76 Rg=17.012 SPS=2388
# 3rd loop
# ---
#
# bl=133 pos[1]=[-6.9 -13.3 -3.1] dr=0.96 t=0.0ps kin=1.47 pot=19.77 Rg=17.004 SPS=2221
# 3rd loop
# ---
#
# bl=134 pos[1]=[-6.6 -13.0 -2.4] dr=0.92 t=0.0ps kin=1.49 pot=19.75 Rg=16.984 SPS=2241
# 3rd loop
# ---
#
# bl=135 pos[1]=[-6.0 -12.5 -3.3] dr=0.94 t=0.0ps kin=1.47 pot=19.73 Rg=16.941 SPS=2182
# 3rd loop
# ---
# bl=136 pos[1]=[-6.2 -12.5 -3.1] dr=0.91 t=0.0ps kin=1.50 pot=19.72 Rg=16.923 SPS=2175
# 3rd loop
# ---
#
# bl=137 pos[1]=[-7.0 -12.9 -1.9] dr=0.93 t=0.0ps kin=1.47 pot=19.75 Rg=16.917 SPS=2123
# 3rd loop
# ---
#
# bl=138 pos[1]=[-7.1 -12.5 -2.1] dr=0.93 t=0.0ps kin=1.49 pot=19.74 Rg=16.911 SPS=2291
# 3rd loop
# ---
#
# bl=139 pos[1]=[-8.1 -12.2 -2.2] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=16.891 SPS=2276
# 3rd loop
# ---
#
# bl=140 pos[1]=[-7.7 -11.8 -2.6] dr=0.93 t=0.0ps kin=1.51 pot=19.78 Rg=16.861 SPS=2229
# 3rd loop
# ---
#
# bl=141 pos[1]=[-7.4 -12.5 -2.8] dr=0.94 t=0.0ps kin=1.52 pot=19.79 Rg=16.867 SPS=2186
# 3rd loop
# ---
#
# bl=142 pos[1]=[-7.0 -14.0 -3.6] dr=0.94 t=0.0ps kin=1.52 pot=19.79 Rg=16.877 SPS=2311
# 3rd loop
# ---
#
# bl=143 pos[1]=[-7.0 -14.0 -3.6] dr=0.95 t=0.0ps kin=1.52 pot=19.79 Rg=16.902 SPS=2234
# 3rd loop
# ---
#
# bl=144 pos[1]=[-6.5 -13.4 -3.6] dr=0.92 t=0.0ps kin=1.49 pot=19.80 Rg=16.908 SPS=2253
# 3rd loop
# ---
#
# bl=145 pos[1]=[-6.9 -14.5 -2.5] dr=0.92 t=0.0ps kin=1.50 pot=19.77 Rg=16.918 SPS=2258
# 3rd loop
# ---
#
# bl=146 pos[1]=[-6.4 -14.1 -1.1] dr=0.93 t=0.0ps kin=1.52 pot=19.81 Rg=16.935 SPS=2270
# 3rd loop
# ---
#
# bl=147 pos[1]=[-4.3 -13.1 -1.8] dr=0.94 t=0.0ps kin=1.52 pot=19.80 Rg=16.952 SPS=2289
# 3rd loop
# ---
#
# bl=148 pos[1]=[-3.8 -11.6 -2.9] dr=0.95 t=0.0ps kin=1.53 pot=19.80 Rg=16.981 SPS=2218
# 3rd loop
# ---
#
# bl=149 pos[1]=[-3.5 -12.0 -2.8] dr=0.95 t=0.0ps kin=1.55 pot=19.80 Rg=17.023 SPS=2216
# 3rd loop
# ---
#
#
# Statistics for the simulation chr10_chr11, number of particles: 5415,  number of chains: 2
#
# Statistics for particle position
#      mean position is:  [-0.3024214   0.21219426 -0.00529096]   Rg =  17.02333
#      median bond size is  0.9638877035882262
#      three shortest/longest (<10)/ bonds are  [0.8785501  0.88169848 0.88256595]    [1.09401659 1.0956494  1.13647112]
#      95 percentile of distance to center is:    22.486339537801435
#      density of closest 95% monomers is:    0.10801328255629496
#      density of the core monomers is:    0.0752892267146935
#      min/median/mean/max coordinates are:
#      x: -22.77, -2.25, -0.30, 21.85
#      y: -18.57, 0.91, 0.21, 19.78
#      z: -17.42, -0.09, -0.01, 16.34
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5524933925334996 should be: 1.5
#      fastest particles are (in kT):  [ 8.67654828  9.2962414   9.65412019  9.71591797 10.54263953]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosomeChain0', 'IdealChromosomeChain1']
#      Number of exceptions:   5413
#
# Potential Energy Ep =  19.803381809787627
# bl=150 pos[1]=[-3.9 -11.7 -1.3] dr=0.96 t=0.0ps kin=1.51 pot=19.79 Rg=17.052 SPS=2221
# 3rd loop
# ---
#
# bl=151 pos[1]=[-5.3 -12.6 -0.3] dr=0.95 t=0.0ps kin=1.50 pot=19.75 Rg=17.040 SPS=2248
# 3rd loop
# ---
#
# bl=152 pos[1]=[-5.9 -14.4 -1.6] dr=0.95 t=0.0ps kin=1.51 pot=19.76 Rg=17.015 SPS=2260
# 3rd loop
# ---
#
# bl=153 pos[1]=[-7.1 -14.3 -2.3] dr=0.94 t=0.0ps kin=1.51 pot=19.74 Rg=17.001 SPS=2308
# 3rd loop
# ---
#
# bl=154 pos[1]=[-7.9 -15.1 -2.1] dr=0.92 t=0.0ps kin=1.50 pot=19.76 Rg=16.997 SPS=2291
# 3rd loop
# ---
#
# bl=155 pos[1]=[-7.2 -13.6 -1.0] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=16.982 SPS=2207
# 3rd loop
# ---
#
# bl=156 pos[1]=[-5.6 -12.6 -1.5] dr=0.93 t=0.0ps kin=1.49 pot=19.76 Rg=16.969 SPS=2280
# 3rd loop
# ---
#
# bl=157 pos[1]=[-5.5 -12.7 -0.7] dr=0.94 t=0.0ps kin=1.47 pot=19.76 Rg=16.982 SPS=2192
# 3rd loop
# ---
#
# bl=158 pos[1]=[-5.6 -13.5 0.1] dr=0.93 t=0.0ps kin=1.51 pot=19.72 Rg=16.971 SPS=2312
# 3rd loop
# ---
#
# bl=159 pos[1]=[-6.5 -13.9 0.2] dr=0.95 t=0.0ps kin=1.47 pot=19.80 Rg=16.948 SPS=2278
# 3rd loop
# ---
#
# bl=160 pos[1]=[-7.7 -14.5 -0.9] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=16.916 SPS=2242
# 3rd loop
# ---
#
# bl=161 pos[1]=[-7.2 -14.1 -1.4] dr=0.95 t=0.0ps kin=1.52 pot=19.78 Rg=16.871 SPS=2183
# 3rd loop
# ---
#
# bl=162 pos[1]=[-6.1 -14.1 -1.5] dr=0.92 t=0.0ps kin=1.53 pot=19.76 Rg=16.831 SPS=2239
# 3rd loop
# ---
#
# bl=163 pos[1]=[-7.5 -13.9 -0.5] dr=0.95 t=0.0ps kin=1.50 pot=19.79 Rg=16.808 SPS=2300
# 3rd loop
# ---
#
# bl=164 pos[1]=[-7.0 -14.4 -0.8] dr=0.95 t=0.0ps kin=1.48 pot=19.77 Rg=16.788 SPS=2247
# 3rd loop
# ---
#
# bl=165 pos[1]=[-5.5 -13.5 -1.1] dr=0.93 t=0.0ps kin=1.46 pot=19.78 Rg=16.775 SPS=2302
# 3rd loop
# ---
#
# bl=166 pos[1]=[-5.0 -12.8 -2.9] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=16.736 SPS=2319
# 3rd loop
# ---
#
# bl=167 pos[1]=[-5.3 -12.0 -2.0] dr=0.94 t=0.0ps kin=1.45 pot=19.79 Rg=16.734 SPS=2290
# 3rd loop
# ---
#
# bl=168 pos[1]=[-6.3 -12.4 -1.4] dr=0.94 t=0.0ps kin=1.49 pot=19.75 Rg=16.754 SPS=2216
# 3rd loop
# ---
#
# bl=169 pos[1]=[-5.9 -12.6 -2.9] dr=0.93 t=0.0ps kin=1.51 pot=19.75 Rg=16.744 SPS=2195
# 3rd loop
# ---
#
# bl=170 pos[1]=[-7.2 -10.7 -2.8] dr=0.94 t=0.0ps kin=1.48 pot=19.79 Rg=16.738 SPS=2195
# 3rd loop
# ---
#
# bl=171 pos[1]=[-5.5 -11.1 -2.2] dr=0.93 t=0.0ps kin=1.50 pot=19.79 Rg=16.750 SPS=2186
# 3rd loop
# ---
#
# bl=172 pos[1]=[-5.1 -10.8 -3.1] dr=0.95 t=0.0ps kin=1.48 pot=19.77 Rg=16.774 SPS=2244
# 3rd loop
# ---
#
# bl=173 pos[1]=[-4.3 -11.8 -2.4] dr=0.95 t=0.0ps kin=1.50 pot=19.77 Rg=16.789 SPS=2212
# 3rd loop
# ---
#
# bl=174 pos[1]=[-4.0 -11.2 -3.1] dr=0.95 t=0.0ps kin=1.50 pot=19.75 Rg=16.786 SPS=2258
# 3rd loop
# ---
#
# bl=175 pos[1]=[-4.1 -11.7 -2.9] dr=0.93 t=0.0ps kin=1.52 pot=19.75 Rg=16.801 SPS=2194
# 3rd loop
# ---
#
# bl=176 pos[1]=[-3.8 -12.8 -3.1] dr=0.92 t=0.0ps kin=1.52 pot=19.77 Rg=16.839 SPS=2327
# 3rd loop
# ---
#
# bl=177 pos[1]=[-4.1 -13.2 -2.7] dr=0.95 t=0.0ps kin=1.48 pot=19.78 Rg=16.887 SPS=2203
# 3rd loop
# ---
#
# bl=178 pos[1]=[-5.2 -12.2 -2.5] dr=0.95 t=0.0ps kin=1.50 pot=19.80 Rg=16.892 SPS=2268
# 3rd loop
# ---
#
# bl=179 pos[1]=[-4.7 -13.1 -2.7] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=16.883 SPS=2270
# 3rd loop
# ---
#
# bl=180 pos[1]=[-4.7 -13.7 -1.6] dr=0.95 t=0.0ps kin=1.50 pot=19.78 Rg=16.862 SPS=2281
# 3rd loop
# ---
#
# bl=181 pos[1]=[-5.0 -12.8 -0.3] dr=0.95 t=0.0ps kin=1.50 pot=19.76 Rg=16.840 SPS=2222
# 3rd loop
# ---
#
# bl=182 pos[1]=[-4.6 -12.4 -0.7] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=16.830 SPS=2295
# 3rd loop
# ---
#
# bl=183 pos[1]=[-4.0 -12.0 -2.0] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=16.796 SPS=2233
# 3rd loop
# ---
#
# bl=184 pos[1]=[-4.6 -12.4 -3.0] dr=0.95 t=0.0ps kin=1.49 pot=19.78 Rg=16.749 SPS=2233
# 3rd loop
# ---
#
# bl=185 pos[1]=[-4.1 -12.3 -2.7] dr=0.93 t=0.0ps kin=1.49 pot=19.76 Rg=16.708 SPS=2336
# 3rd loop
# ---
#
# bl=186 pos[1]=[-2.7 -13.1 -2.4] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=16.686 SPS=2268
# 3rd loop
# ---
#
# bl=187 pos[1]=[-2.8 -13.6 -1.6] dr=0.94 t=0.0ps kin=1.51 pot=19.76 Rg=16.681 SPS=2296
# 3rd loop
# ---
#
# bl=188 pos[1]=[-2.7 -12.3 -0.6] dr=0.94 t=0.0ps kin=1.50 pot=19.75 Rg=16.694 SPS=2265
# 3rd loop
# ---
#
# bl=189 pos[1]=[-3.0 -12.3 -0.7] dr=0.94 t=0.0ps kin=1.51 pot=19.73 Rg=16.686 SPS=2234
# 3rd loop
# ---
#
# bl=190 pos[1]=[-4.6 -11.2 -0.1] dr=0.94 t=0.0ps kin=1.48 pot=19.75 Rg=16.663 SPS=2196
# 3rd loop
# ---
#
# bl=191 pos[1]=[-5.3 -11.1 -0.0] dr=0.94 t=0.0ps kin=1.51 pot=19.74 Rg=16.622 SPS=2297
# 3rd loop
# ---
#
# bl=192 pos[1]=[-4.6 -10.5 0.9] dr=0.93 t=0.0ps kin=1.48 pot=19.77 Rg=16.602 SPS=2300
# 3rd loop
# ---
#
# bl=193 pos[1]=[-5.0 -11.1 1.8] dr=0.93 t=0.0ps kin=1.53 pot=19.76 Rg=16.586 SPS=2259
# 3rd loop
# ---
#
# bl=194 pos[1]=[-6.1 -10.9 3.3] dr=0.95 t=0.0ps kin=1.49 pot=19.80 Rg=16.587 SPS=2206
# 3rd loop
# ---
#
# bl=195 pos[1]=[-5.3 -12.1 3.4] dr=0.94 t=0.0ps kin=1.49 pot=19.79 Rg=16.588 SPS=2273
# 3rd loop
# ---
#
# bl=196 pos[1]=[-4.1 -12.0 3.2] dr=0.94 t=0.0ps kin=1.48 pot=19.80 Rg=16.602 SPS=2196
# 3rd loop
# ---
#
# bl=197 pos[1]=[-3.2 -12.4 0.8] dr=0.96 t=0.0ps kin=1.49 pot=19.81 Rg=16.623 SPS=2161
# 3rd loop
# ---
#
# bl=198 pos[1]=[-3.6 -14.0 -1.3] dr=0.95 t=0.0ps kin=1.50 pot=19.79 Rg=16.615 SPS=2255
# 3rd loop
# ---
#
# bl=199 pos[1]=[-3.8 -13.0 -1.6] dr=0.93 t=0.0ps kin=1.53 pot=19.77 Rg=16.610 SPS=2212
# 3rd loop
# ---
#
#
# Statistics for the simulation chr10_chr11, number of particles: 5415,  number of chains: 2
#
# Statistics for particle position
#      mean position is:  [-0.4664816   0.3403511  -0.06052843]   Rg =  16.610025
#      median bond size is  0.9646208904541448
#      three shortest/longest (<10)/ bonds are  [0.86586986 0.87166445 0.87795352]    [1.10534269 1.10702151 1.11268106]
#      95 percentile of distance to center is:    22.133369050508858
#      density of closest 95% monomers is:    0.11326373542402102
#      density of the core monomers is:    0.08052896560180019
#      min/median/mean/max coordinates are:
#      x: -20.29, -1.34, -0.47, 22.15
#      y: -20.42, 1.03, 0.34, 18.59
#      z: -16.77, -0.34, -0.06, 16.96
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5356922863645612 should be: 1.5
#      fastest particles are (in kT):  [ 8.41585765  8.999308    9.059951    9.201649   10.36427726]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosomeChain0', 'IdealChromosomeChain1']
#      Number of exceptions:   5413
#
# Potential Energy Ep =  19.768827908587255
# bl=200 pos[1]=[-5.1 -11.9 -1.8] dr=0.95 t=0.0ps kin=1.51 pot=19.79 Rg=16.614 SPS=2295
# 3rd loop
# ---
#
# bl=201 pos[1]=[-4.8 -11.6 -1.2] dr=0.96 t=0.0ps kin=1.50 pot=19.78 Rg=16.627 SPS=2215
# 3rd loop
# ---
#
# bl=202 pos[1]=[-4.8 -11.7 -1.1] dr=0.94 t=0.0ps kin=1.47 pot=19.82 Rg=16.640 SPS=2275
# 3rd loop
# ---
#
# bl=203 pos[1]=[-4.5 -11.2 -0.3] dr=0.93 t=0.0ps kin=1.51 pot=19.77 Rg=16.644 SPS=2286
# 3rd loop
# ---
#
# bl=204 pos[1]=[-4.9 -10.8 -0.7] dr=0.93 t=0.0ps kin=1.48 pot=19.76 Rg=16.646 SPS=2303
# 3rd loop
# ---
#
# bl=205 pos[1]=[-4.3 -10.5 0.4] dr=0.94 t=0.0ps kin=1.50 pot=19.75 Rg=16.656 SPS=2201
# 3rd loop
# ---
#
# bl=206 pos[1]=[-4.9 -11.7 1.7] dr=0.95 t=0.0ps kin=1.48 pot=19.75 Rg=16.688 SPS=2253
# 3rd loop
# ---
#
# bl=207 pos[1]=[-3.6 -10.4 2.3] dr=0.94 t=0.0ps kin=1.48 pot=19.77 Rg=16.694 SPS=2273
# 3rd loop
# ---
#
# bl=208 pos[1]=[-4.8 -11.6 1.0] dr=0.93 t=0.0ps kin=1.47 pot=19.78 Rg=16.684 SPS=2254
# 3rd loop
# ---
#
# bl=209 pos[1]=[-4.6 -11.1 0.0] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=16.696 SPS=2310
# 3rd loop
# ---
#
# bl=210 pos[1]=[-5.3 -10.0 -0.4] dr=0.93 t=0.0ps kin=1.50 pot=19.77 Rg=16.711 SPS=2286
# 3rd loop
# ---
#
# bl=211 pos[1]=[-6.4 -10.3 -1.0] dr=0.95 t=0.0ps kin=1.53 pot=19.78 Rg=16.731 SPS=2247
# 3rd loop
# ---
#
# bl=212 pos[1]=[-6.5 -10.3 -1.1] dr=0.94 t=0.0ps kin=1.51 pot=19.80 Rg=16.743 SPS=2242
# 3rd loop
# ---
#
# bl=213 pos[1]=[-6.7 -10.7 -1.6] dr=0.96 t=0.0ps kin=1.52 pot=19.81 Rg=16.770 SPS=2292
# 3rd loop
# ---
#
# bl=214 pos[1]=[-7.0 -10.1 -1.8] dr=0.95 t=0.0ps kin=1.50 pot=19.81 Rg=16.818 SPS=2308
# 3rd loop
# ---
#
# bl=215 pos[1]=[-6.7 -9.7 -0.9] dr=0.95 t=0.0ps kin=1.48 pot=19.81 Rg=16.843 SPS=2230
# 3rd loop
# ---
#
# bl=216 pos[1]=[-6.2 -9.8 -1.6] dr=0.94 t=0.0ps kin=1.52 pot=19.80 Rg=16.843 SPS=2212
# 3rd loop
# ---
#
# bl=217 pos[1]=[-6.9 -10.8 -1.2] dr=0.96 t=0.0ps kin=1.50 pot=19.80 Rg=16.858 SPS=2252
# 3rd loop
# ---
#
# bl=218 pos[1]=[-6.7 -10.8 -1.2] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=16.858 SPS=2244
# 3rd loop
# ---
#
# bl=219 pos[1]=[-6.2 -10.3 -1.4] dr=0.96 t=0.0ps kin=1.49 pot=19.79 Rg=16.870 SPS=2316
# 3rd loop
# ---
#
# bl=220 pos[1]=[-6.1 -9.4 -0.7] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=16.870 SPS=2363
# 3rd loop
# ---
#
# bl=221 pos[1]=[-5.9 -8.9 -1.6] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=16.846 SPS=2271
# 3rd loop
# ---
#
# bl=222 pos[1]=[-6.4 -9.2 -2.2] dr=0.94 t=0.0ps kin=1.50 pot=19.74 Rg=16.816 SPS=2251
# 3rd loop
# ---
#
# bl=223 pos[1]=[-6.6 -9.3 -1.9] dr=0.94 t=0.0ps kin=1.49 pot=19.75 Rg=16.791 SPS=2312
# 3rd loop
# ---
#
# bl=224 pos[1]=[-6.7 -9.0 -0.4] dr=0.94 t=0.0ps kin=1.47 pot=19.78 Rg=16.791 SPS=2208
# 3rd loop
# ---
#
# bl=225 pos[1]=[-6.4 -9.2 -0.7] dr=0.95 t=0.0ps kin=1.49 pot=19.79 Rg=16.791 SPS=2330
# 3rd loop
# ---
#
# bl=226 pos[1]=[-6.4 -9.2 -0.9] dr=0.94 t=0.0ps kin=1.48 pot=19.79 Rg=16.775 SPS=2301
# 3rd loop
# ---
#
# bl=227 pos[1]=[-6.4 -9.3 -2.5] dr=0.95 t=0.0ps kin=1.46 pot=19.77 Rg=16.774 SPS=2191
# 3rd loop
# ---
#
# bl=228 pos[1]=[-6.6 -9.9 -2.4] dr=0.95 t=0.0ps kin=1.48 pot=19.76 Rg=16.749 SPS=2284
# 3rd loop
# ---
#
# bl=229 pos[1]=[-6.8 -9.5 -1.7] dr=0.92 t=0.0ps kin=1.50 pot=19.76 Rg=16.701 SPS=2301
# 3rd loop
# ---
#
# bl=230 pos[1]=[-6.4 -9.1 -1.8] dr=0.95 t=0.0ps kin=1.49 pot=19.77 Rg=16.695 SPS=2221
# 3rd loop
# ---
#
# bl=231 pos[1]=[-6.2 -8.9 -2.0] dr=0.93 t=0.0ps kin=1.47 pot=19.77 Rg=16.700 SPS=2265
# 3rd loop
# ---
#
# bl=232 pos[1]=[-7.1 -9.2 -1.9] dr=0.94 t=0.0ps kin=1.48 pot=19.77 Rg=16.685 SPS=2287
# 3rd loop
# ---
#
# bl=233 pos[1]=[-6.8 -8.8 -2.4] dr=0.94 t=0.0ps kin=1.48 pot=19.77 Rg=16.683 SPS=2206
# 3rd loop
# ---
#
# bl=234 pos[1]=[-6.3 -8.2 -2.7] dr=0.96 t=0.0ps kin=1.50 pot=19.78 Rg=16.671 SPS=2308
# 3rd loop
# ---
#
# bl=235 pos[1]=[-5.3 -8.5 -2.0] dr=0.95 t=0.0ps kin=1.51 pot=19.78 Rg=16.622 SPS=2291
# 3rd loop
# ---
#
# bl=236 pos[1]=[-5.0 -8.1 -3.8] dr=0.96 t=0.0ps kin=1.53 pot=19.76 Rg=16.592 SPS=2201
# 3rd loop
# ---
#
# bl=237 pos[1]=[-5.0 -8.3 -4.5] dr=0.96 t=0.0ps kin=1.51 pot=19.79 Rg=16.597 SPS=2278
# 3rd loop
# ---
#
# bl=238 pos[1]=[-5.5 -8.0 -4.4] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=16.615 SPS=2321
# 3rd loop
# ---
#
# bl=239 pos[1]=[-5.5 -8.0 -3.9] dr=0.95 t=0.0ps kin=1.52 pot=19.79 Rg=16.625 SPS=2153
# 3rd loop
# ---
#
# bl=240 pos[1]=[-5.7 -8.0 -2.6] dr=0.96 t=0.0ps kin=1.55 pot=19.78 Rg=16.621 SPS=2210
# 3rd loop
# ---
#
# bl=241 pos[1]=[-5.9 -8.5 -2.0] dr=0.94 t=0.0ps kin=1.53 pot=19.79 Rg=16.611 SPS=2320
# 3rd loop
# ---
#
# bl=242 pos[1]=[-5.4 -9.5 -1.8] dr=0.96 t=0.0ps kin=1.50 pot=19.78 Rg=16.586 SPS=2246
# 3rd loop
# ---
#
# bl=243 pos[1]=[-5.7 -9.6 -1.4] dr=0.94 t=0.0ps kin=1.47 pot=19.77 Rg=16.560 SPS=2300
# 3rd loop
# ---
#
# bl=244 pos[1]=[-5.8 -9.8 -1.4] dr=0.93 t=0.0ps kin=1.49 pot=19.80 Rg=16.539 SPS=2296
# 3rd loop
# ---
#
# bl=245 pos[1]=[-5.4 -10.1 -1.2] dr=0.93 t=0.0ps kin=1.48 pot=19.77 Rg=16.512 SPS=2250
# 3rd loop
# ---
#
# bl=246 pos[1]=[-6.2 -10.1 -2.0] dr=0.94 t=0.0ps kin=1.49 pot=19.75 Rg=16.486 SPS=2307
# 3rd loop
# ---
#
# bl=247 pos[1]=[-6.5 -9.5 -1.6] dr=0.95 t=0.0ps kin=1.52 pot=19.77 Rg=16.477 SPS=2261
# 3rd loop
# ---
#
# bl=248 pos[1]=[-7.0 -8.0 -2.7] dr=0.97 t=0.0ps kin=1.49 pot=19.78 Rg=16.462 SPS=2241
# 3rd loop
# ---
#
# bl=249 pos[1]=[-6.8 -8.2 -2.9] dr=0.94 t=0.0ps kin=1.49 pot=19.75 Rg=16.472 SPS=2186
# 3rd loop
# ---
#
#
# Statistics for the simulation chr10_chr11, number of particles: 5415,  number of chains: 2
#
# Statistics for particle position
#      mean position is:  [-0.36835238  0.39147002  0.13619892]   Rg =  16.471794
#      median bond size is  0.9634374459083371
#      three shortest/longest (<10)/ bonds are  [0.86993316 0.87299317 0.87547759]    [1.09318857 1.09368307 1.10497788]
#      95 percentile of distance to center is:    22.210343778366184
#      density of closest 95% monomers is:    0.11209019242695499
#      density of the core monomers is:    0.0930981639805421
#      min/median/mean/max coordinates are:
#      x: -21.01, -0.21, -0.37, 21.19
#      y: -18.69, 0.48, 0.39, 19.76
#      z: -15.86, -0.28, 0.14, 17.70
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4913030388139152 should be: 1.5
#      fastest particles are (in kT):  [8.53320578 8.64486638 9.04584338 9.17888841 9.79654953]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosomeChain0', 'IdealChromosomeChain1']
#      Number of exceptions:   5413
#
# Potential Energy Ep =  19.754750981071098
# bl=250 pos[1]=[-7.5 -8.9 -2.7] dr=0.93 t=0.0ps kin=1.50 pot=19.74 Rg=16.475 SPS=2264
# 3rd loop
# ---
#
# bl=251 pos[1]=[-7.4 -8.6 -1.7] dr=0.94 t=0.0ps kin=1.47 pot=19.74 Rg=16.475 SPS=2276
# 3rd loop
# ---
#
# bl=252 pos[1]=[-8.1 -9.3 -2.1] dr=0.96 t=0.0ps kin=1.47 pot=19.73 Rg=16.455 SPS=2204
# 3rd loop
# ---
#
# bl=253 pos[1]=[-8.7 -9.6 -2.9] dr=0.96 t=0.0ps kin=1.49 pot=19.76 Rg=16.401 SPS=2273
# 3rd loop
# ---
#
# bl=254 pos[1]=[-8.6 -10.5 -3.1] dr=0.95 t=0.0ps kin=1.49 pot=19.75 Rg=16.347 SPS=2236
# 3rd loop
# ---
#
# bl=255 pos[1]=[-8.9 -10.4 -3.2] dr=0.95 t=0.0ps kin=1.50 pot=19.75 Rg=16.321 SPS=2168
# 3rd loop
# ---
#
# bl=256 pos[1]=[-9.4 -10.4 -3.0] dr=0.95 t=0.0ps kin=1.51 pot=19.76 Rg=16.278 SPS=2296
# 3rd loop
# ---
#
# bl=257 pos[1]=[-9.4 -10.2 -3.5] dr=0.95 t=0.0ps kin=1.51 pot=19.77 Rg=16.249 SPS=2227
# 3rd loop
# ---
#
# bl=258 pos[1]=[-9.0 -9.6 -3.8] dr=0.95 t=0.0ps kin=1.53 pot=19.78 Rg=16.228 SPS=2272
# 3rd loop
# ---
#
# bl=259 pos[1]=[-9.2 -10.1 -3.2] dr=0.95 t=0.0ps kin=1.55 pot=19.76 Rg=16.208 SPS=2292
# 3rd loop
# ---
#
# bl=260 pos[1]=[-8.9 -10.5 -3.5] dr=0.93 t=0.0ps kin=1.49 pot=19.82 Rg=16.185 SPS=2254
# 3rd loop
# ---
#
# bl=261 pos[1]=[-8.8 -11.1 -3.7] dr=0.94 t=0.0ps kin=1.52 pot=19.80 Rg=16.173 SPS=2200
# 3rd loop
# ---
#
# bl=262 pos[1]=[-7.9 -10.2 -3.4] dr=0.93 t=0.0ps kin=1.50 pot=19.80 Rg=16.172 SPS=2263
# 3rd loop
# ---
#
# bl=263 pos[1]=[-7.6 -10.1 -2.0] dr=0.95 t=0.0ps kin=1.49 pot=19.77 Rg=16.188 SPS=2237
# 3rd loop
# ---
#
# bl=264 pos[1]=[-7.5 -10.0 -2.0] dr=0.93 t=0.0ps kin=1.49 pot=19.76 Rg=16.210 SPS=2202
# 3rd loop
# ---
#
# bl=265 pos[1]=[-7.8 -11.8 -1.6] dr=0.95 t=0.0ps kin=1.52 pot=19.77 Rg=16.221 SPS=2299
# 3rd loop
# ---
#
# bl=266 pos[1]=[-7.3 -11.7 -2.4] dr=0.95 t=0.0ps kin=1.45 pot=19.81 Rg=16.226 SPS=2249
# 3rd loop
# ---
#
# bl=267 pos[1]=[-7.7 -12.5 -2.5] dr=0.97 t=0.0ps kin=1.52 pot=19.74 Rg=16.204 SPS=2296
# 3rd loop
# ---
#
# bl=268 pos[1]=[-8.4 -13.0 -2.1] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=16.194 SPS=2219
# 3rd loop
# ---
#
# bl=269 pos[1]=[-8.9 -14.3 -2.0] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=16.180 SPS=2249
# 3rd loop
# ---
# bl=270 pos[1]=[-9.6 -14.5 -1.6] dr=0.95 t=0.0ps kin=1.53 pot=19.74 Rg=16.162 SPS=2197
# 3rd loop
# ---
#
# bl=271 pos[1]=[-9.0 -15.3 -1.8] dr=0.94 t=0.0ps kin=1.49 pot=19.76 Rg=16.169 SPS=2255
# 3rd loop
# ---
#
# bl=272 pos[1]=[-7.7 -13.8 -2.7] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=16.162 SPS=2300
# 3rd loop
# ---
#
# bl=273 pos[1]=[-7.8 -13.8 -2.3] dr=0.95 t=0.0ps kin=1.47 pot=19.77 Rg=16.144 SPS=2288
# 3rd loop
# ---
#
# bl=274 pos[1]=[-9.1 -13.7 -1.8] dr=0.94 t=0.0ps kin=1.47 pot=19.76 Rg=16.131 SPS=2195
# 3rd loop
# ---
#
# bl=275 pos[1]=[-9.1 -13.6 -2.3] dr=0.95 t=0.0ps kin=1.46 pot=19.80 Rg=16.103 SPS=2298
# 3rd loop
# ---
#
# bl=276 pos[1]=[-10.1 -14.2 -2.9] dr=0.95 t=0.0ps kin=1.53 pot=19.78 Rg=16.077 SPS=2166
# 3rd loop
# ---
#
# bl=277 pos[1]=[-9.7 -13.7 -3.3] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=16.033 SPS=2263
# 3rd loop
# ---
#
# bl=278 pos[1]=[-9.0 -12.9 -3.1] dr=0.95 t=0.0ps kin=1.52 pot=19.81 Rg=16.003 SPS=2243
# 3rd loop
# ---
#
# bl=279 pos[1]=[-9.4 -12.4 -3.0] dr=0.94 t=0.0ps kin=1.51 pot=19.82 Rg=15.981 SPS=2259
# 3rd loop
# ---
#
# bl=280 pos[1]=[-9.6 -12.1 -2.1] dr=0.94 t=0.0ps kin=1.52 pot=19.78 Rg=15.978 SPS=2298
# 3rd loop
# ---
#
# bl=281 pos[1]=[-9.8 -12.4 -1.8] dr=0.94 t=0.0ps kin=1.53 pot=19.79 Rg=15.994 SPS=2330
# 3rd loop
# ---
#
# bl=282 pos[1]=[-8.8 -12.5 -2.7] dr=0.95 t=0.0ps kin=1.50 pot=19.79 Rg=15.988 SPS=2161
# 3rd loop
# ---
#
# bl=283 pos[1]=[-9.7 -11.5 -3.8] dr=0.94 t=0.0ps kin=1.48 pot=19.83 Rg=15.988 SPS=2222
# 3rd loop
# ---
#
# bl=284 pos[1]=[-9.7 -11.0 -3.5] dr=0.97 t=0.0ps kin=1.48 pot=19.82 Rg=15.993 SPS=2244
# 3rd loop
# ---
#
# bl=285 pos[1]=[-8.5 -12.4 -2.8] dr=0.96 t=0.0ps kin=1.51 pot=19.79 Rg=15.992 SPS=2227
# 3rd loop
# ---
#
# bl=286 pos[1]=[-8.6 -12.4 -2.8] dr=0.95 t=0.0ps kin=1.51 pot=19.80 Rg=15.972 SPS=2265
# 3rd loop
# ---
#
# bl=287 pos[1]=[-8.2 -11.1 -2.2] dr=0.94 t=0.0ps kin=1.52 pot=19.79 Rg=15.949 SPS=2319
# 3rd loop
# ---
#
# bl=288 pos[1]=[-7.9 -12.2 -2.2] dr=0.93 t=0.0ps kin=1.51 pot=19.78 Rg=15.937 SPS=2228
# 3rd loop
# ---
#
# bl=289 pos[1]=[-8.3 -11.7 -2.7] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=15.915 SPS=2254
# 3rd loop
# ---
#
# bl=290 pos[1]=[-8.2 -12.2 -2.1] dr=0.93 t=0.0ps kin=1.52 pot=19.74 Rg=15.928 SPS=2263
# 3rd loop
# ---
#
# bl=291 pos[1]=[-9.1 -11.4 -2.1] dr=0.97 t=0.0ps kin=1.48 pot=19.78 Rg=15.966 SPS=2255
# 3rd loop
# ---
#
# bl=292 pos[1]=[-8.3 -11.4 -1.4] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=15.971 SPS=2259
# 3rd loop
# ---
#
# bl=293 pos[1]=[-9.4 -12.0 -1.4] dr=0.95 t=0.0ps kin=1.50 pot=19.80 Rg=15.972 SPS=2249
# 3rd loop
# ---
#
# bl=294 pos[1]=[-9.9 -11.9 -2.3] dr=0.95 t=0.0ps kin=1.54 pot=19.78 Rg=15.943 SPS=2313
# 3rd loop
# ---
#
# bl=295 pos[1]=[-9.2 -11.2 -2.0] dr=0.95 t=0.0ps kin=1.51 pot=19.79 Rg=15.888 SPS=2254
# 3rd loop
# ---
#
# bl=296 pos[1]=[-9.7 -12.0 -2.5] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=15.845 SPS=2251
# 3rd loop
# ---
#
# bl=297 pos[1]=[-8.6 -11.6 -2.1] dr=0.92 t=0.0ps kin=1.51 pot=19.76 Rg=15.824 SPS=2292
# 3rd loop
# ---
#
# bl=298 pos[1]=[-8.4 -11.3 -2.2] dr=0.95 t=0.0ps kin=1.53 pot=19.77 Rg=15.809 SPS=2270
# 3rd loop
# ---
#
# bl=299 pos[1]=[-8.5 -11.4 -2.8] dr=0.95 t=0.0ps kin=1.50 pot=19.76 Rg=15.794 SPS=2267
# 3rd loop
# ---
#
#
# Statistics for the simulation chr10_chr11, number of particles: 5415,  number of chains: 2
#
# Statistics for particle position
#      mean position is:  [-0.65549614  0.40467809  0.32980742]   Rg =  15.793578
#      median bond size is  0.9636944416478394
#      three shortest/longest (<10)/ bonds are  [0.8694863  0.87482191 0.87820718]    [1.08788658 1.10155055 1.10524247]
#      95 percentile of distance to center is:    21.69232673430976
#      density of closest 95% monomers is:    0.12031368957761127
#      density of the core monomers is:    0.126495997439744
#      min/median/mean/max coordinates are:
#      x: -21.75, -0.64, -0.66, 18.33
#      y: -18.75, 1.19, 0.40, 20.22
#      z: -15.16, -0.42, 0.33, 18.10
#
# Statistics for velocities:
#      mean kinetic energy is:  1.504868503201181 should be: 1.5
#      fastest particles are (in kT):  [ 8.48393647  8.54599985  8.60419694  9.36577876 11.21505753]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosomeChain0', 'IdealChromosomeChain1']
#      Number of exceptions:   5413
#
# Potential Energy Ep =  19.76216672437673
# bl=300 pos[1]=[-7.5 -11.8 -3.4] dr=0.94 t=0.0ps kin=1.47 pot=19.78 Rg=15.786 SPS=2263
# 3rd loop
# ---
#
# bl=301 pos[1]=[-7.4 -11.4 -4.3] dr=0.95 t=0.0ps kin=1.49 pot=19.75 Rg=15.770 SPS=2280
# 3rd loop
# ---
#
# bl=302 pos[1]=[-7.5 -11.7 -3.9] dr=0.93 t=0.0ps kin=1.50 pot=19.79 Rg=15.753 SPS=2272
# 3rd loop
# ---
#
# bl=303 pos[1]=[-9.4 -12.5 -4.3] dr=0.95 t=0.0ps kin=1.48 pot=19.81 Rg=15.746 SPS=2248
# 3rd loop
# ---
#
# bl=304 pos[1]=[-9.8 -12.6 -4.4] dr=0.93 t=0.0ps kin=1.50 pot=19.77 Rg=15.767 SPS=2352
# 3rd loop
# ---
#
# bl=305 pos[1]=[-10.5 -12.6 -4.9] dr=0.96 t=0.0ps kin=1.51 pot=19.76 Rg=15.780 SPS=2286
# 3rd loop
# ---
#
# bl=306 pos[1]=[-10.2 -12.7 -4.0] dr=0.94 t=0.0ps kin=1.50 pot=19.75 Rg=15.787 SPS=2299
# 3rd loop
# ---
#
# bl=307 pos[1]=[-9.9 -12.6 -4.0] dr=0.95 t=0.0ps kin=1.48 pot=19.74 Rg=15.798 SPS=2282
# 3rd loop
# ---
#
# bl=308 pos[1]=[-10.1 -13.8 -4.0] dr=0.94 t=0.0ps kin=1.50 pot=19.74 Rg=15.806 SPS=2327
# 3rd loop
# ---
#
# bl=309 pos[1]=[-10.2 -14.0 -4.1] dr=0.96 t=0.0ps kin=1.50 pot=19.73 Rg=15.811 SPS=2282
# 3rd loop
# ---
#
# bl=310 pos[1]=[-9.5 -14.0 -3.7] dr=0.93 t=0.0ps kin=1.46 pot=19.76 Rg=15.829 SPS=2232
# 3rd loop
# ---
#
# bl=311 pos[1]=[-9.4 -13.6 -3.4] dr=0.94 t=0.0ps kin=1.49 pot=19.74 Rg=15.823 SPS=2254
# 3rd loop
# ---
#
# bl=312 pos[1]=[-9.8 -13.6 -3.3] dr=0.95 t=0.0ps kin=1.48 pot=19.77 Rg=15.815 SPS=2303
# 3rd loop
# ---
#
# bl=313 pos[1]=[-9.5 -13.7 -3.6] dr=0.93 t=0.0ps kin=1.49 pot=19.76 Rg=15.783 SPS=2244
# 3rd loop
# ---
#
# bl=314 pos[1]=[-9.1 -12.8 -3.8] dr=0.95 t=0.0ps kin=1.48 pot=19.78 Rg=15.765 SPS=2264
# 3rd loop
# ---
#
# bl=315 pos[1]=[-8.8 -12.0 -4.2] dr=0.94 t=0.0ps kin=1.51 pot=19.76 Rg=15.765 SPS=2269
# 3rd loop
# ---
#
# bl=316 pos[1]=[-8.5 -12.4 -4.2] dr=0.95 t=0.0ps kin=1.50 pot=19.76 Rg=15.743 SPS=2217
# 3rd loop
# ---
#
# bl=317 pos[1]=[-8.2 -12.2 -3.8] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=15.745 SPS=2327
# 3rd loop
# ---
#
# bl=318 pos[1]=[-8.2 -12.3 -3.8] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=15.744 SPS=2362
# 3rd loop
# ---
#
# bl=319 pos[1]=[-7.5 -12.7 -4.3] dr=0.94 t=0.0ps kin=1.52 pot=19.75 Rg=15.757 SPS=2224
# 3rd loop
# ---
#
# bl=320 pos[1]=[-7.1 -12.9 -4.2] dr=0.93 t=0.0ps kin=1.47 pot=19.78 Rg=15.776 SPS=2247
# 3rd loop
# ---
#
# bl=321 pos[1]=[-7.2 -12.7 -3.5] dr=0.95 t=0.0ps kin=1.50 pot=19.76 Rg=15.778 SPS=2305
# 3rd loop
# ---
#
# bl=322 pos[1]=[-7.1 -12.1 -2.9] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=15.767 SPS=2250
# 3rd loop
# ---
#
# bl=323 pos[1]=[-7.7 -11.9 -3.4] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=15.749 SPS=2323
# 3rd loop
# ---
#
# bl=324 pos[1]=[-7.8 -12.3 -2.3] dr=0.95 t=0.0ps kin=1.51 pot=19.78 Rg=15.731 SPS=2280
# 3rd loop
# ---
#
# bl=325 pos[1]=[-8.0 -11.8 -3.3] dr=0.91 t=0.0ps kin=1.48 pot=19.78 Rg=15.714 SPS=2284
# 3rd loop
# ---
#
# bl=326 pos[1]=[-7.3 -12.5 -3.1] dr=0.92 t=0.0ps kin=1.48 pot=19.78 Rg=15.717 SPS=2246
# 3rd loop
# ---
#
# bl=327 pos[1]=[-6.5 -11.5 -2.8] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=15.698 SPS=2291
# 3rd loop
# ---
#
# bl=328 pos[1]=[-6.9 -12.0 -2.2] dr=0.94 t=0.0ps kin=1.52 pot=19.76 Rg=15.683 SPS=2269
# 3rd loop
# ---
#
# bl=329 pos[1]=[-7.4 -12.7 -2.8] dr=0.93 t=0.0ps kin=1.49 pot=19.78 Rg=15.687 SPS=2239
# 3rd loop
# ---
#
# bl=330 pos[1]=[-8.1 -12.8 -3.2] dr=0.95 t=0.0ps kin=1.48 pot=19.79 Rg=15.703 SPS=2304
# 3rd loop
# ---
#
# bl=331 pos[1]=[-8.6 -12.4 -3.8] dr=0.95 t=0.0ps kin=1.51 pot=19.77 Rg=15.702 SPS=2237
# 3rd loop
# ---
#
# bl=332 pos[1]=[-8.7 -11.5 -3.2] dr=0.95 t=0.0ps kin=1.50 pot=19.78 Rg=15.686 SPS=2263
# 3rd loop
# ---
#
# bl=333 pos[1]=[-8.8 -11.4 -3.2] dr=0.95 t=0.0ps kin=1.51 pot=19.79 Rg=15.660 SPS=2219
# 3rd loop
# ---
#
# bl=334 pos[1]=[-8.9 -11.0 -2.7] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=15.631 SPS=2291
# 3rd loop
# ---
#
# bl=335 pos[1]=[-9.4 -11.2 -3.4] dr=0.93 t=0.0ps kin=1.52 pot=19.77 Rg=15.612 SPS=2223
# 3rd loop
# ---
#
# bl=336 pos[1]=[-9.3 -10.9 -3.4] dr=0.96 t=0.0ps kin=1.51 pot=19.76 Rg=15.586 SPS=2233
# 3rd loop
# ---
#
# bl=337 pos[1]=[-9.9 -11.3 -3.7] dr=0.95 t=0.0ps kin=1.50 pot=19.75 Rg=15.553 SPS=2255
# 3rd loop
# ---
#
# bl=338 pos[1]=[-10.4 -11.2 -3.2] dr=0.95 t=0.0ps kin=1.50 pot=19.76 Rg=15.504 SPS=2290
# 3rd loop
# ---
# bl=339 pos[1]=[-10.5 -11.6 -2.8] dr=0.94 t=0.0ps kin=1.51 pot=19.76 Rg=15.473 SPS=2253
# 3rd loop
# ---
#
# bl=340 pos[1]=[-9.8 -11.1 -3.8] dr=0.94 t=0.0ps kin=1.49 pot=19.79 Rg=15.452 SPS=2278
# 3rd loop
# ---
#
# bl=341 pos[1]=[-9.9 -11.8 -3.4] dr=0.96 t=0.0ps kin=1.51 pot=19.80 Rg=15.446 SPS=2268
# 3rd loop
# ---
#
# bl=342 pos[1]=[-8.1 -12.4 -4.4] dr=0.95 t=0.0ps kin=1.50 pot=19.80 Rg=15.424 SPS=2315
# 3rd loop
# ---
#
# bl=343 pos[1]=[-7.3 -12.4 -4.4] dr=0.95 t=0.0ps kin=1.48 pot=19.81 Rg=15.406 SPS=2307
# 3rd loop
# ---
#
# bl=344 pos[1]=[-8.2 -13.4 -4.1] dr=0.95 t=0.0ps kin=1.49 pot=19.80 Rg=15.377 SPS=2263
# 3rd loop
# ---
#
# bl=345 pos[1]=[-8.1 -13.6 -5.4] dr=0.96 t=0.0ps kin=1.49 pot=19.81 Rg=15.362 SPS=2308
# 3rd loop
# ---
#
# bl=346 pos[1]=[-7.9 -14.3 -5.0] dr=0.95 t=0.0ps kin=1.48 pot=19.79 Rg=15.364 SPS=2311
# 3rd loop
# ---
#
# bl=347 pos[1]=[-7.7 -14.2 -5.3] dr=0.95 t=0.0ps kin=1.48 pot=19.77 Rg=15.342 SPS=2246
# 3rd loop
# ---
#
# bl=348 pos[1]=[-8.1 -14.1 -5.3] dr=0.95 t=0.0ps kin=1.51 pot=19.79 Rg=15.309 SPS=2282
# 3rd loop
# ---
#
# bl=349 pos[1]=[-7.6 -13.9 -5.3] dr=0.95 t=0.0ps kin=1.49 pot=19.79 Rg=15.293 SPS=2296
# 3rd loop
# ---
#
#
# Statistics for the simulation chr10_chr11, number of particles: 5415,  number of chains: 2
#
# Statistics for particle position
#      mean position is:  [-0.58087546  0.35117396  0.28291914]   Rg =  15.293335
#      median bond size is  0.9637916236893711
#      three shortest/longest (<10)/ bonds are  [0.8759002  0.87771591 0.87950687]    [1.0871628  1.08994009 1.11878702]
#      95 percentile of distance to center is:    20.89976470438856
#      density of closest 95% monomers is:    0.13452694095691486
#      density of the core monomers is:    0.16167557288220857
#      min/median/mean/max coordinates are:
#      x: -19.47, -0.63, -0.58, 19.04
#      y: -18.04, 1.05, 0.35, 21.29
#      z: -15.25, -0.31, 0.28, 17.11
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4956262478468927 should be: 1.5
#      fastest particles are (in kT):  [8.38933548 8.39106641 8.6792605  8.95000506 9.88854109]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosomeChain0', 'IdealChromosomeChain1']
#      Number of exceptions:   5413
#
# Potential Energy Ep =  19.791396872114497
# bl=350 pos[1]=[-7.7 -13.1 -5.1] dr=0.95 t=0.0ps kin=1.51 pot=19.80 Rg=15.312 SPS=2237
# 3rd loop
# ---
#
# bl=351 pos[1]=[-7.4 -13.2 -4.5] dr=0.94 t=0.0ps kin=1.50 pot=19.80 Rg=15.334 SPS=2229
# 3rd loop
# ---
#
# bl=352 pos[1]=[-7.1 -13.5 -4.4] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=15.328 SPS=2209
# 3rd loop
# ---
#
# bl=353 pos[1]=[-7.1 -13.2 -3.6] dr=0.96 t=0.0ps kin=1.48 pot=19.76 Rg=15.308 SPS=2269
# 3rd loop
# ---
#
# bl=354 pos[1]=[-7.0 -13.6 -3.6] dr=0.95 t=0.0ps kin=1.50 pot=19.77 Rg=15.300 SPS=2301
# 3rd loop
# ---
#
# bl=355 pos[1]=[-7.2 -12.6 -4.2] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=15.307 SPS=2261
# 3rd loop
# ---
#
# bl=356 pos[1]=[-6.9 -12.8 -4.8] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=15.294 SPS=2325
# 3rd loop
# ---
#
# bl=357 pos[1]=[-6.7 -12.4 -4.7] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=15.286 SPS=2251
# 3rd loop
# ---
#
# bl=358 pos[1]=[-7.0 -12.9 -4.9] dr=0.93 t=0.0ps kin=1.48 pot=19.75 Rg=15.266 SPS=2273
# 3rd loop
# ---
#
# bl=359 pos[1]=[-6.8 -13.4 -4.4] dr=0.93 t=0.0ps kin=1.48 pot=19.75 Rg=15.233 SPS=2273
# 3rd loop
# ---
#
# bl=360 pos[1]=[-7.1 -13.4 -3.9] dr=0.94 t=0.0ps kin=1.51 pot=19.75 Rg=15.213 SPS=2253
# 3rd loop
# ---
#
# bl=361 pos[1]=[-6.3 -14.1 -3.2] dr=0.94 t=0.0ps kin=1.47 pot=19.77 Rg=15.223 SPS=2243
# 3rd loop
# ---
#
# bl=362 pos[1]=[-5.9 -13.7 -3.2] dr=0.94 t=0.0ps kin=1.50 pot=19.77 Rg=15.217 SPS=2275
# 3rd loop
# ---
#
# bl=363 pos[1]=[-5.7 -14.7 -3.4] dr=0.93 t=0.0ps kin=1.49 pot=19.79 Rg=15.215 SPS=2288
# 3rd loop
# ---
#
# bl=364 pos[1]=[-6.5 -15.1 -3.0] dr=0.95 t=0.0ps kin=1.52 pot=19.77 Rg=15.211 SPS=2183
# 3rd loop
# ---
#
# bl=365 pos[1]=[-6.2 -14.8 -3.4] dr=0.95 t=0.0ps kin=1.50 pot=19.79 Rg=15.194 SPS=2309
# 3rd loop
# ---
#
# bl=366 pos[1]=[-5.3 -14.6 -3.0] dr=0.95 t=0.0ps kin=1.49 pot=19.80 Rg=15.177 SPS=2221
# 3rd loop
# ---
#
# bl=367 pos[1]=[-5.1 -13.7 -2.9] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=15.152 SPS=2338
# 3rd loop
# ---
#
# bl=368 pos[1]=[-4.9 -13.5 -2.8] dr=0.95 t=0.0ps kin=1.47 pot=19.79 Rg=15.130 SPS=2255
# 3rd loop
# ---
#
# bl=369 pos[1]=[-5.0 -13.7 -3.1] dr=0.95 t=0.0ps kin=1.49 pot=19.77 Rg=15.123 SPS=2226
# 3rd loop
# ---
#
# bl=370 pos[1]=[-6.1 -12.9 -2.8] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=15.114 SPS=2291
# 3rd loop
# ---
#
# bl=371 pos[1]=[-6.5 -12.9 -2.7] dr=0.94 t=0.0ps kin=1.49 pot=19.80 Rg=15.109 SPS=2211
# 3rd loop
# ---
#
# bl=372 pos[1]=[-5.4 -13.1 -3.0] dr=0.94 t=0.0ps kin=1.48 pot=19.78 Rg=15.116 SPS=2265
# 3rd loop
# ---
#
# bl=373 pos[1]=[-5.4 -13.4 -1.5] dr=0.94 t=0.0ps kin=1.51 pot=19.78 Rg=15.095 SPS=2263
# 3rd loop
# ---
#
# bl=374 pos[1]=[-6.2 -12.0 -1.2] dr=0.95 t=0.0ps kin=1.52 pot=19.75 Rg=15.065 SPS=2270
# 3rd loop
# ---
#
# bl=375 pos[1]=[-6.2 -11.3 -1.2] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=15.022 SPS=2236
# 3rd loop
# ---
#
# bl=376 pos[1]=[-5.5 -11.7 -1.4] dr=0.95 t=0.0ps kin=1.50 pot=19.77 Rg=15.012 SPS=2245
# 3rd loop
# ---
#
# bl=377 pos[1]=[-5.4 -11.7 -1.5] dr=0.94 t=0.0ps kin=1.47 pot=19.78 Rg=15.005 SPS=2287
# 3rd loop
# ---
#
# bl=378 pos[1]=[-5.2 -11.2 -1.6] dr=0.94 t=0.0ps kin=1.49 pot=19.77 Rg=14.984 SPS=2281
# 3rd loop
# ---
#
# bl=379 pos[1]=[-5.8 -11.0 -2.1] dr=0.95 t=0.0ps kin=1.50 pot=19.74 Rg=14.954 SPS=2253
# 3rd loop
# ---
#
# bl=380 pos[1]=[-4.5 -10.5 -1.5] dr=0.93 t=0.0ps kin=1.49 pot=19.76 Rg=14.933 SPS=2207
# 3rd loop
# ---
#
# bl=381 pos[1]=[-3.8 -10.4 -0.7] dr=0.93 t=0.0ps kin=1.52 pot=19.77 Rg=14.915 SPS=2225
# 3rd loop
# ---
#
# bl=382 pos[1]=[-3.4 -9.7 -0.9] dr=0.95 t=0.0ps kin=1.50 pot=19.80 Rg=14.896 SPS=2231
# 3rd loop
# ---
#
# bl=383 pos[1]=[-5.6 -9.0 -0.5] dr=0.95 t=0.0ps kin=1.50 pot=19.79 Rg=14.897 SPS=2266
# 3rd loop
# ---
#
# bl=384 pos[1]=[-4.7 -9.2 -0.2] dr=0.95 t=0.0ps kin=1.48 pot=19.78 Rg=14.890 SPS=2262
# 3rd loop
# ---
#
# bl=385 pos[1]=[-4.7 -10.5 -0.3] dr=0.95 t=0.0ps kin=1.49 pot=19.77 Rg=14.877 SPS=2279
# 3rd loop
# ---
#
# bl=386 pos[1]=[-5.3 -10.1 -0.1] dr=0.92 t=0.0ps kin=1.48 pot=19.78 Rg=14.875 SPS=2260
# 3rd loop
# ---
#
# bl=387 pos[1]=[-5.1 -9.4 -0.1] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=14.839 SPS=2250
# 3rd loop
# ---
#
# bl=388 pos[1]=[-5.5 -9.4 0.4] dr=0.95 t=0.0ps kin=1.50 pot=19.77 Rg=14.801 SPS=2279
# 3rd loop
# ---
#
# ...
# ---
#
# bl=877 pos[1]=[-12.9 -9.1 0.5] dr=0.94 t=0.0ps kin=1.50 pot=19.79 Rg=14.354 SPS=2269
# 3rd loop
# ---
#
# bl=878 pos[1]=[-12.5 -8.8 1.0] dr=0.94 t=0.0ps kin=1.51 pot=19.74 Rg=14.347 SPS=2266
# 3rd loop
# ---
#
# bl=879 pos[1]=[-12.7 -9.4 1.8] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=14.349 SPS=2289
# 3rd loop
# ---
#
# bl=880 pos[1]=[-12.2 -9.3 2.1] dr=0.94 t=0.0ps kin=1.49 pot=19.76 Rg=14.345 SPS=2273
# 3rd loop
# ---
#
# bl=881 pos[1]=[-12.9 -9.7 1.8] dr=0.97 t=0.0ps kin=1.49 pot=19.81 Rg=14.324 SPS=2313
# 3rd loop
# ---
#
# bl=882 pos[1]=[-12.0 -9.9 2.0] dr=0.96 t=0.0ps kin=1.52 pot=19.79 Rg=14.332 SPS=2209
# 3rd loop
# ---
#
# bl=883 pos[1]=[-12.1 -10.3 2.4] dr=0.94 t=0.0ps kin=1.48 pot=19.78 Rg=14.345 SPS=2229
# 3rd loop
# ---
#
# bl=884 pos[1]=[-12.1 -10.2 2.4] dr=0.94 t=0.0ps kin=1.51 pot=19.75 Rg=14.332 SPS=2313
# 3rd loop
# ---
#
# bl=885 pos[1]=[-11.9 -9.8 2.2] dr=0.95 t=0.0ps kin=1.48 pot=19.76 Rg=14.323 SPS=2298
# 3rd loop
# ---
#
# bl=886 pos[1]=[-12.9 -9.0 1.9] dr=0.94 t=0.0ps kin=1.46 pot=19.77 Rg=14.307 SPS=2233
# 3rd loop
# ---
#
# bl=887 pos[1]=[-12.5 -9.3 0.4] dr=0.94 t=0.0ps kin=1.48 pot=19.73 Rg=14.287 SPS=2310
# 3rd loop
# ---
#
# bl=888 pos[1]=[-11.9 -9.3 1.0] dr=0.94 t=0.0ps kin=1.47 pot=19.76 Rg=14.267 SPS=2281
# 3rd loop
# ---
#
# bl=889 pos[1]=[-11.5 -9.4 2.0] dr=0.96 t=0.0ps kin=1.52 pot=19.75 Rg=14.266 SPS=2264
# 3rd loop
# ---
#
# bl=890 pos[1]=[-12.0 -9.3 0.9] dr=0.95 t=0.0ps kin=1.48 pot=19.80 Rg=14.234 SPS=2248
# 3rd loop
# ---
#
# bl=891 pos[1]=[-12.6 -9.2 1.7] dr=0.95 t=0.0ps kin=1.52 pot=19.78 Rg=14.204 SPS=2226
# 3rd loop
# ---
#
# bl=892 pos[1]=[-13.0 -9.6 1.6] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=14.193 SPS=2247
# 3rd loop
# ---
#
# bl=893 pos[1]=[-12.3 -8.7 1.2] dr=0.94 t=0.0ps kin=1.50 pot=19.81 Rg=14.182 SPS=2304
# 3rd loop
# ---
#
# bl=894 pos[1]=[-12.3 -10.1 1.8] dr=0.95 t=0.0ps kin=1.53 pot=19.78 Rg=14.173 SPS=2172
# 3rd loop
# ---
#
# bl=895 pos[1]=[-12.8 -10.6 1.6] dr=0.94 t=0.0ps kin=1.52 pot=19.77 Rg=14.170 SPS=2272
# 3rd loop
# ---
#
# bl=896 pos[1]=[-12.4 -10.2 1.1] dr=0.95 t=0.0ps kin=1.50 pot=19.78 Rg=14.166 SPS=2284
# 3rd loop
# ---
#
# bl=897 pos[1]=[-12.9 -10.3 0.9] dr=0.93 t=0.0ps kin=1.51 pot=19.76 Rg=14.155 SPS=2169
# 3rd loop
# ---
#
# bl=898 pos[1]=[-12.7 -9.6 2.0] dr=0.94 t=0.0ps kin=1.47 pot=19.78 Rg=14.149 SPS=2374
# 3rd loop
# ---
#
# bl=899 pos[1]=[-13.3 -9.5 1.6] dr=0.94 t=0.0ps kin=1.50 pot=19.75 Rg=14.115 SPS=2300
# 3rd loop
# ---
#
#
# Statistics for the simulation chr10_chr11, number of particles: 5415,  number of chains: 2
#
# Statistics for particle position
#      mean position is:  [-1.46794316  0.81646947  0.50513541]   Rg =  14.114708
#      median bond size is  0.9638349286814242
#      three shortest/longest (<10)/ bonds are  [0.87291807 0.8774018  0.87951431]    [1.10709639 1.11116516 1.12167755]
#      95 percentile of distance to center is:    19.85947009143893
#      density of closest 95% monomers is:    0.15679437876423147
#      density of the core monomers is:    0.23679993216292322
#      min/median/mean/max coordinates are:
#      x: -23.04, -0.86, -1.47, 20.02
#      y: -16.96, 0.87, 0.82, 19.07
#      z: -11.07, 0.21, 0.51, 13.70
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5045692080210813 should be: 1.5
#      fastest particles are (in kT):  [ 8.30141211  9.30516287  9.43278575  9.6326609  10.32244269]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosomeChain0', 'IdealChromosomeChain1']
#      Number of exceptions:   5413
#
# Potential Energy Ep =  19.753889658356417
# bl=900 pos[1]=[-12.1 -10.1 1.5] dr=0.94 t=0.0ps kin=1.51 pot=19.75 Rg=14.097 SPS=2310
# 3rd loop
# ---
#
# bl=901 pos[1]=[-11.1 -9.9 1.6] dr=0.93 t=0.0ps kin=1.51 pot=19.76 Rg=14.091 SPS=2270
# 3rd loop
# ---
#
# bl=902 pos[1]=[-11.1 -9.8 1.6] dr=0.93 t=0.0ps kin=1.48 pot=19.76 Rg=14.063 SPS=2283
# 3rd loop
# ---
#
# bl=903 pos[1]=[-10.9 -10.0 1.7] dr=0.94 t=0.0ps kin=1.51 pot=19.74 Rg=14.021 SPS=2316
# 3rd loop
# ---
#
# bl=904 pos[1]=[-10.7 -9.9 2.0] dr=0.94 t=0.0ps kin=1.49 pot=19.75 Rg=14.000 SPS=2250
# 3rd loop
# ---
#
# bl=905 pos[1]=[-10.4 -9.7 1.7] dr=0.93 t=0.0ps kin=1.48 pot=19.76 Rg=13.996 SPS=2286
# 3rd loop
# ---
#
# bl=906 pos[1]=[-10.6 -9.8 1.4] dr=0.94 t=0.0ps kin=1.48 pot=19.77 Rg=13.990 SPS=2209
# 3rd loop
# ---
#
# bl=907 pos[1]=[-10.7 -9.0 0.6] dr=0.93 t=0.0ps kin=1.50 pot=19.76 Rg=13.979 SPS=2257
# 3rd loop
# ---
#
# bl=908 pos[1]=[-11.6 -9.3 0.7] dr=0.94 t=0.0ps kin=1.50 pot=19.73 Rg=13.969 SPS=2180
# 3rd loop
# ---
#
# bl=909 pos[1]=[-11.1 -9.5 0.8] dr=0.94 t=0.0ps kin=1.49 pot=19.75 Rg=13.994 SPS=2224
# 3rd loop
# ---
#
# bl=910 pos[1]=[-11.7 -9.1 1.5] dr=0.93 t=0.0ps kin=1.51 pot=19.74 Rg=14.017 SPS=2282
# 3rd loop
# ---
#
# bl=911 pos[1]=[-11.0 -9.1 1.5] dr=0.94 t=0.0ps kin=1.49 pot=19.74 Rg=14.026 SPS=2218
# 3rd loop
# ---
#
# bl=912 pos[1]=[-11.1 -9.1 2.0] dr=0.94 t=0.0ps kin=1.50 pot=19.77 Rg=14.046 SPS=2284
# 3rd loop
# ---
#
# bl=913 pos[1]=[-11.6 -9.3 2.1] dr=0.94 t=0.0ps kin=1.51 pot=19.78 Rg=14.077 SPS=2214
# 3rd loop
# ---
#
# bl=914 pos[1]=[-11.0 -9.1 2.0] dr=0.94 t=0.0ps kin=1.51 pot=19.79 Rg=14.085 SPS=2305
# 3rd loop
# ---
#
# bl=915 pos[1]=[-11.2 -9.4 1.6] dr=0.96 t=0.0ps kin=1.50 pot=19.79 Rg=14.096 SPS=2327
# 3rd loop
# ---
#
# bl=916 pos[1]=[-11.2 -9.6 1.3] dr=0.95 t=0.0ps kin=1.52 pot=19.78 Rg=14.106 SPS=2212
# 3rd loop
# ---
#
# bl=917 pos[1]=[-10.4 -10.1 1.3] dr=0.94 t=0.0ps kin=1.52 pot=19.78 Rg=14.122 SPS=2330
# 3rd loop
# ---
#
# bl=918 pos[1]=[-11.7 -10.0 1.8] dr=0.95 t=0.0ps kin=1.49 pot=19.80 Rg=14.112 SPS=2362
# 3rd loop
# ---
#
# bl=919 pos[1]=[-12.1 -10.1 1.5] dr=0.93 t=0.0ps kin=1.50 pot=19.78 Rg=14.079 SPS=2307
# 3rd loop
# ---
#
# bl=920 pos[1]=[-11.8 -8.4 2.3] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=14.071 SPS=2251
# 3rd loop
# ---
#
# bl=921 pos[1]=[-11.3 -9.4 1.7] dr=0.93 t=0.0ps kin=1.51 pot=19.77 Rg=14.060 SPS=2263
# 3rd loop
# ---
#
# bl=922 pos[1]=[-12.2 -9.9 1.6] dr=0.95 t=0.0ps kin=1.50 pot=19.78 Rg=14.069 SPS=2261
# 3rd loop
# ---
#
# bl=923 pos[1]=[-11.7 -10.7 1.5] dr=0.95 t=0.0ps kin=1.51 pot=19.79 Rg=14.069 SPS=2308
# 3rd loop
# ---
#
# bl=924 pos[1]=[-10.3 -10.2 1.5] dr=0.94 t=0.0ps kin=1.51 pot=19.79 Rg=14.032 SPS=2205
# 3rd loop
# ---
#
# bl=925 pos[1]=[-10.1 -10.9 1.9] dr=0.92 t=0.0ps kin=1.50 pot=19.81 Rg=14.005 SPS=2304
# 3rd loop
# ---
#
# bl=926 pos[1]=[-10.4 -12.2 1.1] dr=0.96 t=0.0ps kin=1.51 pot=19.78 Rg=14.005 SPS=2324
# 3rd loop
# ---
#
# bl=927 pos[1]=[-9.3 -11.7 1.4] dr=0.94 t=0.0ps kin=1.50 pot=19.79 Rg=14.009 SPS=2358
# 3rd loop
# ---
#
# bl=928 pos[1]=[-9.5 -11.8 0.7] dr=0.94 t=0.0ps kin=1.51 pot=19.77 Rg=14.001 SPS=2258
# 3rd loop
# ---
#
# bl=929 pos[1]=[-10.0 -11.3 0.2] dr=0.95 t=0.0ps kin=1.52 pot=19.77 Rg=13.984 SPS=2303
# 3rd loop
# ---
#
# bl=930 pos[1]=[-9.9 -12.1 -0.0] dr=0.95 t=0.0ps kin=1.53 pot=19.76 Rg=13.979 SPS=2293
# 3rd loop
# ---
#
# bl=931 pos[1]=[-8.8 -11.3 0.6] dr=0.95 t=0.0ps kin=1.51 pot=19.76 Rg=13.966 SPS=2205
# 3rd loop
# ---
#
# bl=932 pos[1]=[-8.8 -11.5 1.5] dr=0.93 t=0.0ps kin=1.50 pot=19.77 Rg=13.977 SPS=2355
# 3rd loop
# ---
#
# bl=933 pos[1]=[-7.7 -11.3 0.7] dr=0.94 t=0.0ps kin=1.50 pot=19.76 Rg=13.988 SPS=2253
# 3rd loop
# ---
#
# bl=934 pos[1]=[-8.2 -10.6 1.5] dr=0.95 t=0.0ps kin=1.50 pot=19.74 Rg=13.980 SPS=2254
# 3rd loop
# ---
#
# bl=935 pos[1]=[-7.5 -10.1 0.9] dr=0.92 t=0.0ps kin=1.47 pot=19.78 Rg=13.957 SPS=2287
# 3rd loop
# ---
#
# bl=936 pos[1]=[-7.4 -10.1 0.8] dr=0.94 t=0.0ps kin=1.48 pot=19.78 Rg=13.922 SPS=2330
# 3rd loop
# ---
#
# bl=937 pos[1]=[-7.1 -10.3 1.0] dr=0.93 t=0.0ps kin=1.49 pot=19.75 Rg=13.883 SPS=2253
# 3rd loop
# ---
#
# bl=938 pos[1]=[-6.8 -10.2 0.9] dr=0.94 t=0.0ps kin=1.48 pot=19.74 Rg=13.859 SPS=2216
# 3rd loop
# ---
#
# bl=939 pos[1]=[-7.8 -11.0 1.9] dr=0.92 t=0.0ps kin=1.47 pot=19.73 Rg=13.855 SPS=2339
# 3rd loop
# ---
#
# bl=940 pos[1]=[-8.6 -11.5 2.5] dr=0.93 t=0.0ps kin=1.47 pot=19.75 Rg=13.866 SPS=2211
# 3rd loop
# ---
#
# bl=941 pos[1]=[-7.8 -11.3 3.4] dr=0.95 t=0.0ps kin=1.48 pot=19.74 Rg=13.878 SPS=2296
# 3rd loop
# ---
# bl=942 pos[1]=[-8.4 -10.4 3.5] dr=0.95 t=0.0ps kin=1.47 pot=19.76 Rg=13.892 SPS=2327
# 3rd loop
# ---
#
# bl=943 pos[1]=[-9.0 -9.7 3.8] dr=0.93 t=0.0ps kin=1.50 pot=19.75 Rg=13.934 SPS=2219
# 3rd loop
# ---
#
# bl=944 pos[1]=[-9.1 -9.6 4.1] dr=0.94 t=0.0ps kin=1.50 pot=19.75 Rg=13.961 SPS=2218
# 3rd loop
# ---
#
# bl=945 pos[1]=[-10.0 -10.0 4.6] dr=0.95 t=0.0ps kin=1.47 pot=19.78 Rg=13.975 SPS=2253
# 3rd loop
# ---
#
# bl=946 pos[1]=[-8.5 -10.3 4.2] dr=0.95 t=0.0ps kin=1.50 pot=19.76 Rg=13.973 SPS=2208
# 3rd loop
# ---
#
# bl=947 pos[1]=[-8.5 -10.0 4.7] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=13.955 SPS=2314
# 3rd loop
# ---
#
# bl=948 pos[1]=[-7.4 -8.8 4.7] dr=0.95 t=0.0ps kin=1.52 pot=19.76 Rg=13.942 SPS=2296
# 3rd loop
# ---
#
# bl=949 pos[1]=[-7.7 -8.2 4.9] dr=0.95 t=0.0ps kin=1.52 pot=19.79 Rg=13.937 SPS=2244
# 3rd loop
# ---
#
#
# Statistics for the simulation chr10_chr11, number of particles: 5415,  number of chains: 2
#
# Statistics for particle position
#      mean position is:  [-1.31748324  0.29032331  0.21154068]   Rg =  13.936526
#      median bond size is  0.9638704943161286
#      three shortest/longest (<10)/ bonds are  [0.87934957 0.88062801 0.8844589 ]    [1.0996766  1.10469078 1.13044753]
#      95 percentile of distance to center is:    19.532390737937227
#      density of closest 95% monomers is:    0.16480380943106357
#      density of the core monomers is:    0.23546980780338586
#      min/median/mean/max coordinates are:
#      x: -22.62, -0.99, -1.32, 17.76
#      y: -17.23, 0.03, 0.29, 18.98
#      z: -12.86, 0.03, 0.21, 15.47
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5232627962465586 should be: 1.5
#      fastest particles are (in kT):  [7.69131641 7.78397291 8.23286283 8.71368972 9.44578729]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosomeChain0', 'IdealChromosomeChain1']
#      Number of exceptions:   5413
#
# Potential Energy Ep =  19.789716066481994
# bl=950 pos[1]=[-7.5 -9.0 5.1] dr=0.95 t=0.0ps kin=1.48 pot=19.78 Rg=13.930 SPS=2291
# 3rd loop
# ---
#
# bl=951 pos[1]=[-7.2 -8.5 4.7] dr=0.95 t=0.0ps kin=1.49 pot=19.78 Rg=13.917 SPS=2257
# 3rd loop
# ---
#
# bl=952 pos[1]=[-7.7 -7.9 4.2] dr=0.93 t=0.0ps kin=1.51 pot=19.76 Rg=13.904 SPS=2327
# 3rd loop
# ---
#
# bl=953 pos[1]=[-8.3 -8.4 4.1] dr=0.95 t=0.0ps kin=1.49 pot=19.76 Rg=13.906 SPS=2209
# 3rd loop
# ---
#
# bl=954 pos[1]=[-7.9 -7.6 4.2] dr=0.94 t=0.0ps kin=1.50 pot=19.73 Rg=13.930 SPS=2282
# 3rd loop
# ---
#
# bl=955 pos[1]=[-7.1 -7.3 3.9] dr=0.93 t=0.0ps kin=1.49 pot=19.74 Rg=13.972 SPS=2296
# 3rd loop
# ---
#
# bl=956 pos[1]=[-7.1 -8.0 3.8] dr=0.94 t=0.0ps kin=1.50 pot=19.71 Rg=14.002 SPS=2191
# 3rd loop
# ---
#
# bl=957 pos[1]=[-6.8 -8.7 4.1] dr=0.94 t=0.0ps kin=1.48 pot=19.74 Rg=14.023 SPS=2316
# 3rd loop
# ---
#
# bl=958 pos[1]=[-7.6 -9.6 3.9] dr=0.93 t=0.0ps kin=1.48 pot=19.74 Rg=14.039 SPS=2326
# 3rd loop
# ---
#
# bl=959 pos[1]=[-8.4 -9.6 3.5] dr=0.94 t=0.0ps kin=1.48 pot=19.76 Rg=14.050 SPS=2268
# 3rd loop
# ---
#
# bl=960 pos[1]=[-7.9 -10.1 2.9] dr=0.94 t=0.0ps kin=1.50 pot=19.75 Rg=14.054 SPS=2250
# 3rd loop
# ---
#
# bl=961 pos[1]=[-7.9 -9.6 3.1] dr=0.95 t=0.0ps kin=1.48 pot=19.76 Rg=14.074 SPS=2225
# 3rd loop
# ---
#
# bl=962 pos[1]=[-7.0 -8.9 2.4] dr=0.93 t=0.0ps kin=1.46 pot=19.74 Rg=14.115 SPS=2228
# 3rd loop
# ---
#
# bl=963 pos[1]=[-7.4 -8.5 2.3] dr=0.95 t=0.0ps kin=1.48 pot=19.76 Rg=14.129 SPS=2326
# 3rd loop
# ---
#
# bl=964 pos[1]=[-7.4 -8.9 1.6] dr=0.93 t=0.0ps kin=1.49 pot=19.76 Rg=14.133 SPS=2277
# 3rd loop
# ---
#
# bl=965 pos[1]=[-7.8 -9.7 1.9] dr=0.95 t=0.0ps kin=1.50 pot=19.75 Rg=14.143 SPS=2214
# 3rd loop
# ---
#
# bl=966 pos[1]=[-6.8 -9.8 2.1] dr=0.95 t=0.0ps kin=1.49 pot=19.77 Rg=14.158 SPS=2240
# 3rd loop
# ---
#
# bl=967 pos[1]=[-5.3 -10.5 2.5] dr=0.95 t=0.0ps kin=1.49 pot=19.76 Rg=14.159 SPS=2265
# 3rd loop
# ---
#
# bl=968 pos[1]=[-5.1 -11.0 1.9] dr=0.93 t=0.0ps kin=1.47 pot=19.76 Rg=14.164 SPS=2233
# 3rd loop
# ---
#
# bl=969 pos[1]=[-6.0 -10.8 2.2] dr=0.93 t=0.0ps kin=1.47 pot=19.76 Rg=14.165 SPS=2322
# 3rd loop
# ---
#
# bl=970 pos[1]=[-6.4 -10.5 1.8] dr=0.92 t=0.0ps kin=1.46 pot=19.76 Rg=14.152 SPS=2278
# 3rd loop
# ---
#
# bl=971 pos[1]=[-6.7 -9.3 1.3] dr=0.93 t=0.0ps kin=1.49 pot=19.74 Rg=14.125 SPS=2221
# 3rd loop
# ---
#
# bl=972 pos[1]=[-6.4 -9.6 0.2] dr=0.94 t=0.0ps kin=1.50 pot=19.75 Rg=14.102 SPS=2188
# 3rd loop
# ---
#
# bl=973 pos[1]=[-7.1 -10.1 0.4] dr=0.92 t=0.0ps kin=1.46 pot=19.77 Rg=14.108 SPS=2245
# 3rd loop
# ---
#
# bl=974 pos[1]=[-7.1 -10.1 0.6] dr=0.93 t=0.0ps kin=1.47 pot=19.77 Rg=14.116 SPS=2174
# 3rd loop
# ---
#
# bl=975 pos[1]=[-5.7 -10.3 1.9] dr=0.93 t=0.0ps kin=1.49 pot=19.77 Rg=14.121 SPS=2246
# 3rd loop
# ---
#
# bl=976 pos[1]=[-5.8 -10.3 2.0] dr=0.96 t=0.0ps kin=1.49 pot=19.76 Rg=14.115 SPS=2312
# 3rd loop
# ---
#
# bl=977 pos[1]=[-5.9 -10.6 1.4] dr=0.93 t=0.0ps kin=1.51 pot=19.78 Rg=14.125 SPS=2313
# 3rd loop
# ---
#
# bl=978 pos[1]=[-5.6 -9.9 1.6] dr=0.94 t=0.0ps kin=1.49 pot=19.78 Rg=14.165 SPS=2267
# 3rd loop
# ---
#
# bl=979 pos[1]=[-6.2 -10.2 2.2] dr=0.94 t=0.0ps kin=1.49 pot=19.79 Rg=14.212 SPS=2247
# 3rd loop
# ---
#
# bl=980 pos[1]=[-6.4 -10.0 1.7] dr=0.92 t=0.0ps kin=1.53 pot=19.74 Rg=14.236 SPS=2324
# 3rd loop
# ---
#
# bl=981 pos[1]=[-6.1 -9.3 2.0] dr=0.96 t=0.0ps kin=1.51 pot=19.76 Rg=14.240 SPS=2306
# 3rd loop
# ---
#
# bl=982 pos[1]=[-6.7 -9.8 1.8] dr=0.95 t=0.0ps kin=1.51 pot=19.75 Rg=14.216 SPS=2364
# 3rd loop
# ---
#
# bl=983 pos[1]=[-5.9 -10.3 1.7] dr=0.94 t=0.0ps kin=1.48 pot=19.77 Rg=14.220 SPS=2242
# 3rd loop
# ---
#
# bl=984 pos[1]=[-5.9 -10.1 2.9] dr=0.95 t=0.0ps kin=1.53 pot=19.76 Rg=14.201 SPS=2107
# 3rd loop
# ---
#
# bl=985 pos[1]=[-6.8 -10.6 3.5] dr=0.93 t=0.0ps kin=1.51 pot=19.77 Rg=14.179 SPS=2320
# 3rd loop
# ---
#
# bl=986 pos[1]=[-7.8 -11.4 3.5] dr=0.93 t=0.0ps kin=1.48 pot=19.78 Rg=14.177 SPS=2266
# 3rd loop
# ---
#
# bl=987 pos[1]=[-7.4 -10.8 3.4] dr=0.94 t=0.0ps kin=1.50 pot=19.78 Rg=14.145 SPS=2337
# 3rd loop
# ---
#
# bl=988 pos[1]=[-7.9 -11.4 3.4] dr=0.94 t=0.0ps kin=1.50 pot=19.80 Rg=14.114 SPS=2252
# 3rd loop
# ---
#
# bl=989 pos[1]=[-9.9 -12.1 4.8] dr=0.94 t=0.0ps kin=1.50 pot=19.79 Rg=14.089 SPS=2258
# 3rd loop
# ---
#
# bl=990 pos[1]=[-10.4 -13.1 5.0] dr=0.93 t=0.0ps kin=1.50 pot=19.78 Rg=14.074 SPS=2158
# 3rd loop
# ---
#
# bl=991 pos[1]=[-10.7 -14.0 5.2] dr=0.95 t=0.0ps kin=1.51 pot=19.77 Rg=14.100 SPS=2261
# 3rd loop
# ---
#
# bl=992 pos[1]=[-9.9 -14.3 5.4] dr=0.93 t=0.0ps kin=1.49 pot=19.80 Rg=14.109 SPS=2214
# 3rd loop
# ---
#
# bl=993 pos[1]=[-10.0 -13.8 6.3] dr=0.94 t=0.0ps kin=1.51 pot=19.81 Rg=14.109 SPS=2171
# 3rd loop
# ---
#
# bl=994 pos[1]=[-9.5 -13.2 6.5] dr=0.95 t=0.0ps kin=1.55 pot=19.77 Rg=14.101 SPS=2270
# 3rd loop
# ---
#
# bl=995 pos[1]=[-8.8 -11.3 5.5] dr=0.97 t=0.0ps kin=1.55 pot=19.80 Rg=14.088 SPS=2192
# 3rd loop
# ---
#
# bl=996 pos[1]=[-9.2 -10.8 6.8] dr=0.96 t=0.0ps kin=1.50 pot=19.79 Rg=14.084 SPS=2305
# 3rd loop
# ---
#
# bl=997 pos[1]=[-9.1 -10.8 7.2] dr=0.96 t=0.0ps kin=1.51 pot=19.77 Rg=14.078 SPS=2291
# 3rd loop
# ---
#
# bl=998 pos[1]=[-10.0 -10.1 6.6] dr=0.95 t=0.0ps kin=1.50 pot=19.80 Rg=14.071 SPS=2317
# 3rd loop
# ---
#
# bl=999 pos[1]=[-10.3 -10.4 7.1] dr=0.95 t=0.0ps kin=1.53 pot=19.79 Rg=14.048 SPS=2226
# 3rd loop
# ---
#
#
# Statistics for the simulation chr10_chr11, number of particles: 5415,  number of chains: 2
#
# Statistics for particle position
#      mean position is:  [-1.47887426  0.13038579  0.33628366]   Rg =  14.047767
#      median bond size is  0.9651501413010622
#      three shortest/longest (<10)/ bonds are  [0.86759328 0.86994242 0.87327283]    [1.11807333 1.12797699 1.14518696]
#      95 percentile of distance to center is:    19.607097173692445
#      density of closest 95% monomers is:    0.16292718473018852
#      density of the core monomers is:    0.23577968921433534
#      min/median/mean/max coordinates are:
#      x: -20.23, -1.71, -1.48, 18.01
#      y: -17.49, 0.31, 0.13, 19.66
#      z: -11.74, 0.28, 0.34, 14.54
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5331512819155957 should be: 1.5
#      fastest particles are (in kT):  [ 8.39577398  9.2422969   9.86197706 10.2604216  10.81754499]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'FlatBottomHarmonic', 'TypetoType', 'IdealChromosomeChain0', 'IdealChromosomeChain1']
#      Number of exceptions:   5413
#
# Potential Energy Ep =  19.79353647276085
# bl=1000 pos[1]=[-11.1 -10.7 6.7] dr=0.94 t=0.0ps kin=1.53 pot=19.80 Rg=14.033 SPS=2329
# 3rd loop
# ---

# %% [markdown]
# **Simulation Run Successfully !**
